# %% [markdown]
# # Permutation Importance NLP Feature Ranks

# %%
# Packages
import pandas as pd
from stattotex import stattotex
# Variables of interest
variables_of_interest = ['Passive', 'Ovrst', 'word_count', 'num_transparency', 'pos_score_finbert', 'gf_score']

# %% [markdown]
# ## Load Permutation Importance

# %%
perm_importance = pd.read_parquet('../../../../Output/Modelling/XGBoost/exclude_previous_rating_model_3/exclude_previous_rating_model_3_permutation_importance.parquet')
# Drop 'num__' and 'cat__' from column names
perm_importance['feature'] = perm_importance['feature'].str.replace('num__', '').str.replace('cat__', '')
# Sort and create rank on mean, descending
#perm_importance = perm_importance.sort_values('mean', ascending=False)
perm_importance['rank'] = perm_importance['mean'].rank(ascending=False)
# Make rank an integer
perm_importance['rank'] = perm_importance['rank'].astype(int)
# sort
perm_importance = perm_importance.sort_values('rank')
perm_importance
# Out:
#                      feature      mean       std  rank
# 49          retainedEarnings  0.043819  0.005761     1
# 118                marketCap  0.035169  0.005735     2
# 80             dividendsPaid  0.021455  0.004481     3
# 132                debtRatio  0.009987  0.003413     4
# 48               commonStock  0.009693  0.002248     5
# ..                       ...       ...       ...   ...
# 2             workingCapital -0.001648  0.001732   149
# 138     freeCashFlowPerShare -0.001751  0.000764   150
# 89              freeCashFlow -0.001911  0.000694   151
# 81   otherFinancingActivites -0.002434  0.001301   152
# 19            netReceivables -0.003140  0.001969   153
#
# [153 rows x 4 columns]

# %% [markdown]
# ## Load Variable Index

# %%
variable_index = pd.read_excel('../../../../Variable Index.xlsx')
variable_index
# Out:
#                               column_name  \
# 0                                Altman_Z
# 1                                    EBIT
# 2             common_plus_preferred_stock
# 3                          workingCapital
# 4                                 Ratio_A
# ..                                    ...
# 200        operatingCashFlowPerShare_diff
# 201             freeCashFlowPerShare_diff
# 202                     cashPerShare_diff
# 203         operatingCashFlowToSales_diff
# 204  freeCashFlowToOperatingCashFlow_diff
#
#                                      Clean Column Name  \
# 0                                     Altman's Z Score
# 1                                                 EBIT
# 2                          Common Plus Preferred Stock
# 3                                      Working Capital
# 4                                              Ratio A
# ..                                                 ...
# 200  Difference in Operating Cash Flow Per Share fr...
# 201  Difference in Free Cash Flow Per Share from pr...
# 202  Difference in Cash Per Share from prior fixed ...
# 203  Difference in Operating Cash Flow to Sales fro...
# 204  Difference in Free Cash Flow to Operating Cash...
#
#                   Variable Type Data Type Ratio?  \
# 0              Altman's Z Score   Numeric      Y
# 1    Constructed for Altman's Z   Numeric    NaN
# 2    Constructed for Altman's Z   Numeric    NaN
# 3    Constructed for Altman's Z   Numeric    NaN
# 4    Constructed for Altman's Z   Numeric      Y
# ..                          ...       ...    ...
# 200    Additional Change Ratios   Numeric    NaN
# 201    Additional Change Ratios   Numeric    NaN
# 202    Additional Change Ratios   Numeric    NaN
# 203    Additional Change Ratios   Numeric    NaN
# 204    Additional Change Ratios   Numeric    NaN
#
#                                                  Notes Rating Model 1  \
# 0                                                  NaN              X
# 1                                                  NaN            NaN
# 2                                                  NaN            NaN
# 3                                                  NaN            NaN
# 4                                                  NaN            NaN
# ..                                                 ...            ...
# 200  Primarily for changes models, but can be used ...            NaN
# 201  Primarily for changes models, but can be used ...            NaN
# 202  Primarily for changes models, but can be used ...            NaN
# 203  Primarily for changes models, but can be used ...            NaN
# 204  Primarily for changes models, but can be used ...            NaN
#
#     Rating Model 2 Rating Model 3 Change Model 1 Change Model 2 Change Model 3
# 0              NaN            NaN              X            NaN            NaN
# 1                X              X            NaN              X              X
# 2                X              X            NaN              X              X
# 3                X              X            NaN              X              X
# 4                X              X            NaN              X              X
# ..             ...            ...            ...            ...            ...
# 200            NaN            NaN            NaN              X              X
# 201            NaN            NaN            NaN              X              X
# 202            NaN            NaN            NaN              X              X
# 203            NaN            NaN            NaN              X              X
# 204            NaN            NaN            NaN              X              X
#
# [205 rows x 12 columns]

# %%
# Values of Variable Type
variable_index['Variable Type'].value_counts()
# Out:
# Variable Type
# Financial Statements          108
# Additional Change Ratios       17
# Additional Ratios              17
# Constructed for Tone           12
# Change Ratios                  11
# Disallowed                      8
# Constructed for Altman's Z      8
# Metadata                        7
# NLP Feature                     7
# Predicted - Change              2
# Predicted - Rating              2
# Previous Rating                 1
# Sector                          1
# Train-Test Split                1
# Transcript Text                 1
# Market Capitalization           1
# Altman's Z Score                1
# Name: count, dtype: int64

# %% [markdown]
# ## Merge

# %%
combined = perm_importance.merge(variable_index, left_on='feature', right_on='column_name', how='left')
# Limit to Variable Type of 'Constructed for Tone', 'NLP Feature'
combined = combined[combined['Variable Type'].isin(['Constructed for Tone', 'NLP Feature'])]
# Limit to feature in variables of interest
#combined = combined[combined['feature'].isin(variables_of_interest)]
# Rank for Negativ
rneg = combined.query('feature == "Negativ"')['rank'].values[0]
print(rneg)
# Stattotex
stattotex(rneg, 'rNeg', '../../../../Output/Modelling/XGBoost/exclude_previous_rating_model_3/permutation_importance_nlp_ranks.tex')
# Rank for pos_score_finbert
pos_score_finbert = combined.query('feature == "pos_score_finbert"')['rank'].values[0]
stattotex(pos_score_finbert, 'rPosScoreFinbert', '../../../../Output/Modelling/XGBoost/exclude_previous_rating_model_3/permutation_importance_nlp_ranks.tex')
# Rank for Undrst
undrst = combined.query('feature == "Undrst"')['rank'].values[0]
stattotex(undrst, 'rUndrst', '../../../../Output/Modelling/XGBoost/exclude_previous_rating_model_3/permutation_importance_nlp_ranks.tex')
# Rank for num_transparency
num_transparency = combined.query('feature == "num_transparency"')['rank'].values[0]
stattotex(num_transparency, 'rNumTransparency', '../../../../Output/Modelling/XGBoost/exclude_previous_rating_model_3/permutation_importance_nlp_ranks.tex')
# Rank for word_count
word_count = combined.query('feature == "word_count"')['rank'].values[0]
stattotex(word_count, 'rWordCount', '../../../../Output/Modelling/XGBoost/exclude_previous_rating_model_3/permutation_importance_nlp_ranks.tex')
# Rank for gf_score
gf_score = combined.query('feature == "gf_score"')['rank'].values[0]
stattotex(gf_score, 'rGfScore', '../../../../Output/Modelling/XGBoost/exclude_previous_rating_model_3/permutation_importance_nlp_ranks.tex')
combined
# Out:
# 39
#                feature      mean       std  rank        column_name  \
# 38             Negativ  0.001677  0.001105    39            Negativ
# 41   pos_score_finbert  0.001424  0.001538    42  pos_score_finbert
# 51              Undrst  0.000966  0.001224    52             Undrst
# 67    num_transparency  0.000681  0.001024    68   num_transparency
# 69               Ovrst  0.000568  0.001041    70              Ovrst
# 71             Positiv  0.000522  0.000965    72            Positiv
# 75                tone  0.000372  0.001062    76               tone
# 86        num_q_by_len  0.000099  0.000858    87       num_q_by_len
# 89              Strong  0.000085  0.000727    90             Strong
# 92                Weak  0.000023  0.001397    93               Weak
# 117             Active -0.000371  0.001424   118             Active
# 121           gf_score -0.000463  0.001103   122           gf_score
# 134         word_count -0.000903  0.000984   135         word_count
# 139            Passive -0.001088  0.001715   140            Passive
#
#                                   Clean Column Name         Variable Type  \
# 38                                    Negative Tone  Constructed for Tone
# 41                         FinBERT Positivity Score           NLP Feature
# 51                                 Understated Tone  Constructed for Tone
# 67                             Numeric Transparency           NLP Feature
# 69                                  Overstated Tone  Constructed for Tone
# 71                                    Positive Tone  Constructed for Tone
# 75                First Principal Component of Tone           NLP Feature
# 86   Number of Questions Divided By Call Word Count           NLP Feature
# 89                                      Strong Tone  Constructed for Tone
# 92                                        Weak Tone  Constructed for Tone
# 117                                     Active Tone  Constructed for Tone
# 121                               Gunning-Fog Score           NLP Feature
# 134                                      Word Count           NLP Feature
# 139                                    Passive Tone  Constructed for Tone
#
#     Data Type Ratio?                                              Notes  \
# 38    Numeric    NaN                                                NaN
# 41    Numeric    NaN                               Supersedes pos_score
# 51    Numeric    NaN                                                NaN
# 67    Numeric    NaN                                                NaN
# 69    Numeric    NaN                                                NaN
# 71    Numeric    NaN                                                NaN
# 75    Numeric    NaN                                                NaN
# 86    Numeric    NaN  Replaces old questions variable, less colinear...
# 89    Numeric    NaN                                                NaN
# 92    Numeric    NaN                                                NaN
# 117   Numeric    NaN                                                NaN
# 121   Numeric    NaN                                                NaN
# 134   Numeric    NaN                                                NaN
# 139   Numeric    NaN                                                NaN
#
#     Rating Model 1 Rating Model 2 Rating Model 3 Change Model 1  \
# 38             NaN            NaN              X            NaN
# 41             NaN            NaN              X            NaN
# 51             NaN            NaN              X            NaN
# 67             NaN            NaN              X            NaN
# 69             NaN            NaN              X            NaN
# 71             NaN            NaN              X            NaN
# 75             NaN            NaN              X            NaN
# 86             NaN            NaN              X            NaN
# 89             NaN            NaN              X            NaN
# 92             NaN            NaN              X            NaN
# 117            NaN            NaN              X            NaN
# 121            NaN            NaN              X            NaN
# 134            NaN            NaN              X            NaN
# 139            NaN            NaN              X            NaN
#
#     Change Model 2 Change Model 3
# 38             NaN              X
# 41             NaN              X
# 51             NaN              X
# 67             NaN              X
# 69             NaN              X
# 71             NaN              X
# 75             NaN              X
# 86             NaN              X
# 89             NaN              X
# 92             NaN              X
# 117            NaN              X
# 121            NaN              X
# 134            NaN              X
# 139            NaN              X
