# %% [markdown]
# # Create Figures and Table Components

# %%
# Packages
import sys
import os
# Add the parent directory to sys.path
sys.path.append(os.path.abspath('..'))
# Import module
from Logistic_Regression_Functions import *

# %% [markdown]
# ## Set Classifier Name and Models to iterate over

# %%
# Rating model names
include_exclude_previous = ['exclude_previous_', 'include_previous_']
model_names = ['rating_model_1', 'rating_model_2', 'rating_model_3']
rating_model_names = []
for include_exclude in include_exclude_previous:
    for model_name in model_names:
        rating_model_names.append(include_exclude + model_name)

# Change model names
prefixes = ['rating_change_', 'smote_rating_change_']
endings = ['model_1', 'model_2', 'model_3']
change_model_names = []
for prefix in prefixes:
    for ending in endings:
        change_model_names.append(prefix + ending)

# Full model names
full_model_names = rating_model_names + change_model_names

# %% [markdown]
# ## Iterate Over Full Model Names and Create Figures and Tables

# %%
for full_model_name in full_model_names:
    # Get the column names and mapping
    if not 'change' in full_model_name:
        _, _, target_column, custom_mapping = get_column_names_and_mapping(full_model_name)
    else:
        _, _, target_column, custom_mapping = get_column_names_and_mapping_change(full_model_name)
    print('creating figures and tables for ' + full_model_name)
    create_model_figure_and_table_components(full_model_name, target_column, custom_mapping)
    print('done creating figures and tables for ' + full_model_name)
# Out:
# creating figures and tables for exclude_previous_rating_model_1
# {'accuracy': 0.19230769230769232, 'f1_score': 0.22655235441872731, 'majority_baseline': 0.32468694096601075}
# Share of predictions exactly as the actual: 19.23%
# Share of predictions 1 or fewer ratings away from actual: 46.33%
# classification report:
#               precision    recall  f1-score   support
#
#            A     0.2075    0.1058    0.1401       208
#           AA     0.1290    0.1538    0.1404        52
#          AAA     0.0443    0.2917    0.0769        24
#            B     0.2449    0.0779    0.1182       154
#           BB     0.3728    0.2993    0.3320       284
#          BBB     0.4557    0.1983    0.2764       363
#            C     0.0240    0.7500    0.0465         4
#           CC     0.0000    0.0000    0.0000         2
#          CCC     0.0455    0.2308    0.0759        26
#            D     0.0000    0.0000    0.0000         1
#
#     accuracy                         0.1923      1118
#    macro avg     0.1524    0.2108    0.1207      1118
# weighted avg     0.3231    0.1923    0.2266      1118
#
# counts of y_test values
# Rating
# BBB    363
# BB     284
# A      208
# B      154
# AA      52
# CCC     26
# AAA     24
# C        4
# CC       2
# D        1
# Name: count, dtype: int64
# start of y_pred
# exclude_previous_rating_model_1_predictions
# BB     228
# AAA    158
# BBB    158
# CCC    132
# C      125
# A      106
# CC     100
# AA      62
# B       49
# Name: count, dtype: int64
# custom mapping
# {'AAA': 0, 'AA': 1, 'A': 2, 'BBB': 3, 'BB': 4, 'B': 5, 'CCC': 6, 'CC': 7, 'C': 8, 'D': 9}
# label:  AAA
# label:  AA
# label:  A
# label:  BBB
# label:  BB
# label:  B
# label:  CCC
# label:  CC
# label:  C
# label:  D
# actual labels
# ['AAA', 'AA', 'A', 'BBB', 'BB', 'B', 'CCC', 'CC', 'C', 'D']
# done creating figures and tables for exclude_previous_rating_model_1
# creating figures and tables for exclude_previous_rating_model_2
# {'accuracy': 0.6225402504472272, 'f1_score': 0.6223108274994374, 'majority_baseline': 0.32468694096601075}
# Share of predictions exactly as the actual: 62.25%
# Share of predictions 1 or fewer ratings away from actual: 91.86%
# classification report:
#               precision    recall  f1-score   support
#
#            A     0.5696    0.6298    0.5982       208
#           AA     0.4737    0.5192    0.4954        52
#          AAA     0.8261    0.7917    0.8085        24
#            B     0.5795    0.7338    0.6476       154
#           BB     0.6483    0.5387    0.5885       284
#          BBB     0.6787    0.6226    0.6494       363
#            C     1.0000    1.0000    1.0000         4
#           CC     0.2500    0.5000    0.3333         2
#          CCC     0.6000    0.8077    0.6885        26
#            D     1.0000    1.0000    1.0000         1
#
#     accuracy                         0.6225      1118
#    macro avg     0.6626    0.7143    0.6809      1118
# weighted avg     0.6295    0.6225    0.6223      1118
#
# counts of y_test values
# Rating
# BBB    363
# BB     284
# A      208
# B      154
# AA      52
# CCC     26
# AAA     24
# C        4
# CC       2
# D        1
# Name: count, dtype: int64
# start of y_pred
# exclude_previous_rating_model_2_predictions
# BBB    333
# BB     236
# A      230
# B      195
# AA      57
# CCC     35
# AAA     23
# C        4
# CC       4
# D        1
# Name: count, dtype: int64
# custom mapping
# {'AAA': 0, 'AA': 1, 'A': 2, 'BBB': 3, 'BB': 4, 'B': 5, 'CCC': 6, 'CC': 7, 'C': 8, 'D': 9}
# label:  AAA
# label:  AA
# label:  A
# label:  BBB
# label:  BB
# label:  B
# label:  CCC
# label:  CC
# label:  C
# label:  D
# actual labels
# ['AAA', 'AA', 'A', 'BBB', 'BB', 'B', 'CCC', 'CC', 'C', 'D']
# done creating figures and tables for exclude_previous_rating_model_2
# creating figures and tables for exclude_previous_rating_model_3
# {'accuracy': 0.6332737030411449, 'f1_score': 0.6329282945345679, 'majority_baseline': 0.32468694096601075}
# Share of predictions exactly as the actual: 63.33%
# Share of predictions 1 or fewer ratings away from actual: 92.67%
# classification report:
#               precision    recall  f1-score   support
#
#            A     0.5874    0.6298    0.6079       208
#           AA     0.6316    0.6923    0.6606        52
#          AAA     0.8261    0.7917    0.8085        24
#            B     0.5864    0.7273    0.6493       154
#           BB     0.6275    0.5458    0.5838       284
#          BBB     0.6909    0.6281    0.6580       363
#            C     1.0000    1.0000    1.0000         4
#           CC     0.3333    1.0000    0.5000         2
#          CCC     0.5556    0.7692    0.6452        26
#            D     1.0000    1.0000    1.0000         1
#
#     accuracy                         0.6333      1118
#    macro avg     0.6839    0.7784    0.7113      1118
# weighted avg     0.6389    0.6333    0.6329      1118
#
# counts of y_test values
# Rating
# BBB    363
# BB     284
# A      208
# B      154
# AA      52
# CCC     26
# AAA     24
# C        4
# CC       2
# D        1
# Name: count, dtype: int64
# start of y_pred
# exclude_previous_rating_model_3_predictions
# BBB    330
# BB     247
# A      223
# B      191
# AA      57
# CCC     36
# AAA     23
# CC       6
# C        4
# D        1
# Name: count, dtype: int64
# custom mapping
# {'AAA': 0, 'AA': 1, 'A': 2, 'BBB': 3, 'BB': 4, 'B': 5, 'CCC': 6, 'CC': 7, 'C': 8, 'D': 9}
# label:  AAA
# label:  AA
# label:  A
# label:  BBB
# label:  BB
# label:  B
# label:  CCC
# label:  CC
# label:  C
# label:  D
# actual labels
# ['AAA', 'AA', 'A', 'BBB', 'BB', 'B', 'CCC', 'CC', 'C', 'D']
# done creating figures and tables for exclude_previous_rating_model_3
# creating figures and tables for include_previous_rating_model_1
# {'accuracy': 0.7441860465116279, 'f1_score': 0.7723058628773185, 'majority_baseline': 0.32468694096601075}
# Share of predictions exactly as the actual: 74.42%
# Share of predictions 1 or fewer ratings away from actual: 77.46%
# classification report:
#               precision    recall  f1-score   support
#
#            A     0.9345    0.7548    0.8351       208
#           AA     0.9400    0.9038    0.9216        52
#          AAA     0.3099    0.9167    0.4632        24
#            B     0.2222    0.0260    0.0465       154
#           BB     0.9611    0.8697    0.9131       284
#          BBB     0.9729    0.8898    0.9295       363
#            C     0.0211    1.0000    0.0412         4
#           CC     1.0000    1.0000    1.0000         2
#          CCC     0.8621    0.9615    0.9091        26
#            D     1.0000    1.0000    1.0000         1
#
#     accuracy                         0.7442      1118
#    macro avg     0.7224    0.8322    0.7059      1118
# weighted avg     0.8377    0.7442    0.7723      1118
#
# counts of y_test values
# Rating
# BBB    363
# BB     284
# A      208
# B      154
# AA      52
# CCC     26
# AAA     24
# C        4
# CC       2
# D        1
# Name: count, dtype: int64
# start of y_pred
# include_previous_rating_model_1_predictions
# BBB    332
# BB     257
# C      190
# A      168
# AAA     71
# AA      50
# CCC     29
# B       18
# CC       2
# D        1
# Name: count, dtype: int64
# custom mapping
# {'AAA': 0, 'AA': 1, 'A': 2, 'BBB': 3, 'BB': 4, 'B': 5, 'CCC': 6, 'CC': 7, 'C': 8, 'D': 9}
# label:  AAA
# label:  AA
# label:  A
# label:  BBB
# label:  BB
# label:  B
# label:  CCC
# label:  CC
# label:  C
# label:  D
# actual labels
# ['AAA', 'AA', 'A', 'BBB', 'BB', 'B', 'CCC', 'CC', 'C', 'D']
# done creating figures and tables for include_previous_rating_model_1
# creating figures and tables for include_previous_rating_model_2
# {'accuracy': 0.9508050089445438, 'f1_score': 0.9510246004251419, 'majority_baseline': 0.32468694096601075}
# Share of predictions exactly as the actual: 95.08%
# Share of predictions 1 or fewer ratings away from actual: 99.46%
# classification report:
#               precision    recall  f1-score   support
#
#            A     0.9604    0.9327    0.9463       208
#           AA     0.9412    0.9231    0.9320        52
#          AAA     0.8519    0.9583    0.9020        24
#            B     0.9359    0.9481    0.9419       154
#           BB     0.9573    0.9472    0.9522       284
#          BBB     0.9669    0.9669    0.9669       363
#            C     1.0000    1.0000    1.0000         4
#           CC     1.0000    1.0000    1.0000         2
#          CCC     0.8065    0.9615    0.8772        26
#            D     1.0000    1.0000    1.0000         1
#
#     accuracy                         0.9508      1118
#    macro avg     0.9420    0.9638    0.9519      1118
# weighted avg     0.9518    0.9508    0.9510      1118
#
# counts of y_test values
# Rating
# BBB    363
# BB     284
# A      208
# B      154
# AA      52
# CCC     26
# AAA     24
# C        4
# CC       2
# D        1
# Name: count, dtype: int64
# start of y_pred
# include_previous_rating_model_2_predictions
# BBB    363
# BB     281
# A      202
# B      156
# AA      51
# CCC     31
# AAA     27
# C        4
# CC       2
# D        1
# Name: count, dtype: int64
# custom mapping
# {'AAA': 0, 'AA': 1, 'A': 2, 'BBB': 3, 'BB': 4, 'B': 5, 'CCC': 6, 'CC': 7, 'C': 8, 'D': 9}
# label:  AAA
# label:  AA
# label:  A
# label:  BBB
# label:  BB
# label:  B
# label:  CCC
# label:  CC
# label:  C
# label:  D
# actual labels
# ['AAA', 'AA', 'A', 'BBB', 'BB', 'B', 'CCC', 'CC', 'C', 'D']
# done creating figures and tables for include_previous_rating_model_2
# creating figures and tables for include_previous_rating_model_3
# {'accuracy': 0.9508050089445438, 'f1_score': 0.9510246004251419, 'majority_baseline': 0.32468694096601075}
# Share of predictions exactly as the actual: 95.08%
# Share of predictions 1 or fewer ratings away from actual: 99.46%
# classification report:
#               precision    recall  f1-score   support
#
#            A     0.9604    0.9327    0.9463       208
#           AA     0.9412    0.9231    0.9320        52
#          AAA     0.8519    0.9583    0.9020        24
#            B     0.9359    0.9481    0.9419       154
#           BB     0.9573    0.9472    0.9522       284
#          BBB     0.9669    0.9669    0.9669       363
#            C     1.0000    1.0000    1.0000         4
#           CC     1.0000    1.0000    1.0000         2
#          CCC     0.8065    0.9615    0.8772        26
#            D     1.0000    1.0000    1.0000         1
#
#     accuracy                         0.9508      1118
#    macro avg     0.9420    0.9638    0.9519      1118
# weighted avg     0.9518    0.9508    0.9510      1118
#
# counts of y_test values
# Rating
# BBB    363
# BB     284
# A      208
# B      154
# AA      52
# CCC     26
# AAA     24
# C        4
# CC       2
# D        1
# Name: count, dtype: int64
# start of y_pred
# include_previous_rating_model_3_predictions
# BBB    363
# BB     281
# A      202
# B      156
# AA      51
# CCC     31
# AAA     27
# C        4
# CC       2
# D        1
# Name: count, dtype: int64
# custom mapping
# {'AAA': 0, 'AA': 1, 'A': 2, 'BBB': 3, 'BB': 4, 'B': 5, 'CCC': 6, 'CC': 7, 'C': 8, 'D': 9}
# label:  AAA
# label:  AA
# label:  A
# label:  BBB
# label:  BB
# label:  B
# label:  CCC
# label:  CC
# label:  C
# label:  D
# actual labels
# ['AAA', 'AA', 'A', 'BBB', 'BB', 'B', 'CCC', 'CC', 'C', 'D']
# done creating figures and tables for include_previous_rating_model_3
# creating figures and tables for rating_change_model_1
# {'accuracy': 0.9534883720930233, 'f1_score': 0.9307862679955704, 'majority_baseline': 0.9534883720930233}
# Share of predictions exactly as the actual: 95.35%
# Share of predictions 1 or fewer ratings away from actual: 100.00%
# classification report:
#                                          precision    recall  f1-score   support
#
# Downgrade Since Last Fixed Quarter Date     0.0000    0.0000    0.0000        20
#         Same As Last Fixed Quarter Date     0.9535    1.0000    0.9762      1066
#   Upgrade Since Last Fixed Quarter Date     0.0000    0.0000    0.0000        32
#
#                                accuracy                         0.9535      1118
#                               macro avg     0.3178    0.3333    0.3254      1118
#                            weighted avg     0.9091    0.9535    0.9308      1118
#
# counts of y_test values
# Change Direction Since Last Fixed Quarter Date
# Same As Last Fixed Quarter Date            1066
# Upgrade Since Last Fixed Quarter Date        32
# Downgrade Since Last Fixed Quarter Date      20
# Name: count, dtype: int64
# start of y_pred
# rating_change_model_1_predictions
# Same As Last Fixed Quarter Date    1118
# Name: count, dtype: int64
# custom mapping
# {'Downgrade Since Last Fixed Quarter Date': -1, 'Same As Last Fixed Quarter Date': 0, 'Upgrade Since Last Fixed Quarter Date': 1}
# label:  Downgrade Since Last Fixed Quarter Date
# label:  Same As Last Fixed Quarter Date
# label:  Upgrade Since Last Fixed Quarter Date
# actual labels
# ['Downgrade', 'Same', 'Upgrade']
# done creating figures and tables for rating_change_model_1
# creating figures and tables for rating_change_model_2
# {'accuracy': 0.028622540250447227, 'f1_score': 0.0015929065878509763, 'majority_baseline': 0.9534883720930233}
# Share of predictions exactly as the actual: 2.86%
# Share of predictions 1 or fewer ratings away from actual: 98.21%
# classification report:
#                                          precision    recall  f1-score   support
#
# Downgrade Since Last Fixed Quarter Date     0.0000    0.0000    0.0000        20
#         Same As Last Fixed Quarter Date     0.0000    0.0000    0.0000      1066
#   Upgrade Since Last Fixed Quarter Date     0.0286    1.0000    0.0557        32
#
#                                accuracy                         0.0286      1118
#                               macro avg     0.0095    0.3333    0.0186      1118
#                            weighted avg     0.0008    0.0286    0.0016      1118
#
# counts of y_test values
# Change Direction Since Last Fixed Quarter Date
# Same As Last Fixed Quarter Date            1066
# Upgrade Since Last Fixed Quarter Date        32
# Downgrade Since Last Fixed Quarter Date      20
# Name: count, dtype: int64
# start of y_pred
# rating_change_model_2_predictions
# Upgrade Since Last Fixed Quarter Date    1118
# Name: count, dtype: int64
# custom mapping
# {'Downgrade Since Last Fixed Quarter Date': -1, 'Same As Last Fixed Quarter Date': 0, 'Upgrade Since Last Fixed Quarter Date': 1}
# label:  Downgrade Since Last Fixed Quarter Date
# label:  Same As Last Fixed Quarter Date
# label:  Upgrade Since Last Fixed Quarter Date
# actual labels
# ['Downgrade', 'Same', 'Upgrade']
# done creating figures and tables for rating_change_model_2
# creating figures and tables for rating_change_model_3
# {'accuracy': 0.5983899821109123, 'f1_score': 0.7188678349088323, 'majority_baseline': 0.9534883720930233}
# Share of predictions exactly as the actual: 59.84%
# Share of predictions 1 or fewer ratings away from actual: 98.84%
# classification report:
#                                          precision    recall  f1-score   support
#
# Downgrade Since Last Fixed Quarter Date     0.0102    0.1000    0.0185        20
#         Same As Last Fixed Quarter Date     0.9500    0.6238    0.7531      1066
#   Upgrade Since Last Fixed Quarter Date     0.0090    0.0625    0.0157        32
#
#                                accuracy                         0.5984      1118
#                               macro avg     0.3231    0.2621    0.2625      1118
#                            weighted avg     0.9063    0.5984    0.7189      1118
#
# counts of y_test values
# Change Direction Since Last Fixed Quarter Date
# Same As Last Fixed Quarter Date            1066
# Upgrade Since Last Fixed Quarter Date        32
# Downgrade Since Last Fixed Quarter Date      20
# Name: count, dtype: int64
# start of y_pred
# rating_change_model_3_predictions
# Same As Last Fixed Quarter Date            700
# Upgrade Since Last Fixed Quarter Date      222
# Downgrade Since Last Fixed Quarter Date    196
# Name: count, dtype: int64
# custom mapping
# {'Downgrade Since Last Fixed Quarter Date': -1, 'Same As Last Fixed Quarter Date': 0, 'Upgrade Since Last Fixed Quarter Date': 1}
# label:  Downgrade Since Last Fixed Quarter Date
# label:  Same As Last Fixed Quarter Date
# label:  Upgrade Since Last Fixed Quarter Date
# actual labels
# ['Downgrade', 'Same', 'Upgrade']
# done creating figures and tables for rating_change_model_3
# creating figures and tables for smote_rating_change_model_1
# {'accuracy': 0.5742397137745975, 'f1_score': 0.696123819338718, 'majority_baseline': 0.9534883720930233}
# Share of predictions exactly as the actual: 57.42%
# Share of predictions 1 or fewer ratings away from actual: 99.46%
# classification report:
#                                          precision    recall  f1-score   support
#
# Downgrade Since Last Fixed Quarter Date     0.0314    0.2500    0.0559        20
#         Same As Last Fixed Quarter Date     0.9543    0.5872    0.7271      1066
#   Upgrade Since Last Fixed Quarter Date     0.0363    0.3438    0.0657        32
#
#                                accuracy                         0.5742      1118
#                               macro avg     0.3407    0.3937    0.2829      1118
#                            weighted avg     0.9115    0.5742    0.6961      1118
#
# counts of y_test values
# Change Direction Since Last Fixed Quarter Date
# Same As Last Fixed Quarter Date            1066
# Upgrade Since Last Fixed Quarter Date        32
# Downgrade Since Last Fixed Quarter Date      20
# Name: count, dtype: int64
# start of y_pred
# smote_rating_change_model_1_predictions
# Same As Last Fixed Quarter Date            656
# Upgrade Since Last Fixed Quarter Date      303
# Downgrade Since Last Fixed Quarter Date    159
# Name: count, dtype: int64
# custom mapping
# {'Downgrade Since Last Fixed Quarter Date': -1, 'Same As Last Fixed Quarter Date': 0, 'Upgrade Since Last Fixed Quarter Date': 1}
# label:  Downgrade Since Last Fixed Quarter Date
# label:  Same As Last Fixed Quarter Date
# label:  Upgrade Since Last Fixed Quarter Date
# actual labels
# ['Downgrade', 'Same', 'Upgrade']
# done creating figures and tables for smote_rating_change_model_1
# creating figures and tables for smote_rating_change_model_2
# {'accuracy': 0.7003577817531306, 'f1_score': 0.7894981767964323, 'majority_baseline': 0.9534883720930233}
# Share of predictions exactly as the actual: 70.04%
# Share of predictions 1 or fewer ratings away from actual: 99.19%
# classification report:
#                                          precision    recall  f1-score   support
#
# Downgrade Since Last Fixed Quarter Date     0.0072    0.0500    0.0127        20
#         Same As Last Fixed Quarter Date     0.9512    0.7317    0.8271      1066
#   Upgrade Since Last Fixed Quarter Date     0.0125    0.0625    0.0208        32
#
#                                accuracy                         0.7004      1118
#                               macro avg     0.3237    0.2814    0.2869      1118
#                            weighted avg     0.9075    0.7004    0.7895      1118
#
# counts of y_test values
# Change Direction Since Last Fixed Quarter Date
# Same As Last Fixed Quarter Date            1066
# Upgrade Since Last Fixed Quarter Date        32
# Downgrade Since Last Fixed Quarter Date      20
# Name: count, dtype: int64
# start of y_pred
# smote_rating_change_model_2_predictions
# Same As Last Fixed Quarter Date            820
# Upgrade Since Last Fixed Quarter Date      160
# Downgrade Since Last Fixed Quarter Date    138
# Name: count, dtype: int64
# custom mapping
# {'Downgrade Since Last Fixed Quarter Date': -1, 'Same As Last Fixed Quarter Date': 0, 'Upgrade Since Last Fixed Quarter Date': 1}
# label:  Downgrade Since Last Fixed Quarter Date
# label:  Same As Last Fixed Quarter Date
# label:  Upgrade Since Last Fixed Quarter Date
# actual labels
# ['Downgrade', 'Same', 'Upgrade']
# done creating figures and tables for smote_rating_change_model_2
# creating figures and tables for smote_rating_change_model_3
# {'accuracy': 0.7164579606440071, 'f1_score': 0.8016944597891343, 'majority_baseline': 0.9534883720930233}
# Share of predictions exactly as the actual: 71.65%
# Share of predictions 1 or fewer ratings away from actual: 98.93%
# classification report:
#                                          precision    recall  f1-score   support
#
# Downgrade Since Last Fixed Quarter Date     0.0156    0.1000    0.0270        20
#         Same As Last Fixed Quarter Date     0.9590    0.7458    0.8391      1066
#   Upgrade Since Last Fixed Quarter Date     0.0248    0.1250    0.0415        32
#
#                                accuracy                         0.7165      1118
#                               macro avg     0.3332    0.3236    0.3025      1118
#                            weighted avg     0.9154    0.7165    0.8017      1118
#
# counts of y_test values
# Change Direction Since Last Fixed Quarter Date
# Same As Last Fixed Quarter Date            1066
# Upgrade Since Last Fixed Quarter Date        32
# Downgrade Since Last Fixed Quarter Date      20
# Name: count, dtype: int64
# start of y_pred
# smote_rating_change_model_3_predictions
# Same As Last Fixed Quarter Date            829
# Upgrade Since Last Fixed Quarter Date      161
# Downgrade Since Last Fixed Quarter Date    128
# Name: count, dtype: int64
# custom mapping
# {'Downgrade Since Last Fixed Quarter Date': -1, 'Same As Last Fixed Quarter Date': 0, 'Upgrade Since Last Fixed Quarter Date': 1}
# label:  Downgrade Since Last Fixed Quarter Date
# label:  Same As Last Fixed Quarter Date
# label:  Upgrade Since Last Fixed Quarter Date
# actual labels
# ['Downgrade', 'Same', 'Upgrade']
# done creating figures and tables for smote_rating_change_model_3
