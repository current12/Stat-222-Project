# %% [markdown]
# # Create Figures and Table Components

# %%
# Packages
import sys
import os
# Add the parent directory to sys.path
sys.path.append(os.path.abspath('..'))
# Import module
from Logistic_Regression_Functions import *

# %% [markdown]
# ## Set Classifier Name and Models to iterate over

# %%
include_exclude_previous = ['exclude_previous_', 'include_previous_']
model_names = ['rating_model_1', 'rating_model_2', 'rating_model_3']

# %% [markdown]
# ## Iterate Over Full Model Names and Create Figures and Tables

# %%
full_model_names = []
for include_exclude in include_exclude_previous:
    for model_name in model_names:
        full_model_names.append(include_exclude + model_name)

# %%
for full_model_name in full_model_names:
    # Get the column names and mapping
    _, _, target_column, custom_mapping = get_column_names_and_mapping(full_model_name)
    print('creating figures and tables for ' + full_model_name)
    create_model_figure_and_table_components(full_model_name, target_column, custom_mapping)
    print('done creating figures and tables for ' + full_model_name)
# Out:
# creating figures and tables for exclude_previous_rating_model_1
# {'accuracy': 0.3507326007326007, 'f1_score': 0.2751027580283354, 'majority_baseline': 0.30128205128205127}
# Share of predictions exactly as the actual: 35.07%
# Share of predictions 1 or fewer ratings away from actual: 80.22%
# classification report:
#               precision    recall  f1-score   support
#
#            A     0.0000    0.0000    0.0000       214
#           AA     0.0000    0.0000    0.0000        42
#          AAA     0.0000    0.0000    0.0000        27
#            B     0.3793    0.2391    0.2933       138
#           BB     0.3133    0.3490    0.3302       298
#          BBB     0.3655    0.7477    0.4910       329
#            C     0.0000    0.0000    0.0000         7
#          CCC     0.0000    0.0000    0.0000        34
#            D     0.0000    0.0000    0.0000         3
#
#     accuracy                         0.3507      1092
#    macro avg     0.1176    0.1484    0.1238      1092
# weighted avg     0.2435    0.3507    0.2751      1092
# done creating figures and tables for exclude_previous_rating_model_1
# creating figures and tables for exclude_previous_rating_model_2
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[4], line 5
#       3 _, _, target_column, custom_mapping = get_column_names_and_mapping(full_model_name)
#       4 print('creating figures and tables for ' + full_model_name)
# ----> 5 create_model_figure_and_table_components(full_model_name, target_column, custom_mapping)
#       6 print('done creating figures and tables for ' + full_model_name)
#
# File c:\Users\ijyli\repo\Stat-222-Project\Code\Modelling\Logistic Regression\Logistic_Regression_Functions.py:226, in create_model_figure_and_table_components(model_name, target_column, custom_mapping)
#     218 """
#     219 Create model figure and table components to be used.
#     220
#     221 Parameters:
#     222 - model_name: name of the model - informs folder and file paths of loaded predictions
#     223 """
#     225 # Load file of predictions
# --> 226 predictions_df = pd.read_excel('../../../../Data/Predictions/Logistic Regression/' + model_name + '/' + model_name + '_predictions.xlsx')
#     228 # Create y_test and y_pred
#     229 y_test = predictions_df[target_column]
#
# File c:\Users\ijyli\miniforge3\envs\capstone\Lib\site-packages\pandas\io\excel\_base.py:504, in read_excel(io, sheet_name, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skiprows, nrows, na_values, keep_default_na, na_filter, verbose, parse_dates, date_parser, date_format, thousands, decimal, comment, skipfooter, storage_options, dtype_backend, engine_kwargs)
#     502 if not isinstance(io, ExcelFile):
#     503     should_close = True
# --> 504     io = ExcelFile(
#     505         io,
#     506         storage_options=storage_options,
#     507         engine=engine,
#     508         engine_kwargs=engine_kwargs,
#     509     )
#     510 elif engine and engine != io.engine:
#     511     raise ValueError(
#     512         "Engine should not be specified when passing "
#     513         "an ExcelFile - ExcelFile already has the engine set"
#     514     )
#
# File c:\Users\ijyli\miniforge3\envs\capstone\Lib\site-packages\pandas\io\excel\_base.py:1563, in ExcelFile.__init__(self, path_or_buffer, engine, storage_options, engine_kwargs)
#    1561     ext = "xls"
#    1562 else:
# -> 1563     ext = inspect_excel_format(
#    1564         content_or_path=path_or_buffer, storage_options=storage_options
#    1565     )
#    1566     if ext is None:
#    1567         raise ValueError(
#    1568             "Excel file format cannot be determined, you must specify "
#    1569             "an engine manually."
#    1570         )
#
# File c:\Users\ijyli\miniforge3\envs\capstone\Lib\site-packages\pandas\io\excel\_base.py:1419, in inspect_excel_format(content_or_path, storage_options)
#    1416 if isinstance(content_or_path, bytes):
#    1417     content_or_path = BytesIO(content_or_path)
# -> 1419 with get_handle(
#    1420     content_or_path, "rb", storage_options=storage_options, is_text=False
#    1421 ) as handle:
#    1422     stream = handle.handle
#    1423     stream.seek(0)
#
# File c:\Users\ijyli\miniforge3\envs\capstone\Lib\site-packages\pandas\io\common.py:872, in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors, storage_options)
#     863         handle = open(
#     864             handle,
#     865             ioargs.mode,
#    (...)
#     868             newline="",
#     869         )
#     870     else:
#     871         # Binary mode
# --> 872         handle = open(handle, ioargs.mode)
#     873     handles.append(handle)
#     875 # Convert BytesIO or file objects passed with an encoding
#
# FileNotFoundError: [Errno 2] No such file or directory: '../../../../Data/Predictions/Logistic Regression/exclude_previous_rating_model_2/exclude_previous_rating_model_2_predictions.xlsx'
