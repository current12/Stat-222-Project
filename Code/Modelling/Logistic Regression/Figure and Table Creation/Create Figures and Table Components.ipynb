# %% [markdown]
# # Create Figures and Table Components

# %%
# Packages
import sys
import os
# Add the parent directory to sys.path
sys.path.append(os.path.abspath('..'))
# Import module
from Logistic_Regression_Functions import *

# %% [markdown]
# ## Set Classifier Name and Models to iterate over

# %%
include_exclude_previous = ['exclude_previous_', 'include_previous_']
model_names = ['rating_model_1', 'rating_model_2', 'rating_model_3']

# %% [markdown]
# ## Iterate Over Full Model Names and Create Figures and Tables

# %%
full_model_names = []
for include_exclude in include_exclude_previous:
    for model_name in model_names:
        full_model_names.append(include_exclude + model_name)

# %%
for full_model_name in full_model_names:
    # Get the column names and mapping
    _, _, target_column, custom_mapping = get_column_names_and_mapping(full_model_name)
    print('creating figures and tables for ' + full_model_name)
    create_model_figure_and_table_components(full_model_name, target_column, custom_mapping)
    print('done creating figures and tables for ' + full_model_name)
# Out:
# creating figures and tables for exclude_previous_rating_model_1
# {'accuracy': 0.3507326007326007, 'f1_score': 0.2751027580283354, 'majority_baseline': 0.30128205128205127}
# Share of predictions exactly as the actual: 35.07%
# Share of predictions 1 or fewer ratings away from actual: 80.22%
# classification report:
#               precision    recall  f1-score   support
#
#            A     0.0000    0.0000    0.0000       214
#           AA     0.0000    0.0000    0.0000        42
#          AAA     0.0000    0.0000    0.0000        27
#            B     0.3793    0.2391    0.2933       138
#           BB     0.3133    0.3490    0.3302       298
#          BBB     0.3655    0.7477    0.4910       329
#            C     0.0000    0.0000    0.0000         7
#          CCC     0.0000    0.0000    0.0000        34
#            D     0.0000    0.0000    0.0000         3
#
#     accuracy                         0.3507      1092
#    macro avg     0.1176    0.1484    0.1238      1092
# weighted avg     0.2435    0.3507    0.2751      1092
# done creating figures and tables for exclude_previous_rating_model_1
# creating figures and tables for exclude_previous_rating_model_2
# {'accuracy': 0.6483516483516484, 'f1_score': 0.6456786969310612, 'majority_baseline': 0.30128205128205127}
# Share of predictions exactly as the actual: 64.84%
# Share of predictions 1 or fewer ratings away from actual: 94.32%
# classification report:
#               precision    recall  f1-score   support
#
#            A     0.6667    0.6075    0.6357       214
#           AA     0.4412    0.3571    0.3947        42
#          AAA     0.7727    0.6296    0.6939        27
#            B     0.5912    0.5870    0.5891       138
#           BB     0.6398    0.6913    0.6645       298
#          BBB     0.6733    0.7204    0.6960       329
#            C     0.8000    0.5714    0.6667         7
#          CCC     0.7200    0.5294    0.6102        34
#            D     0.0000    0.0000    0.0000         3
#
#     accuracy                         0.6484      1092
#    macro avg     0.5894    0.5215    0.5501      1092
# weighted avg     0.6464    0.6484    0.6457      1092
# done creating figures and tables for exclude_previous_rating_model_2
# creating figures and tables for exclude_previous_rating_model_3
# {'accuracy': 0.6556776556776557, 'f1_score': 0.6536904275701935, 'majority_baseline': 0.30128205128205127}
# Share of predictions exactly as the actual: 65.57%
# Share of predictions 1 or fewer ratings away from actual: 94.60%
# classification report:
#               precision    recall  f1-score   support
#
#            A     0.6793    0.5841    0.6281       214
#           AA     0.5882    0.4762    0.5263        42
#          AAA     0.7917    0.7037    0.7451        27
#            B     0.5822    0.6159    0.5986       138
#           BB     0.6399    0.6678    0.6535       298
#          BBB     0.6759    0.7416    0.7072       329
#            C     0.7778    1.0000    0.8750         7
#           CC     0.0000    0.0000    0.0000         0
#          CCC     0.8095    0.5000    0.6182        34
#            D     0.0000    0.0000    0.0000         3
#
#     accuracy                         0.6557      1092
#    macro avg     0.5545    0.5289    0.5352      1092
# weighted avg     0.6573    0.6557    0.6537      1092
# done creating figures and tables for exclude_previous_rating_model_3
# creating figures and tables for include_previous_rating_model_1
# {'accuracy': 0.9496336996336996, 'f1_score': 0.9493868457798927, 'majority_baseline': 0.30128205128205127}
# Share of predictions exactly as the actual: 94.96%
# Share of predictions 1 or fewer ratings away from actual: 99.54%
# classification report:
#               precision    recall  f1-score   support
#
#            A     0.9245    0.9159    0.9202       214
#           AA     0.8947    0.8095    0.8500        42
#          AAA     0.9259    0.9259    0.9259        27
#            B     0.9362    0.9565    0.9462       138
#           BB     0.9701    0.9799    0.9750       298
#          BBB     0.9548    0.9635    0.9592       329
#            C     1.0000    1.0000    1.0000         7
#          CCC     1.0000    0.9118    0.9538        34
#            D     1.0000    1.0000    1.0000         3
#
#     accuracy                         0.9496      1092
#    macro avg     0.9563    0.9403    0.9478      1092
# weighted avg     0.9495    0.9496    0.9494      1092
# done creating figures and tables for include_previous_rating_model_1
# creating figures and tables for include_previous_rating_model_2
# {'accuracy': 0.9468864468864469, 'f1_score': 0.9474701158720303, 'majority_baseline': 0.30128205128205127}
# Share of predictions exactly as the actual: 94.69%
# Share of predictions 1 or fewer ratings away from actual: 99.27%
# classification report:
#               precision    recall  f1-score   support
#
#            A     0.9242    0.9112    0.9176       214
#           AA     0.8947    0.8095    0.8500        42
#          AAA     0.9231    0.8889    0.9057        27
#            B     0.9362    0.9565    0.9462       138
#           BB     0.9700    0.9765    0.9732       298
#          BBB     0.9548    0.9635    0.9592       329
#            C     1.0000    1.0000    1.0000         7
#           CC     0.0000    0.0000    0.0000         0
#          CCC     0.9688    0.9118    0.9394        34
#            D     1.0000    1.0000    1.0000         3
#
#     accuracy                         0.9469      1092
#    macro avg     0.8572    0.8418    0.8491      1092
# weighted avg     0.9484    0.9469    0.9475      1092
# done creating figures and tables for include_previous_rating_model_2
# creating figures and tables for include_previous_rating_model_3
# {'accuracy': 0.9478021978021978, 'f1_score': 0.9479378876224862, 'majority_baseline': 0.30128205128205127}
# Share of predictions exactly as the actual: 94.78%
# Share of predictions 1 or fewer ratings away from actual: 99.36%
# classification report:
#               precision    recall  f1-score   support
#
#            A     0.9242    0.9112    0.9176       214
#           AA     0.8947    0.8095    0.8500        42
#          AAA     0.9231    0.8889    0.9057        27
#            B     0.9362    0.9565    0.9462       138
#           BB     0.9701    0.9799    0.9750       298
#          BBB     0.9548    0.9635    0.9592       329
#            C     1.0000    1.0000    1.0000         7
#           CC     0.0000    0.0000    0.0000         0
#          CCC     0.9688    0.9118    0.9394        34
#            D     1.0000    1.0000    1.0000         3
#
#     accuracy                         0.9478      1092
#    macro avg     0.8572    0.8421    0.8493      1092
# weighted avg     0.9484    0.9478    0.9479      1092
# done creating figures and tables for include_previous_rating_model_3
