# %% [markdown]
# # Symbol and Earnings Call Sector
#
# Create dataset of symbol and earnings call sector

# %%
# packages
import pandas as pd

# %%
calls = pd.read_csv(r'~\Box\STAT 222 Capstone\Intermediate Data\calls.csv')
calls
# Out:
#        Unnamed: 0 company       sector  year  quarter                 date  \
# 0               0    ADNT  automobiles  2017        2  2017-04-28 17:00:00
# 1               1    ADNT  automobiles  2017        3  2017-07-27 17:00:00
# 2               2    ADNT  automobiles  2017        4  2017-11-05 17:00:00
# 3               3    ADNT  automobiles  2018        1  2018-01-29 17:00:00
# 4               4    ADNT  automobiles  2018        2  2018-05-03 17:00:00
# ...           ...     ...          ...   ...      ...                  ...
# 62069       62069     KMX       retail  2022        3  2021-12-22 12:47:07
# 62070       62070     KMX       retail  2022        4  2022-04-12 14:05:22
# 62071       62071     KMX       retail  2023        1  2022-06-24 13:23:08
# 62072       62072     KMX       retail  2023        2  2022-09-29 12:55:26
# 62073       62073     KSS       retail  2007        3  2007-08-17 17:00:00
#
#                                               transcript
# ...

# %%
# Limit to columns company and sector and drop duplicates
ec_sectors = calls[['company', 'sector']].drop_duplicates()
ec_sectors
# Out:
#       company       sector
# 0        ADNT  automobiles
# 23        ALV  automobiles
# 68       APTV  automobiles
# 84       ARVL  automobiles
# 91        AXL  automobiles
# ...       ...          ...
# 61925    JMIA       retail
# 61937    JOAN       retail
# 61943     JWN       retail
# 62010     KMX       retail
# 62073     KSS       retail
#
# [1831 rows x 2 columns]

# %%
# Output to csv
# '~\Box\STAT 222 Capstone\Intermediate Data\earnings_call_company_sectors.csv'
ec_sectors.to_csv(r'~\Box\STAT 222 Capstone\Intermediate Data\earnings_call_company_sectors.csv', index = False)
