# %% [markdown]
# # Combine Credit Rating Data
#
# Original data source: https://www.kaggle.com/datasets/agewerc/corporate-credit-rating
#
# Supplementary data source: https://www.kaggle.com/datasets/kirtandelwadia/corporate-credit-rating-with-financial-ratios

# %%
# Packages
import pandas as pd
import matplotlib.pyplot as plt

# %%
# Load original data into pandas
# ~\..\Box\STAT 222 Capstone\Raw Data\Credit Rating Data From Kaggle\corporate_rating.csv
corporate_rating = pd.read_csv('~\Box\STAT 222 Capstone\Raw Data\Credit Rating Data From Kaggle\corporate_rating.csv')
corporate_rating
# Out:
# <>:3: SyntaxWarning: invalid escape sequence '\B'
# <>:3: SyntaxWarning: invalid escape sequence '\B'
# C:\Users\ijyli\AppData\Local\Temp\ipykernel_7780\1870754754.py:3: SyntaxWarning: invalid escape sequence '\B'
#   corporate_rating = pd.read_csv('~\Box\STAT 222 Capstone\Raw Data\Credit Rating Data From Kaggle\corporate_rating.csv')
#      Rating                         Name Symbol  \
# 0         A        Whirlpool Corporation    WHR
# 1       BBB        Whirlpool Corporation    WHR
# 2       BBB        Whirlpool Corporation    WHR
# 3       BBB        Whirlpool Corporation    WHR
# 4       BBB        Whirlpool Corporation    WHR
# ...     ...                          ...    ...
# 2024    BBB                    NVR, Inc.    NVR
# 2025     BB  Kaiser Aluminum Corporation   KALU
# 2026      B       Cresud S.A.C.I.F. y A.  CRESY
# 2027      B       Cresud S.A.C.I.F. y A.  CRESY
# 2028    CCC       Cresud S.A.C.I.F. y A.  CRESY
#
#                       Rating Agency Name        Date             Sector  \
# 0             Egan-Jones Ratings Company  11/27/2015  Consumer Durables
# 1             Egan-Jones Ratings Company   2/13/2014  Consumer Durables
# 2                          Fitch Ratings    3/6/2015  Consumer Durables
# 3                          Fitch Ratings   6/15/2012  Consumer Durables
# 4     Standard & Poor's Ratings Services  10/24/2016  Consumer Durables
# ...                                  ...         ...                ...
# 2024           Moody's Investors Service    9/5/2012      Capital Goods
# 2025  Standard & Poor's Ratings Services   4/28/2016      Capital Goods
# 2026                       Fitch Ratings  11/30/2012            Finance
# 2027                       Fitch Ratings   6/15/2012            Finance
# 2028                       Fitch Ratings    8/1/2014            Finance
#
#       currentRatio  quickRatio  cashRatio  daysOfSalesOutstanding  ...  \
# 0         0.945894    0.426395   0.099690               44.203245  ...
# 1         1.033559    0.498234   0.203120               38.991156  ...
# 2         0.963703    0.451505   0.122099               50.841385  ...
# 3         1.019851    0.510402   0.176116               41.161738  ...
# 4         0.957844    0.495432   0.141608               47.761126  ...
# ...            ...         ...        ...                     ...  ...
# 2024     11.757767    7.115059   7.057420                1.079762  ...
# 2025      2.962788    1.294743   0.428234               30.602414  ...
# 2026      0.883875    0.842553   0.233830              147.599371  ...
# 2027      0.911713    0.748356   0.310640              131.644566  ...
# 2028      1.085007    1.026375   0.203490              151.660513  ...
#
#       effectiveTaxRate  freeCashFlowOperatingCashFlowRatio  \
# 0             0.202716                            0.437551
# 1             0.074155                            0.541997
# 2             0.214529                            0.513185
# 3             1.816667                           -0.147170
# 4             0.166966                            0.451372
# ...                ...                                 ...
# 2024          0.343500                            0.953231
# 2025          0.363636                            0.602645
# 2026         35.017544                            0.926665
# 2027          0.331525                            0.692804
# 2028          0.266987                            1.101462
#
#       freeCashFlowPerShare  cashPerShare  companyEquityMultiplier  \
# 0                 6.810673      9.809403                 4.008012
# 1                 8.625473     17.402270                 3.156783
# 2                 9.693487     13.103448                 4.094575
# 3                -1.015625     14.440104                 3.630950
# 4                 7.135348     14.257556                 4.012780
# ...                    ...           ...                      ...
# 2024             50.293155    230.194971                 1.759461
# 2025              5.563630      5.958956                 1.614282
# 2026              1.459801      1.056480                 4.034952
# 2027              0.744377      1.470201                 3.825856
# 2028              2.487817      6.109814                 3.939161
#
#       ebitPerRevenue  enterpriseValueMultiple  operatingCashFlowPerShare  \
# 0           0.049351                 7.057088                  15.565438
# 1           0.048857                 6.460618                  15.914250
# 2           0.044334                10.491970                  18.888889
# 3          -0.012858                 4.080741                   6.901042
# 4           0.053770                 8.293505                  15.808147
# ...              ...                      ...                        ...
# 2024        0.086376                15.867701                  52.760726
# 2025       -0.267117                -4.729967                   9.232021
# 2026        0.265092                 9.358311                   1.575328
# 2027        0.130692                22.440102                   1.074441
# 2028        0.302997                 9.604061                   2.258650
#
#       operatingCashFlowSalesRatio  payablesTurnover
# 0                        0.058638          3.906655
# 1                        0.067239          4.002846
# 2                        0.074426          3.483510
# 3                        0.028394          4.581150
# 4                        0.058065          3.857790
# ...                           ...               ...
# 2024                     0.083018         15.758348
# 2025                     0.114089         14.542373
# 2026                     0.283634          2.300168
# 2027                     0.217783          1.997608
# 2028                     0.252606          1.865682
#
# [2029 rows x 31 columns]

# %%
# Load supplementary data
# C:\Users\ijyli\Box\STAT 222 Capstone\Raw Data\Supplementary Credit Rating Data From Kaggle\corporateCreditRatingWithFinancialRatios.csv
supplementary_data = pd.read_csv('~\Box\STAT 222 Capstone\Raw Data\Supplementary Credit Rating Data From Kaggle\corporateCreditRatingWithFinancialRatios.csv')
supplementary_data
# Out:
# <>:3: SyntaxWarning: invalid escape sequence '\B'
# <>:3: SyntaxWarning: invalid escape sequence '\B'
# C:\Users\ijyli\AppData\Local\Temp\ipykernel_7780\1998800122.py:3: SyntaxWarning: invalid escape sequence '\B'
#   supplementary_data = pd.read_csv('~\Box\STAT 222 Capstone\Raw Data\Supplementary Credit Rating Data From Kaggle\corporateCreditRatingWithFinancialRatios.csv')
#                            Rating Agency                     Corporation  \
# 0     Standard & Poor's Ratings Services       American States Water Co.
# 1     Standard & Poor's Ratings Services  Automatic Data Processing Inc.
# 2     Standard & Poor's Ratings Services                      Avnet Inc.
# 3     Standard & Poor's Ratings Services    California Water Service Co.
# 4     Standard & Poor's Ratings Services            Cardinal Health Inc.
# ...                                  ...                             ...
# 7800           Moody's Investors Service                      eBay, Inc.
# 7801           Moody's Investors Service                      eBay, Inc.
# 7802  Standard & Poor's Ratings Services       iHeartCommunications Inc.
# 7803  Standard & Poor's Ratings Services       iHeartCommunications Inc.
# 7804  Standard & Poor's Ratings Services       iHeartCommunications Inc.
#
#      Rating Rating Date      CIK  Binary Rating  SIC Code Sector Ticker  \
# 0        A-  2010-07-30  1056903              1    4941.0  Utils    AWR
# 1       AAA  2010-09-16     8670              1    7374.0  BusEq    ADP
# 2      BBB-  2010-11-23     8858              1    5065.0  Shops    AVT
# 3       AA-  2010-06-29  1035201              1    4941.0  Utils    CWT
# 4         A  2010-07-14   721371              1    5122.0  Shops    CAH
# ...     ...         ...      ...            ...       ...    ...    ...
# 7800   BBB+  2016-02-22  1065088              1    7370.0  BusEq   EBAY
# 7801   BBB+  2016-03-02  1065088              1    7370.0  BusEq   EBAY
# 7802     CC  2016-03-08   739708              0    4832.0  Telcm    CCU
# 7803    CCC  2016-03-24   739708              0    4832.0  Telcm    CCU
# 7804     CC  2016-06-14   739708              0    4832.0  Telcm    CCU
#
#       Current Ratio  ...  EBITDA Margin  Pre-Tax Profit Margin  \
# 0            1.1507  ...        28.9834                13.6093
# 1            1.1129  ...        23.9379                20.8699
# 2            1.9276  ...         3.6338                 3.0536
# 3            0.8358  ...        27.9377                15.1135
# 4            1.2931  ...         1.5847                 1.2304
# ...             ...  ...            ...                    ...
# 7800         3.4927  ...        33.5661                28.0028
# 7801         3.4927  ...        33.5661                28.0028
# 7802         1.7606  ...        14.2454                12.7232
# 7803         1.7606  ...        14.2454                12.7232
# 7804         1.7606  ...        14.2454                12.7232
#
#       Net Profit Margin  Asset Turnover  ROE - Return On Equity  \
# 0                8.3224          0.3173                  8.1724
# 1               13.5690          0.3324                 22.0354
# 2                2.1418          2.4620                 13.6376
# 3                9.0246          0.2946                  9.6412
# 4                0.6518          4.9276                 11.1256
# ...                 ...             ...                     ...
# 7800            20.0768          0.4839                 29.6077
# 7801            20.0768          0.4839                 29.6077
# 7802             8.0626          0.8218                 11.8335
# 7803             8.0626          0.8218                 11.8335
# 7804             8.0626          0.8218                 11.8335
#
#       Return On Tangible Equity  ROA - Return On Assets  \
# 0                        8.1978                  2.6385
# 1                       47.2858                  4.4944
# 2                       16.7991                  5.2731
# 3                        9.7015                  2.6583
# 4                       19.4184                  2.9364
# ...                         ...                     ...
# 7800                    95.6757                 10.9659
# 7801                    95.6757                 10.9659
# 7802                    13.5108                  7.7070
# 7803                    13.5108                  7.7070
# 7804                    13.5108                  7.7070
#
#       ROI - Return On Investment  Operating Cash Flow Per Share  \
# 0                         4.4530                         1.9957
# 1                        21.8765                         0.2501
# 2                         9.6494                        -7.6079
# 3                         5.1018                         1.7438
# 4                         8.1844                         1.9725
# ...                          ...                            ...
# 7800                     14.6116                        -1.2323
# 7801                     14.6116                        -1.2323
# 7802                     10.6101                         0.0907
# 7803                     10.6101                         0.0907
# 7804                     10.6101                         0.0907
#
#       Free Cash Flow Per Share
# 0                      -0.1333
# 1                       0.3132
# 2                      -7.3231
# 3                      -0.8999
# 4                       2.4174
# ...                        ...
# 7800                   -1.2826
# 7801                   -1.2826
# 7802                    1.2552
# 7803                    1.2552
# 7804                    1.2552
#
# [7805 rows x 25 columns]

# %%
# All columns
print(corporate_rating.columns)
print(supplementary_data.columns)
# Out:
# Index(['Rating', 'Name', 'Symbol', 'Rating Agency Name', 'Date', 'Sector',
#        'currentRatio', 'quickRatio', 'cashRatio', 'daysOfSalesOutstanding',
#        'netProfitMargin', 'pretaxProfitMargin', 'grossProfitMargin',
#        'operatingProfitMargin', 'returnOnAssets', 'returnOnCapitalEmployed',
#        'returnOnEquity', 'assetTurnover', 'fixedAssetTurnover',
#        'debtEquityRatio', 'debtRatio', 'effectiveTaxRate',
#        'freeCashFlowOperatingCashFlowRatio', 'freeCashFlowPerShare',
#        'cashPerShare', 'companyEquityMultiplier', 'ebitPerRevenue',
#        'enterpriseValueMultiple', 'operatingCashFlowPerShare',
#        'operatingCashFlowSalesRatio', 'payablesTurnover'],
#       dtype='object')
# Index(['Rating Agency', 'Corporation', 'Rating', 'Rating Date', 'CIK',
#        'Binary Rating', 'SIC Code', 'Sector', 'Ticker', 'Current Ratio',
#        'Long-term Debt / Capital', 'Debt/Equity Ratio', 'Gross Margin',
#        'Operating Margin', 'EBIT Margin', 'EBITDA Margin',
#        'Pre-Tax Profit Margin', 'Net Profit Margin', 'Asset Turnover',
#        'ROE - Return On Equity', 'Return On Tangible Equity',
#        'ROA - Return On Assets', 'ROI - Return On Investment',
#        'Operating Cash Flow Per Share', 'Free Cash Flow Per Share'],
#       dtype='object')

# %%
# In original data, limit to Rating, Name, Symbol, Rating Agency Name, Date, Sector
corporate_rating = corporate_rating[['Rating', 'Name', 'Symbol', 'Rating Agency Name', 'Date', 'Sector']]
# Create Source column as 'Original'
corporate_rating['Source'] = 'Original'
# Convert Date to date format
corporate_rating['Date'] = pd.to_datetime(corporate_rating['Date'])
# In supplementary data, limit to Rating Agency, Corporation, Rating, Rating Date, Sector, Ticker
supplementary_data = supplementary_data[['Rating Agency', 'Corporation', 'Rating', 'Rating Date', 'Sector', 'Ticker']]
# Convert Rating Date to date format
supplementary_data['Rating Date'] = pd.to_datetime(supplementary_data['Rating Date'])
# Create Source column as 'Supplementary'
supplementary_data['Source'] = 'Supplementary'
# Rename columns in supplementary data to match original data
supplementary_data = supplementary_data.rename(columns = {'Rating Agency':'Rating Agency Name', 'Corporation':'Name', 'Rating Date':'Date', 'Ticker':'Symbol'})
# Combined data
combined_data = pd.concat([corporate_rating, supplementary_data], ignore_index = True)
combined_data
# Out:
# C:\Users\ijyli\AppData\Local\Temp\ipykernel_7780\3334983285.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   corporate_rating['Source'] = 'Original'
# C:\Users\ijyli\AppData\Local\Temp\ipykernel_7780\3334983285.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   corporate_rating['Date'] = pd.to_datetime(corporate_rating['Date'])
# C:\Users\ijyli\AppData\Local\Temp\ipykernel_7780\3334983285.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   supplementary_data['Rating Date'] = pd.to_datetime(supplementary_data['Rating Date'])
# C:\Users\ijyli\AppData\Local\Temp\ipykernel_7780\3334983285.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   supplementary_data['Source'] = 'Supplementary'
#      Rating                       Name Symbol  \
# 0         A      Whirlpool Corporation    WHR
# 1       BBB      Whirlpool Corporation    WHR
# 2       BBB      Whirlpool Corporation    WHR
# 3       BBB      Whirlpool Corporation    WHR
# 4       BBB      Whirlpool Corporation    WHR
# ...     ...                        ...    ...
# 9829   BBB+                 eBay, Inc.   EBAY
# 9830   BBB+                 eBay, Inc.   EBAY
# 9831     CC  iHeartCommunications Inc.    CCU
# 9832    CCC  iHeartCommunications Inc.    CCU
# 9833     CC  iHeartCommunications Inc.    CCU
#
#                       Rating Agency Name       Date             Sector  \
# 0             Egan-Jones Ratings Company 2015-11-27  Consumer Durables
# 1             Egan-Jones Ratings Company 2014-02-13  Consumer Durables
# 2                          Fitch Ratings 2015-03-06  Consumer Durables
# 3                          Fitch Ratings 2012-06-15  Consumer Durables
# 4     Standard & Poor's Ratings Services 2016-10-24  Consumer Durables
# ...                                  ...        ...                ...
# 9829           Moody's Investors Service 2016-02-22              BusEq
# 9830           Moody's Investors Service 2016-03-02              BusEq
# 9831  Standard & Poor's Ratings Services 2016-03-08              Telcm
# 9832  Standard & Poor's Ratings Services 2016-03-24              Telcm
# 9833  Standard & Poor's Ratings Services 2016-06-14              Telcm
#
#              Source
# 0          Original
# 1          Original
# 2          Original
# 3          Original
# 4          Original
# ...             ...
# 9829  Supplementary
# 9830  Supplementary
# 9831  Supplementary
# 9832  Supplementary
# 9833  Supplementary
#
# [9834 rows x 7 columns]

# %%
# Missing values?
combined_data.isnull().sum()
# Out:
# Rating                0
# Name                  0
# Symbol                0
# Rating Agency Name    0
# Date                  0
# Sector                0
# Source                0
# dtype: int64

# %%
# Name column seems tricky to harmonize, so drop for now
combined_data = combined_data.drop(columns = ['Name'])

# %%
# Count values of rating
print(combined_data['Rating'].value_counts())
# Strip + or - from Rating
combined_data['Rating'] = combined_data['Rating'].str.strip('+').str.strip('-')
# Count again
print(combined_data['Rating'].value_counts())
# Out:
# Rating
# BBB     1581
# A       1234
# BB       943
# BBB+     846
# A-       722
# BBB-     705
# B        612
# BB+      545
# A+       478
# BB-      427
# B+       422
# B-       288
# AA       274
# AA-      254
# CCC+     151
# CCC      129
# AAA       97
# AA+       73
# CC        23
# C         13
# CCC-      10
# D          6
# CC+        1
# Name: count, dtype: int64
# Rating
# BBB    3132
# A      2434
# BB     1915
# B      1322
# AA      601
# CCC     290
# AAA      97
# CC       24
# C        13
# D         6
# Name: count, dtype: int64

# %%
# Count values of Rating Agency Name
print(combined_data['Rating Agency Name'].value_counts())
# Out:
# Rating Agency Name
# Standard & Poor's Ratings Services    3557
# Egan-Jones Ratings Company            3429
# Moody's Investors Service             2215
# Fitch Ratings                          577
# DBRS                                    29
# Japan Credit Rating Agency,Ltd.         22
# HR Ratings de Mexico S.A. de C.V.        5
# Name: count, dtype: int64

# %%
# Count values of Sector
print(combined_data['Sector'].value_counts())
# Seems tricky to harmonize, so drop for now
combined_data = combined_data.drop(columns = ['Sector'])
# Out:
# Sector
# Other                    1251
# Manuf                     981
# BusEq                     958
# Utils                     843
# Shops                     786
# Enrgy                     665
# Hlth                      625
# NoDur                     567
# Telcm                     386
# Chems                     315
# Energy                    294
# Basic Industries          260
# Consumer Services         250
# Technology                234
# Capital Goods             233
# Durbl                     221
# Public Utilities          211
# Money                     207
# Health Care               171
# Consumer Non-Durables     132
# Consumer Durables          74
# Transportation             63
# Miscellaneous              57
# Finance                    50
# Name: count, dtype: int64

# %%
# Remaining columns
print(combined_data.columns)
# Out:
# Index(['Rating', 'Symbol', 'Rating Agency Name', 'Date', 'Source'], dtype='object')

# %%
# Drop duplicates
combined_data = combined_data.drop_duplicates()

# %%
# Number of rows
print(combined_data.shape[0])
# String collapse on 'Rating', 'Symbol', 'Rating Agency Name', 'Date'
# Combine values of Source column
combined_data = combined_data.groupby(['Rating', 'Symbol', 'Rating Agency Name', 'Date']).agg(', '.join).reset_index()
# Number of rows
print(combined_data.shape[0])
# Out:
# 9834
# 8732

# %%
# Values of Source
print(combined_data['Source'].value_counts())
# Recode 'Original, Supplementary' as 'Both'
combined_data['Source'] = combined_data['Source'].str.replace('Original, Supplementary', 'Both')
# Values of Source
print(combined_data['Source'].value_counts())
# Out:
# Source
# Supplementary              6703
# Original, Supplementary    1102
# Original                    927
# Name: count, dtype: int64
# Source
# Supplementary    6703
# Both             1102
# Original          927
# Name: count, dtype: int64

# %%
# Summarize variables
combined_data.describe()
# Out:
#                                 Date
# count                           8732
# mean   2014-06-11 15:19:22.620247552
# min              2005-08-16 00:00:00
# 25%              2013-07-08 18:00:00
# 50%              2014-07-25 00:00:00
# 75%              2015-07-27 06:00:00
# max              2016-12-27 00:00:00

# %%
# Print out value counts for each column
for col in combined_data.columns:
    print(col, combined_data[col].value_counts())
# Out:
# Rating Rating
# BBB    2771
# A      2195
# BB     1659
# B      1168
# AA      546
# CCC     261
# AAA      91
# CC       23
# C        12
# D         6
# Name: count, dtype: int64
# Symbol Symbol
# DTE     44
# AMX     42
# SCCO    40
# THC     37
# PEP     37
#         ..
# STKL     1
# TILE     1
# TSLA     1
# UAN      1
# UNIT     1
# Name: count, Length: 886, dtype: int64
# Rating Agency Name Rating Agency Name
# Standard & Poor's Ratings Services    3172
# Egan-Jones Ratings Company            3052
# Moody's Investors Service             1924
# Fitch Ratings                          529
# DBRS                                    28
# Japan Credit Rating Agency,Ltd.         22
# HR Ratings de Mexico S.A. de C.V.        5
# Name: count, dtype: int64
# Date Date
# 2012-06-15    535
# 2015-05-29     25
# 2015-09-10     22
# 2014-05-27     21
# 2013-11-26     21
#              ...
# 2011-08-23      1
# 2010-09-28      1
# 2012-03-26      1
# 2011-01-25      1
# 2010-08-03      1
# Name: count, Length: 1448, dtype: int64
# Source Source
# Supplementary    6703
# Both             1102
# Original          927
# Name: count, dtype: int64

# %%
# Sort by Rating Agency Name, Symbol, then Date
combined_data = combined_data.sort_values(by = ['Rating Agency Name', 'Symbol', 'Date'])

# %%
# Save as ~\Box\STAT 222 Capstone\Intermediate Data\combined_data.csv
combined_data.to_csv('~\Box\STAT 222 Capstone\Intermediate Data\combined_credit_rating_data.csv', index = False)
# Out:
# <>:2: SyntaxWarning: invalid escape sequence '\B'
# <>:2: SyntaxWarning: invalid escape sequence '\B'
# C:\Users\ijyli\AppData\Local\Temp\ipykernel_7780\2715337762.py:2: SyntaxWarning: invalid escape sequence '\B'
#   combined_data.to_csv('~\Box\STAT 222 Capstone\Intermediate Data\combined_credit_rating_data.csv', index = False)
