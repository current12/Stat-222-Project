# %% [markdown]
# # All Data EDA
#
# Description of data cleaning before this file:
#
# 1. Load and combine credit rating datasets to get unique ratings, company/tickers, and rating issue dates (unique key is credit rating, rating agency, and issuance date). Limit to S&P ratings from 2010-2016.
# 2. Load dataset of earnings call transcripts, dates, year + quarter of statement releases, companies, and sectors (unique key is company by earnings call date).
# 3. Load tabular financial statement datasets (unique key is company, year, quarter).
# 4. Use earnings call dates to transform dataset of credit ratings so there is one rating at each earnings call date. The key assumption is that a rating stays the same until a new rating is issued. Use leads to get rating at next earnings call date, date of next earnings call, rating 2 earnings call dates ahead, and date of that earnings call.
# 5. Inner join earnings call data with credit rating data. Use year and quarter from earnings calls to inner join with financial statement data. This produces the `all_data` dataset.
#
# GitHub copilot suggestions were used for plotting and low-level syntax.

# %% [markdown]
# # Setup - Sample Path and Packages

# %%
# Flag for if you are running this on the sample dataset
# Sample comprises 100 earnings calls (transcripts included)
# Full data comprises 4532 earnings calls (transcripts included)
sample = False
# Modify this path as needed to run on your machine
sample_path = r'~\Box\STAT 222 Capstone\Intermediate Data\All_Data\all_data_fixed_quarter_dates_sample.csv'

# %%
# Packages
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# # Code

# %%
# Load in sample csv, or full parquet file
# Use inputted sample path, or ~\Box\STAT 222 Capstone\Intermediate Data\All_Data\all_data_fixed_quarter.parquet
if sample:
    df = pd.read_csv(sample_path)
else:
    df = pd.read_parquet(r'~\Box\STAT 222 Capstone\Intermediate Data\All_Data\all_data_fixed_quarter_dates.parquet') 
df
# Out:
#      ticker          fixed_quarter_date earnings_call_date Rating  \
# 0      ABBV  2014-10-01 00:00:00.000000         2014-07-25      A
# 1      ABBV  2015-01-01 00:00:00.000000         2014-10-31      A
# 2      ABBV  2015-04-01 00:00:00.000000         2015-01-30      A
# 3      ABBV  2015-07-01 00:00:00.000000         2015-04-23      A
# 4      ABBV  2015-10-01 00:00:00.000000         2015-07-24      A
# ...     ...                         ...                ...    ...
# 4367    ZTS  2015-10-01 00:00:00.000000         2015-08-04    BBB
# 4368    ZTS  2016-01-01 00:00:00.000000         2015-11-03    BBB
# 4369    ZTS  2016-04-01 00:00:00.000000         2016-02-16    BBB
# 4370    ZTS  2016-07-01 00:00:00.000000         2016-05-04    BBB
# 4371    ZTS  2016-10-01 00:00:00.000000         2016-08-03    BBB
#
#                       Rating Agency Name rating_date         Source  \
# 0     Standard & Poor's Ratings Services  2014-07-18       Original
# 1     Standard & Poor's Ratings Services  2014-07-18       Original
# 2     Standard & Poor's Ratings Services  2014-07-18       Original
# 3     Standard & Poor's Ratings Services  2014-07-18       Original
# 4     Standard & Poor's Ratings Services  2014-07-18       Original
# ...                                  ...         ...            ...
# 4367  Standard & Poor's Ratings Services  2015-01-30           Both
# 4368  Standard & Poor's Ratings Services  2015-11-03  Supplementary
# 4369  Standard & Poor's Ratings Services  2016-01-22           Both
# 4370  Standard & Poor's Ratings Services  2016-01-22           Both
# 4371  Standard & Poor's Ratings Services  2016-01-22           Both
#
#       Rating Rank AAA is 10 Next Rating Next Rating Date  ...  \
# 0                         8        None             None  ...
# 1                         8        None             None  ...
# 2                         8        None             None  ...
# 3                         8        None             None  ...
# 4                         8        None             None  ...
# ...                     ...         ...              ...  ...
# 4367                      7         BBB       2015-11-03  ...
# 4368                      7         BBB       2016-01-22  ...
# 4369                      7         BBB       2016-12-23  ...
# 4370                      7         BBB       2016-12-23  ...
# 4371                      7         BBB       2016-12-23  ...
#
#      Change Direction Since Last Fixed Quarter Date  \
# 0                                              None
# 1                   Same As Last Fixed Quarter Date
# 2                   Same As Last Fixed Quarter Date
# 3                   Same As Last Fixed Quarter Date
# 4                   Same As Last Fixed Quarter Date
# ...                                             ...
# 4367                Same As Last Fixed Quarter Date
# 4368                Same As Last Fixed Quarter Date
# 4369                Same As Last Fixed Quarter Date
# 4370                Same As Last Fixed Quarter Date
# 4371                Same As Last Fixed Quarter Date
#
#      Change Since Last Fixed Quarter Date Ticker  \
# 0                                     NaN   ABBV
# 1                                     0.0   ABBV
# 2                                     0.0   ABBV
# 3                                     0.0   ABBV
# 4                                     0.0   ABBV
# ...                                   ...    ...
# 4367                                  0.0    ZTS
# 4368                                  0.0    ZTS
# 4369                                  0.0    ZTS
# 4370                                  0.0    ZTS
# 4371                                  0.0    ZTS
#
#                                             Description Company Name  \
# 0     AbbVie Inc. (AbbVie) is a research-based bioph...   ABBVIE INC
# 1     AbbVie Inc. (AbbVie) is a research-based bioph...   ABBVIE INC
# 2     AbbVie Inc. (AbbVie) is a research-based bioph...   ABBVIE INC
# 3     AbbVie Inc. (AbbVie) is a research-based bioph...   ABBVIE INC
# 4     AbbVie Inc. (AbbVie) is a research-based bioph...   ABBVIE INC
# ...                                                 ...          ...
# 4367  Zoetis Inc. is focused on the discovery, devel...   ZOETIS INC
# 4368  Zoetis Inc. is focused on the discovery, devel...   ZOETIS INC
# 4369  Zoetis Inc. is focused on the discovery, devel...   ZOETIS INC
# 4370  Zoetis Inc. is focused on the discovery, devel...   ZOETIS INC
# 4371  Zoetis Inc. is focused on the discovery, devel...   ZOETIS INC
#
#            Sector                                  Industry Group  \
# 0     Health Care  Pharmaceuticals, Biotechnology & Life Sciences
# 1     Health Care  Pharmaceuticals, Biotechnology & Life Sciences
# 2     Health Care  Pharmaceuticals, Biotechnology & Life Sciences
# 3     Health Care  Pharmaceuticals, Biotechnology & Life Sciences
# 4     Health Care  Pharmaceuticals, Biotechnology & Life Sciences
# ...           ...                                             ...
# 4367  Health Care  Pharmaceuticals, Biotechnology & Life Sciences
# 4368  Health Care  Pharmaceuticals, Biotechnology & Life Sciences
# 4369  Health Care  Pharmaceuticals, Biotechnology & Life Sciences
# 4370  Health Care  Pharmaceuticals, Biotechnology & Life Sciences
# 4371  Health Care  Pharmaceuticals, Biotechnology & Life Sciences
#
#              Industry     Sub-Industry  \
# 0       Biotechnology    Biotechnology
# 1       Biotechnology    Biotechnology
# 2       Biotechnology    Biotechnology
# 3       Biotechnology    Biotechnology
# 4       Biotechnology    Biotechnology
# ...               ...              ...
# 4367  Pharmaceuticals  Pharmaceuticals
# 4368  Pharmaceuticals  Pharmaceuticals
# 4369  Pharmaceuticals  Pharmaceuticals
# 4370  Pharmaceuticals  Pharmaceuticals
# 4371  Pharmaceuticals  Pharmaceuticals
#
#                                                 Comment
# 0     Companies primarily engaged in the research, d...
# 1     Companies primarily engaged in the research, d...
# 2     Companies primarily engaged in the research, d...
# 3     Companies primarily engaged in the research, d...
# 4     Companies primarily engaged in the research, d...
# ...                                                 ...
# 4367  Companies engaged in the research, development...
# 4368  Companies engaged in the research, development...
# 4369  Companies engaged in the research, development...
# 4370  Companies engaged in the research, development...
# 4371  Companies engaged in the research, development...
#
# [4372 rows x 160 columns]

# %%
## summary of the raw data 

# Summarize all numeric columns
# use describe method, transpose, and print all rows
# round to two decimal places, no scientific notation, commas for thousands
pd.options.display.float_format = '{:,.2f}'.format
# pandas setting to display all rows
pd.set_option('display.max_rows', None)
df.describe().T
# Out:
#                                                    count              mean  \
# Rating Rank AAA is 10                           4,372.00              6.76
# credit_rating_year                              4,372.00          2,013.25
# days_since_call                                 4,372.00             57.45
# year                                            4,372.00          2,014.09
# quarter                                         4,372.00              2.49
# cik                                             4,372.00        707,777.49
# calendarYear                                    4,372.00          2,014.09
# period                                          4,372.00              2.49
# cashAndCashEquivalents                          4,372.00  1,257,519,922.98
# shortTermInvestments                            4,372.00    275,497,324.98
# cashAndShortTermInvestments                     4,372.00  1,643,178,905.40
# netReceivables                                  4,372.00  1,788,949,094.38
# inventory                                       4,372.00  1,395,351,415.16
# otherCurrentAssets                              4,372.00    526,983,189.15
# totalCurrentAssets                              4,372.00  5,777,137,240.98
# propertyPlantEquipmentNet                       4,372.00  4,878,274,489.04
# goodwill                                        4,372.00  2,816,608,128.62
# intangibleAssets                                4,372.00  1,420,805,924.83
# goodwillAndIntangibleAssets                     4,372.00  4,296,560,843.65
# longTermInvestments                             4,372.00    483,202,524.11
# taxAssets                                       4,372.00    417,913,251.48
# otherNonCurrentAssets                           4,372.00    673,890,655.74
# totalNonCurrentAssets                           4,372.00 12,058,179,832.14
# otherAssets                                     4,372.00         35,506.01
# totalAssets                                     4,372.00 18,058,240,365.33
# accountPayables                                 4,372.00  1,370,800,996.80
# shortTermDebt                                   4,372.00    574,647,785.01
# taxPayables                                     4,372.00     86,677,369.05
# deferredRevenue                                 4,372.00    355,898,294.10
# otherCurrentLiabilities                         4,372.00  1,239,838,602.58
# totalCurrentLiabilities                         4,372.00  3,759,839,301.94
# longTermDebt                                    4,372.00  4,594,767,122.00
# deferredRevenueNonCurrent                       4,372.00    259,875,570.93
# deferredTaxLiabilitiesNonCurrent                4,372.00    672,189,142.11
# otherNonCurrentLiabilities                      4,372.00  1,074,004,691.35
# totalNonCurrentLiabilities                      4,372.00  7,256,705,399.81
# otherLiabilities                                4,372.00        232,808.44
# capitalLeaseObligations                         4,372.00     27,137,248.44
# totalLiabilities                                4,372.00 11,188,095,500.83
# preferredStock                                  4,372.00      9,380,279.74
# commonStock                                     4,372.00    378,184,840.51
# retainedEarnings                                4,372.00  4,870,760,677.72
# accumulatedOtherComprehensiveIncomeLoss         4,372.00   -502,832,271.81
# othertotalStockholdersEquity                    4,372.00  1,380,608,060.82
# totalStockholdersEquity                         4,372.00  6,353,599,725.30
# totalEquity                                     4,372.00  6,401,340,714.63
# totalLiabilitiesAndStockholdersEquity           4,372.00 18,050,660,133.40
# minorityInterest                                4,372.00    178,623,568.79
# totalLiabilitiesAndTotalEquity                  4,372.00 18,050,660,133.40
# totalInvestments                                4,372.00  1,245,010,588.28
# totalDebt                                       4,372.00  5,224,543,386.02
# netDebt                                         4,372.00  3,878,346,866.65
# cik_cash_flow_statement                         4,372.00        707,777.49
# netIncome                                       4,372.00    258,586,788.33
# depreciationAndAmortization                     4,372.00    168,932,778.78
# deferredIncomeTax                               4,372.00      3,835,504.70
# stockBasedCompensation                          4,372.00     15,434,221.07
# changeInWorkingCapital                          4,372.00    -18,150,584.58
# accountsReceivables                             4,372.00    -18,454,343.55
# inventory_cash_flow_statement                   4,372.00    -13,966,467.87
# accountsPayables                                4,372.00      8,077,902.88
# otherWorkingCapital                             4,372.00     10,707,604.55
# otherNonCashItems                               4,372.00     21,082,104.01
# netCashProvidedByOperatingActivities            4,372.00    481,925,095.99
# investmentsInPropertyPlantAndEquipment          4,372.00   -211,141,328.19
# acquisitionsNet                                 4,372.00    -32,524,446.52
# purchasesOfInvestments                          4,372.00    -99,893,520.74
# salesMaturitiesOfInvestments                    4,372.00    102,590,341.78
# otherInvestingActivites                         4,372.00      5,810,511.60
# netCashUsedForInvestingActivites                4,372.00   -304,357,760.80
# debtRepayment                                   4,372.00   -313,935,742.12
# commonStockIssued                               4,372.00     43,632,109.38
# commonStockRepurchased                          4,372.00    -91,370,165.62
# dividendsPaid                                   4,372.00   -109,165,865.62
# otherFinancingActivites                         4,372.00    272,862,917.44
# netCashUsedProvidedByFinancingActivities        4,372.00   -166,861,793.20
# effectOfForexChangesOnCash                      4,372.00     -2,481,588.63
# netChangeInCash                                 4,372.00      9,842,630.04
# cashAtEndOfPeriod                               4,372.00  1,257,000,867.53
# cashAtBeginningOfPeriod                         4,372.00  1,254,244,508.16
# operatingCashFlow                               4,372.00    481,925,095.99
# capitalExpenditure                              4,372.00   -211,141,353.56
# freeCashFlow                                    4,372.00    235,151,013.99
# cik_income_statement                            4,372.00        707,777.49
# revenue                                         4,372.00  3,618,998,700.47
# costOfRevenue                                   4,372.00  2,432,663,186.90
# grossProfit                                     4,372.00  1,198,526,763.58
# grossProfitRatio                                4,372.00              0.35
# researchAndDevelopmentExpenses                  4,372.00     46,629,059.47
# generalAndAdministrativeExpenses                4,372.00    201,762,298.17
# sellingAndMarketingExpenses                     4,372.00     58,112,270.44
# sellingGeneralAndAdministrativeExpenses         4,372.00    484,467,211.28
# otherExpenses                                   4,372.00     52,222,335.00
# operatingExpenses                               4,372.00    781,721,594.26
# costAndExpenses                                 4,372.00  3,172,613,317.60
# interestIncome                                  4,372.00      4,330,468.53
# interestExpense                                 4,372.00     51,721,469.65
# depreciationAndAmortization_income_statement    4,372.00    169,673,055.15
# ebitda                                          4,372.00    608,444,324.19
# ebitdaratio                                     4,372.00              0.18
# operatingIncome                                 4,372.00    436,161,234.55
# operatingIncomeRatio                            4,372.00              0.09
# totalOtherIncomeExpensesNet                     4,372.00    -19,500,198.28
# incomeBeforeTax                                 4,372.00    367,780,140.41
# incomeBeforeTaxRatio                            4,372.00              0.07
# incomeTaxExpense                                4,372.00    100,191,425.24
# netIncome_income_statement                      4,372.00    265,912,384.82
# netIncomeRatio                                  4,372.00              0.05
# eps                                             4,372.00              0.53
# epsdiluted                                      4,372.00              0.56
# weightedAverageShsOut                           4,372.00    449,934,405.27
# weightedAverageShsOutDil                        4,372.00    416,137,143.75
# rating_on_previous_fixed_quarter_date AAA is 10 4,059.00              6.76
# Change Since Last Fixed Quarter Date            4,059.00              0.01
#
#                                                               std  \
# Rating Rank AAA is 10                                        1.28
# credit_rating_year                                           1.61
# days_since_call                                             15.24
# year                                                         1.56
# quarter                                                      1.10
# cik                                                    549,023.40
# calendarYear                                                 1.56
# period                                                       1.10
# cashAndCashEquivalents                           2,307,452,658.78
# shortTermInvestments                             1,203,525,437.74
# cashAndShortTermInvestments                      3,714,583,644.75
# netReceivables                                   2,873,518,163.42
# inventory                                        2,201,422,911.66
# otherCurrentAssets                               1,093,277,992.54
# totalCurrentAssets                               9,779,249,123.86
# propertyPlantEquipmentNet                        8,601,163,559.12
# goodwill                                         4,973,136,892.23
# intangibleAssets                                 3,265,923,606.25
# goodwillAndIntangibleAssets                      7,942,119,638.54
# longTermInvestments                              1,628,704,730.44
# taxAssets                                        1,070,314,972.95
# otherNonCurrentAssets                            1,629,782,846.20
# totalNonCurrentAssets                           21,175,379,972.43
# otherAssets                                            622,787.83
# totalAssets                                     29,904,221,449.38
# accountPayables                                  2,638,240,770.37
# shortTermDebt                                    1,245,467,678.75
# taxPayables                                        277,370,385.35
# deferredRevenue                                    813,198,358.31
# otherCurrentLiabilities                          2,265,283,325.32
# totalCurrentLiabilities                          6,424,999,074.49
# longTermDebt                                     6,837,318,639.55
# deferredRevenueNonCurrent                          848,723,002.15
# deferredTaxLiabilitiesNonCurrent                 1,347,840,599.50
# otherNonCurrentLiabilities                       1,892,336,485.33
# totalNonCurrentLiabilities                      12,265,348,445.53
# otherLiabilities                                     3,254,448.80
# capitalLeaseObligations                            244,911,964.41
# totalLiabilities                                18,310,383,200.81
# preferredStock                                      47,228,665.36
# commonStock                                      1,520,263,659.24
# retainedEarnings                                 9,020,464,089.29
# accumulatedOtherComprehensiveIncomeLoss          1,111,054,957.79
# othertotalStockholdersEquity                     4,537,935,897.35
# totalStockholdersEquity                         10,897,240,361.45
# totalEquity                                     11,021,542,150.58
# totalLiabilitiesAndStockholdersEquity           29,908,166,482.30
# minorityInterest                                   553,427,657.20
# totalLiabilitiesAndTotalEquity                  29,908,166,482.30
# totalInvestments                                 4,424,746,843.05
# totalDebt                                        7,958,228,920.51
# netDebt                                          6,621,787,800.84
# cik_cash_flow_statement                                549,023.40
# netIncome                                          511,683,316.84
# depreciationAndAmortization                        307,848,239.53
# deferredIncomeTax                                   70,350,504.33
# stockBasedCompensation                              30,777,725.02
# changeInWorkingCapital                             237,086,029.43
# accountsReceivables                                116,450,200.49
# inventory_cash_flow_statement                       90,483,040.02
# accountsPayables                                    99,759,013.79
# otherWorkingCapital                                198,534,901.64
# otherNonCashItems                                  177,287,463.44
# netCashProvidedByOperatingActivities               887,804,832.58
# investmentsInPropertyPlantAndEquipment             402,133,241.77
# acquisitionsNet                                    127,742,725.47
# purchasesOfInvestments                             419,176,221.97
# salesMaturitiesOfInvestments                       405,277,928.99
# otherInvestingActivites                            128,900,587.93
# netCashUsedForInvestingActivites                   641,883,184.08
# debtRepayment                                      642,120,974.15
# commonStockIssued                                  129,161,803.81
# commonStockRepurchased                             207,297,225.63
# dividendsPaid                                      239,279,238.04
# otherFinancingActivites                            692,402,875.04
# netCashUsedProvidedByFinancingActivities           519,727,419.93
# effectOfForexChangesOnCash                          19,392,837.94
# netChangeInCash                                    381,469,591.30
# cashAtEndOfPeriod                                2,298,372,262.29
# cashAtBeginningOfPeriod                          2,293,048,007.16
# operatingCashFlow                                  887,804,832.58
# capitalExpenditure                                 402,133,228.45
# freeCashFlow                                       556,839,275.83
# cik_income_statement                                   549,023.40
# revenue                                          6,135,744,289.75
# costOfRevenue                                    4,792,487,518.20
# grossProfit                                      2,155,171,985.65
# grossProfitRatio                                             0.39
# researchAndDevelopmentExpenses                     171,947,994.19
# generalAndAdministrativeExpenses                   385,121,436.07
# sellingAndMarketingExpenses                        213,220,458.17
# sellingGeneralAndAdministrativeExpenses            852,807,707.64
# otherExpenses                                      388,269,389.57
# operatingExpenses                                1,522,475,238.07
# costAndExpenses                                  5,592,390,000.14
# interestIncome                                      17,734,777.70
# interestExpense                                     85,452,943.52
# depreciationAndAmortization_income_statement       305,688,285.13
# ebitda                                           1,077,656,255.69
# ebitdaratio                                                  0.72
# operatingIncome                                    812,285,735.14
# operatingIncomeRatio                                         0.51
# totalOtherIncomeExpensesNet                        106,140,962.95
# incomeBeforeTax                                    723,365,903.84
# incomeBeforeTaxRatio                                         0.43
# incomeTaxExpense                                   196,857,466.63
# netIncome_income_statement                         539,410,296.34
# netIncomeRatio                                               0.54
# eps                                                          4.05
# epsdiluted                                                   3.76
# weightedAverageShsOut                            1,117,014,155.30
# weightedAverageShsOutDil                           990,792,951.19
# rating_on_previous_fixed_quarter_date AAA is 10              1.28
# Change Since Last Fixed Quarter Date                         0.27
#
#                                                                min  \
# Rating Rank AAA is 10                                         2.00
# credit_rating_year                                        2,010.00
# days_since_call                                               0.00
# year                                                      2,010.00
# quarter                                                       1.00
# cik                                                       1,800.00
# calendarYear                                              2,010.00
# period                                                        1.00
# cashAndCashEquivalents                                        0.00
# shortTermInvestments                                   -515,000.00
# cashAndShortTermInvestments                                   0.00
# netReceivables                                       -4,199,600.00
# inventory                                           -24,912,000.00
# otherCurrentAssets                                      -98,000.00
# totalCurrentAssets                                            8.00
# propertyPlantEquipmentNet                                     0.00
# goodwill                                           -202,702,100.00
# intangibleAssets                                              0.00
# goodwillAndIntangibleAssets                      -1,618,944,000.00
# longTermInvestments                                -452,709,000.00
# taxAssets                                        -2,310,712,000.00
# otherNonCurrentAssets                            -2,834,000,000.00
# totalNonCurrentAssets                                         0.00
# otherAssets                                          -3,918,000.00
# totalAssets                                                   8.00
# accountPayables                                         -97,284.00
# shortTermDebt                                          -655,561.00
# taxPayables                                             -84,089.00
# deferredRevenue                                    -135,100,000.00
# otherCurrentLiabilities                             -40,150,000.00
# totalCurrentLiabilities                                       0.00
# longTermDebt                                                  0.00
# deferredRevenueNonCurrent                          -500,933,000.00
# deferredTaxLiabilitiesNonCurrent                     -1,300,000.00
# otherNonCurrentLiabilities                         -233,364,494.00
# totalNonCurrentLiabilities                                    0.00
# otherLiabilities                                     -2,000,224.00
# capitalLeaseObligations                                       0.00
# totalLiabilities                                              0.00
# preferredStock                                                0.00
# commonStock                                            -725,200.00
# retainedEarnings                                 -4,698,000,000.00
# accumulatedOtherComprehensiveIncomeLoss          -7,118,000,000.00
# othertotalStockholdersEquity                    -12,825,000,000.00
# totalStockholdersEquity                            -476,060,458.00
# totalEquity                                        -476,060,458.00
# totalLiabilitiesAndStockholdersEquity                         8.00
# minorityInterest                                    -20,252,654.04
# totalLiabilitiesAndTotalEquity                                8.00
# totalInvestments                                   -303,000,000.00
# totalDebt                                                     0.00
# netDebt                                          -2,437,681,449.59
# cik_cash_flow_statement                                   1,800.00
# netIncome                                          -392,803,000.00
# depreciationAndAmortization                            -876,000.00
# deferredIncomeTax                                  -293,000,000.00
# stockBasedCompensation                             -117,625,930.02
# changeInWorkingCapital                           -1,254,000,000.00
# accountsReceivables                                -688,000,000.00
# inventory_cash_flow_statement                      -599,000,000.00
# accountsPayables                                   -424,000,000.00
# otherWorkingCapital                              -1,788,851,160.00
# otherNonCashItems                                -1,848,719,007.00
# netCashProvidedByOperatingActivities               -367,488,850.57
# investmentsInPropertyPlantAndEquipment           -3,705,000,000.00
# acquisitionsNet                                  -1,031,000,000.00
# purchasesOfInvestments                          -11,997,654,000.00
# salesMaturitiesOfInvestments                         -3,419,000.00
# otherInvestingActivites                            -679,000,000.00
# netCashUsedForInvestingActivites                 -5,351,000,000.00
# debtRepayment                                    -4,502,000,000.00
# commonStockIssued                                   -10,423,183.28
# commonStockRepurchased                           -2,086,545,366.00
# dividendsPaid                                    -1,758,000,000.00
# otherFinancingActivites                            -975,168,999.00
# netCashUsedProvidedByFinancingActivities         -3,604,000,000.00
# effectOfForexChangesOnCash                         -104,000,000.00
# netChangeInCash                                  -1,716,000,000.00
# cashAtEndOfPeriod                                            18.00
# cashAtBeginningOfPeriod                              -2,556,000.00
# operatingCashFlow                                  -367,488,850.57
# capitalExpenditure                               -3,705,000,000.00
# freeCashFlow                                       -682,000,000.00
# cik_income_statement                                      1,800.00
# revenue                                              -6,646,000.00
# costOfRevenue                                        -4,822,000.00
# grossProfit                                          -7,195,000.00
# grossProfitRatio                                            -17.88
# researchAndDevelopmentExpenses                         -214,000.00
# generalAndAdministrativeExpenses                    -15,529,576.71
# sellingAndMarketingExpenses                          -3,003,000.00
# sellingGeneralAndAdministrativeExpenses             -11,283,000.00
# otherExpenses                                      -446,174,207.59
# operatingExpenses                                    -2,976,356.00
# costAndExpenses                                      -5,794,000.00
# interestIncome                                      -22,067,601.47
# interestExpense                                     -48,846,275.90
# depreciationAndAmortization_income_statement         -1,550,000.00
# ebitda                                             -262,368,860.15
# ebitdaratio                                                 -44.29
# operatingIncome                                    -337,266,425.90
# operatingIncomeRatio                                        -20.35
# totalOtherIncomeExpensesNet                        -864,000,000.00
# incomeBeforeTax                                    -412,072,000.00
# incomeBeforeTaxRatio                                         -9.38
# incomeTaxExpense                                   -142,000,000.00
# netIncome_income_statement                         -392,000,000.00
# netIncomeRatio                                               -8.88
# eps                                                        -156.36
# epsdiluted                                                 -156.36
# weightedAverageShsOut                                         0.00
# weightedAverageShsOutDil                                      0.00
# rating_on_previous_fixed_quarter_date AAA is 10               2.00
# Change Since Last Fixed Quarter Date                         -2.00
#
#                                                              25%  \
# Rating Rank AAA is 10                                       6.00
# credit_rating_year                                      2,012.00
# days_since_call                                            55.00
# year                                                    2,013.00
# quarter                                                     2.00
# cik                                                    75,677.00
# calendarYear                                            2,013.00
# period                                                      2.00
# cashAndCashEquivalents                            132,996,000.00
# shortTermInvestments                                        0.00
# cashAndShortTermInvestments                       133,850,000.00
# netReceivables                                    287,841,250.00
# inventory                                         161,000,000.00
# otherCurrentAssets                                 50,723,750.00
# totalCurrentAssets                              1,049,903,250.00
# propertyPlantEquipmentNet                         563,750,000.00
# goodwill                                          133,374,000.00
# intangibleAssets                                   12,284,500.00
# goodwillAndIntangibleAssets                       310,842,500.00
# longTermInvestments                                         0.00
# taxAssets                                                   0.00
# otherNonCurrentAssets                              46,131,500.00
# totalNonCurrentAssets                           2,044,515,750.00
# otherAssets                                                 0.00
# totalAssets                                     3,420,050,000.00
# accountPayables                                   143,674,250.00
# shortTermDebt                                       8,075,000.00
# taxPayables                                                 0.00
# deferredRevenue                                             0.00
# otherCurrentLiabilities                           140,771,250.00
# totalCurrentLiabilities                           538,278,250.00
# longTermDebt                                      959,932,500.00
# deferredRevenueNonCurrent                                   0.00
# deferredTaxLiabilitiesNonCurrent                            0.00
# otherNonCurrentLiabilities                        107,953,000.00
# totalNonCurrentLiabilities                      1,436,038,750.00
# otherLiabilities                                            0.00
# capitalLeaseObligations                                     0.00
# totalLiabilities                                2,157,976,750.00
# preferredStock                                              0.00
# commonStock                                           859,750.00
# retainedEarnings                                  229,342,500.00
# accumulatedOtherComprehensiveIncomeLoss          -429,829,250.00
# othertotalStockholdersEquity                      -22,603,750.00
# totalStockholdersEquity                         1,005,965,000.00
# totalEquity                                     1,006,900,000.00
# totalLiabilitiesAndStockholdersEquity           3,420,050,000.00
# minorityInterest                                            0.00
# totalLiabilitiesAndTotalEquity                  3,420,050,000.00
# totalInvestments                                            0.00
# totalDebt                                       1,063,049,500.00
# netDebt                                           557,916,750.00
# cik_cash_flow_statement                                75,677.00
# netIncome                                          19,861,500.00
# depreciationAndAmortization                        25,500,000.00
# deferredIncomeTax                                  -7,603,000.00
# stockBasedCompensation                              2,033,250.00
# changeInWorkingCapital                            -75,000,000.00
# accountsReceivables                               -27,500,000.00
# inventory_cash_flow_statement                     -21,118,750.00
# accountsPayables                                  -10,346,750.00
# otherWorkingCapital                               -27,254,500.00
# otherNonCashItems                                  -7,200,000.00
# netCashProvidedByOperatingActivities               52,434,000.00
# investmentsInPropertyPlantAndEquipment           -207,000,000.00
# acquisitionsNet                                   -14,935,500.00
# purchasesOfInvestments                             -6,973,000.00
# salesMaturitiesOfInvestments                                0.00
# otherInvestingActivites                            -3,046,500.00
# netCashUsedForInvestingActivites                 -278,193,509.28
# debtRepayment                                    -294,872,000.00
# commonStockIssued                                           0.00
# commonStockRepurchased                            -75,000,000.00
# dividendsPaid                                     -91,741,500.00
# otherFinancingActivites                            -1,387,738.50
# netCashUsedProvidedByFinancingActivities         -218,000,000.00
# effectOfForexChangesOnCash                         -3,000,000.00
# netChangeInCash                                   -61,527,500.00
# cashAtEndOfPeriod                                 132,706,000.00
# cashAtBeginningOfPeriod                           131,439,750.00
# operatingCashFlow                                  52,434,000.00
# capitalExpenditure                               -207,000,000.00
# freeCashFlow                                       -2,855,000.00
# cik_income_statement                                   75,677.00
# revenue                                           614,779,250.00
# costOfRevenue                                     348,779,750.00
# grossProfit                                       184,024,000.00
# grossProfitRatio                                            0.20
# researchAndDevelopmentExpenses                              0.00
# generalAndAdministrativeExpenses                            0.00
# sellingAndMarketingExpenses                                 0.00
# sellingGeneralAndAdministrativeExpenses            64,552,750.00
# otherExpenses                                        -400,000.00
# operatingExpenses                                 102,461,250.00
# costAndExpenses                                   527,605,250.00
# interestIncome                                              0.00
# interestExpense                                    11,451,750.00
# depreciationAndAmortization_income_statement       26,432,500.00
# ebitda                                             91,527,750.00
# ebitdaratio                                                 0.10
# operatingIncome                                    53,384,000.00
# operatingIncomeRatio                                        0.06
# totalOtherIncomeExpensesNet                       -20,708,750.00
# incomeBeforeTax                                    30,075,000.00
# incomeBeforeTaxRatio                                        0.03
# incomeTaxExpense                                    6,000,000.00
# netIncome_income_statement                         20,992,250.00
# netIncomeRatio                                              0.02
# eps                                                         0.21
# epsdiluted                                                  0.21
# weightedAverageShsOut                              75,565,384.50
# weightedAverageShsOutDil                           75,352,358.25
# rating_on_previous_fixed_quarter_date AAA is 10             6.00
# Change Since Last Fixed Quarter Date                        0.00
#
#                                                              50%  \
# Rating Rank AAA is 10                                       7.00
# credit_rating_year                                      2,013.00
# days_since_call                                            61.00
# year                                                    2,014.00
# quarter                                                     2.00
# cik                                                   833,079.00
# calendarYear                                            2,014.00
# period                                                      2.00
# cashAndCashEquivalents                            426,228,500.00
# shortTermInvestments                                        0.00
# cashAndShortTermInvestments                       471,992,500.00
# netReceivables                                    703,460,500.00
# inventory                                         565,900,000.00
# otherCurrentAssets                                145,373,000.00
# totalCurrentAssets                              2,400,569,500.00
# propertyPlantEquipmentNet                       1,569,743,500.00
# goodwill                                          886,146,500.00
# intangibleAssets                                  274,886,500.00
# goodwillAndIntangibleAssets                     1,360,200,000.00
# longTermInvestments                                   671,000.00
# taxAssets                                          45,211,500.00
# otherNonCurrentAssets                             207,500,000.00
# totalNonCurrentAssets                           4,880,601,000.00
# otherAssets                                                 0.00
# totalAssets                                     7,729,146,000.00
# accountPayables                                   420,019,500.00
# shortTermDebt                                      83,800,000.00
# taxPayables                                         1,865,000.00
# deferredRevenue                                    28,163,000.00
# otherCurrentLiabilities                           385,740,500.00
# totalCurrentLiabilities                         1,346,413,500.00
# longTermDebt                                    2,253,601,500.00
# deferredRevenueNonCurrent                                   0.00
# deferredTaxLiabilitiesNonCurrent                  133,630,500.00
# otherNonCurrentLiabilities                        378,139,500.00
# totalNonCurrentLiabilities                      3,259,000,000.00
# otherLiabilities                                            0.00
# capitalLeaseObligations                                     0.00
# totalLiabilities                                4,931,768,500.00
# preferredStock                                              0.00
# commonStock                                         4,800,000.00
# retainedEarnings                                1,570,464,500.00
# accumulatedOtherComprehensiveIncomeLoss          -114,121,000.00
# othertotalStockholdersEquity                      415,834,000.00
# totalStockholdersEquity                         2,334,636,500.00
# totalEquity                                     2,337,617,500.00
# totalLiabilitiesAndStockholdersEquity           7,729,146,000.00
# minorityInterest                                    4,870,500.00
# totalLiabilitiesAndTotalEquity                  7,729,146,000.00
# totalInvestments                                   25,469,000.00
# totalDebt                                       2,490,706,500.00
# netDebt                                         1,633,911,500.00
# cik_cash_flow_statement                               833,079.00
# netIncome                                          81,090,000.00
# depreciationAndAmortization                        64,600,000.00
# deferredIncomeTax                                           0.00
# stockBasedCompensation                              6,571,500.00
# changeInWorkingCapital                             -2,984,000.00
# accountsReceivables                                         0.00
# inventory_cash_flow_statement                               0.00
# accountsPayables                                            0.00
# otherWorkingCapital                                         0.00
# otherNonCashItems                                   2,199,500.00
# netCashProvidedByOperatingActivities              168,601,500.00
# investmentsInPropertyPlantAndEquipment            -62,000,000.00
# acquisitionsNet                                             0.00
# purchasesOfInvestments                                      0.00
# salesMaturitiesOfInvestments                                0.00
# otherInvestingActivites                               100,000.00
# netCashUsedForInvestingActivites                  -71,000,000.00
# debtRepayment                                     -35,474,000.00
# commonStockIssued                                           0.00
# commonStockRepurchased                             -1,436,500.00
# dividendsPaid                                     -22,511,000.00
# otherFinancingActivites                             8,100,000.00
# netCashUsedProvidedByFinancingActivities          -45,627,500.00
# effectOfForexChangesOnCash                                  0.00
# netChangeInCash                                       642,500.00
# cashAtEndOfPeriod                                 427,593,500.00
# cashAtBeginningOfPeriod                           427,238,000.00
# operatingCashFlow                                 168,601,500.00
# capitalExpenditure                                -62,000,000.00
# freeCashFlow                                       70,000,000.00
# cik_income_statement                                  833,079.00
# revenue                                         1,521,516,500.00
# costOfRevenue                                     915,144,000.00
# grossProfit                                       431,150,000.00
# grossProfitRatio                                            0.33
# researchAndDevelopmentExpenses                              0.00
# generalAndAdministrativeExpenses                   45,340,000.00
# sellingAndMarketingExpenses                                 0.00
# sellingGeneralAndAdministrativeExpenses           179,727,500.00
# otherExpenses                                         265,500.00
# operatingExpenses                                 250,987,000.00
# costAndExpenses                                 1,327,381,000.00
# interestIncome                                              0.00
# interestExpense                                    24,711,000.00
# depreciationAndAmortization_income_statement       66,851,000.00
# ebitda                                            229,472,500.00
# ebitdaratio                                                 0.16
# operatingIncome                                   153,950,000.00
# operatingIncomeRatio                                        0.11
# totalOtherIncomeExpensesNet                        -2,000,000.00
# incomeBeforeTax                                   112,421,500.00
# incomeBeforeTaxRatio                                        0.09
# incomeTaxExpense                                   31,764,000.00
# netIncome_income_statement                         83,250,000.00
# netIncomeRatio                                              0.06
# eps                                                         0.58
# epsdiluted                                                  0.58
# weightedAverageShsOut                             151,769,035.00
# weightedAverageShsOutDil                          154,000,000.00
# rating_on_previous_fixed_quarter_date AAA is 10             7.00
# Change Since Last Fixed Quarter Date                        0.00
#
#                                                               75%  \
# Rating Rank AAA is 10                                        8.00
# credit_rating_year                                       2,015.00
# days_since_call                                             67.00
# year                                                     2,015.00
# quarter                                                      3.00
# cik                                                  1,101,239.00
# calendarYear                                             2,015.00
# period                                                       3.00
# cashAndCashEquivalents                           1,317,250,000.00
# shortTermInvestments                                18,859,500.00
# cashAndShortTermInvestments                      1,541,050,000.00
# netReceivables                                   1,862,461,750.00
# inventory                                        1,569,800,000.00
# otherCurrentAssets                                 443,225,000.00
# totalCurrentAssets                               5,777,025,000.00
# propertyPlantEquipmentNet                        5,178,000,000.00
# goodwill                                         2,948,425,500.00
# intangibleAssets                                 1,091,304,000.00
# goodwillAndIntangibleAssets                      4,182,459,500.00
# longTermInvestments                                242,043,000.00
# taxAssets                                          302,250,000.00
# otherNonCurrentAssets                              656,000,000.00
# totalNonCurrentAssets                           12,677,275,000.00
# otherAssets                                                  0.00
# totalAssets                                     19,518,900,000.00
# accountPayables                                  1,329,025,000.00
# shortTermDebt                                      484,713,500.00
# taxPayables                                         48,000,000.00
# deferredRevenue                                    298,722,000.00
# otherCurrentLiabilities                          1,150,250,000.00
# totalCurrentLiabilities                          3,932,183,000.00
# longTermDebt                                     5,069,000,000.00
# deferredRevenueNonCurrent                           84,517,000.00
# deferredTaxLiabilitiesNonCurrent                   681,024,000.00
# otherNonCurrentLiabilities                       1,084,115,250.00
# totalNonCurrentLiabilities                       7,758,300,000.00
# otherLiabilities                                             0.00
# capitalLeaseObligations                                      0.00
# totalLiabilities                                12,440,275,000.00
# preferredStock                                               0.00
# commonStock                                        132,302,250.00
# retainedEarnings                                 5,085,350,000.00
# accumulatedOtherComprehensiveIncomeLoss             -4,004,500.00
# othertotalStockholdersEquity                     2,139,102,750.00
# totalStockholdersEquity                          6,506,750,000.00
# totalEquity                                      6,518,200,000.00
# totalLiabilitiesAndStockholdersEquity           19,518,900,000.00
# minorityInterest                                    74,475,000.00
# totalLiabilitiesAndTotalEquity                  19,518,900,000.00
# totalInvestments                                   440,520,750.00
# totalDebt                                        5,851,500,000.00
# netDebt                                          4,126,450,000.00
# cik_cash_flow_statement                              1,101,239.00
# netIncome                                          266,175,000.00
# depreciationAndAmortization                        186,238,000.00
# deferredIncomeTax                                   10,114,250.00
# stockBasedCompensation                              15,989,250.00
# changeInWorkingCapital                              46,454,250.00
# accountsReceivables                                  9,134,000.00
# inventory_cash_flow_statement                        6,298,500.00
# accountsPayables                                    19,300,000.00
# otherWorkingCapital                                 32,000,000.00
# otherNonCashItems                                   27,000,000.00
# netCashProvidedByOperatingActivities               509,775,000.00
# investmentsInPropertyPlantAndEquipment             -22,993,750.00
# acquisitionsNet                                              0.00
# purchasesOfInvestments                                       0.00
# salesMaturitiesOfInvestments                        12,492,500.00
# otherInvestingActivites                              6,776,250.00
# netCashUsedForInvestingActivites                   -19,599,250.00
# debtRepayment                                       -1,000,000.00
# commonStockIssued                                   13,000,000.00
# commonStockRepurchased                                       0.00
# dividendsPaid                                       -1,794,500.00
# otherFinancingActivites                            190,250,000.00
# netCashUsedProvidedByFinancingActivities             3,517,905.00
# effectOfForexChangesOnCash                             600,000.00
# netChangeInCash                                     64,545,750.00
# cashAtEndOfPeriod                                1,318,052,250.00
# cashAtBeginningOfPeriod                          1,311,204,250.00
# operatingCashFlow                                  509,775,000.00
# capitalExpenditure                                 -22,993,750.00
# freeCashFlow                                       260,450,000.00
# cik_income_statement                                 1,101,239.00
# revenue                                          3,662,250,000.00
# costOfRevenue                                    2,121,097,750.00
# grossProfit                                      1,152,250,000.00
# grossProfitRatio                                             0.49
# researchAndDevelopmentExpenses                               0.00
# generalAndAdministrativeExpenses                   209,775,000.00
# sellingAndMarketingExpenses                                  0.00
# sellingGeneralAndAdministrativeExpenses            449,975,000.00
# otherExpenses                                        9,404,000.00
# operatingExpenses                                  674,250,000.00
# costAndExpenses                                  3,060,525,000.00
# interestIncome                                       1,534,500.00
# interestExpense                                     56,079,500.00
# depreciationAndAmortization_income_statement       185,000,000.00
# ebitda                                             634,850,000.00
# ebitdaratio                                                  0.24
# operatingIncome                                    429,060,000.00
# operatingIncomeRatio                                         0.17
# totalOtherIncomeExpensesNet                          2,800,000.00
# incomeBeforeTax                                    381,494,250.00
# incomeBeforeTaxRatio                                         0.15
# incomeTaxExpense                                   107,000,000.00
# netIncome_income_statement                         271,662,500.00
# netIncomeRatio                                               0.11
# eps                                                          1.09
# epsdiluted                                                   1.07
# weightedAverageShsOut                              416,073,931.00
# weightedAverageShsOutDil                           411,000,000.00
# rating_on_previous_fixed_quarter_date AAA is 10              8.00
# Change Since Last Fixed Quarter Date                         0.00
#
#                                                                max
# Rating Rank AAA is 10                                        10.00
# credit_rating_year                                        2,016.00
# days_since_call                                              91.00
# year                                                      2,019.00
# quarter                                                       4.00
# cik                                                   1,841,666.00
# calendarYear                                              2,019.00
# period                                                        4.00
# cashAndCashEquivalents                           18,347,000,000.00
# shortTermInvestments                             16,882,000,000.00
# cashAndShortTermInvestments                      38,376,000,000.00
# netReceivables                                   23,172,000,000.00
# inventory                                        15,342,000,000.00
# otherCurrentAssets                               10,224,000,000.00
# totalCurrentAssets                               84,554,000,000.00
# propertyPlantEquipmentNet                        85,559,000,000.00
# goodwill                                         30,165,000,000.00
# intangibleAssets                                 26,333,000,000.00
# goodwillAndIntangibleAssets                      62,128,000,000.00
# longTermInvestments                              21,385,000,000.00
# taxAssets                                        10,596,000,000.00
# otherNonCurrentAssets                            17,225,000,000.00
# totalNonCurrentAssets                           209,400,000,000.00
# otherAssets                                          13,442,000.00
# totalAssets                                     269,604,000,000.00
# accountPayables                                  22,692,064,000.00
# shortTermDebt                                    11,546,000,000.00
# taxPayables                                       3,033,000,000.00
# deferredRevenue                                   7,558,000,000.00
# otherCurrentLiabilities                          18,249,000,000.00
# totalCurrentLiabilities                          69,529,000,000.00
# longTermDebt                                     59,719,000,000.00
# deferredRevenueNonCurrent                         8,359,000,000.00
# deferredTaxLiabilitiesNonCurrent                 13,607,000,000.00
# otherNonCurrentLiabilities                       17,749,000,000.00
# totalNonCurrentLiabilities                      103,796,000,000.00
# otherLiabilities                                     53,949,000.00
# capitalLeaseObligations                           9,056,234,000.00
# totalLiabilities                                165,598,000,000.00
# preferredStock                                      530,000,000.00
# commonStock                                      25,004,000,000.00
# retainedEarnings                                 64,714,000,000.00
# accumulatedOtherComprehensiveIncomeLoss           2,507,598,451.88
# othertotalStockholdersEquity                     30,621,000,000.00
# totalStockholdersEquity                          98,815,000,000.00
# totalEquity                                     104,500,000,000.00
# totalLiabilitiesAndStockholdersEquity           269,604,000,000.00
# minorityInterest                                  4,240,000,000.00
# totalLiabilitiesAndTotalEquity                  269,604,000,000.00
# totalInvestments                                 37,169,000,000.00
# totalDebt                                        71,149,000,000.00
# netDebt                                          50,898,000,000.00
# cik_cash_flow_statement                               1,841,666.00
# netIncome                                         4,240,000,000.00
# depreciationAndAmortization                       2,811,000,000.00
# deferredIncomeTax                                 1,850,454,000.00
# stockBasedCompensation                              298,000,000.00
# changeInWorkingCapital                              985,700,000.00
# accountsReceivables                                 381,000,000.00
# inventory_cash_flow_statement                       360,000,000.00
# accountsPayables                                  1,789,652,000.00
# otherWorkingCapital                               1,171,700,000.00
# otherNonCashItems                                 1,266,000,000.00
# netCashProvidedByOperatingActivities              7,658,000,000.00
# investmentsInPropertyPlantAndEquipment                  363,000.00
# acquisitionsNet                                     329,000,000.00
# purchasesOfInvestments                               81,823,000.00
# salesMaturitiesOfInvestments                      8,936,406,000.00
# otherInvestingActivites                           3,060,433,659.00
# netCashUsedForInvestingActivites                    368,000,000.00
# debtRepayment                                            54,579.00
# commonStockIssued                                 1,111,490,728.00
# commonStockRepurchased                              310,240,449.00
# dividendsPaid                                                 0.00
# otherFinancingActivites                           4,958,000,000.00
# netCashUsedProvidedByFinancingActivities          1,402,000,000.00
# effectOfForexChangesOnCash                          198,174,198.37
# netChangeInCash                                   2,099,000,000.00
# cashAtEndOfPeriod                                18,068,000,000.00
# cashAtBeginningOfPeriod                          17,627,000,000.00
# operatingCashFlow                                 7,658,000,000.00
# capitalExpenditure                                      363,000.00
# freeCashFlow                                      4,028,000,000.00
# cik_income_statement                                  1,841,666.00
# revenue                                          45,549,000,000.00
# costOfRevenue                                    35,898,000,000.00
# grossProfit                                      18,837,000,000.00
# grossProfitRatio                                              5.00
# researchAndDevelopmentExpenses                    1,484,000,000.00
# generalAndAdministrativeExpenses                  3,000,308,000.00
# sellingAndMarketingExpenses                       1,586,000,000.00
# sellingGeneralAndAdministrativeExpenses           6,034,000,000.00
# otherExpenses                                    16,189,674,590.00
# operatingExpenses                                12,124,000,000.00
# costAndExpenses                                  41,798,000,000.00
# interestIncome                                      227,000,000.00
# interestExpense                                     732,000,000.00
# depreciationAndAmortization_income_statement      3,284,000,000.00
# ebitda                                            9,960,000,000.00
# ebitdaratio                                                   6.05
# operatingIncome                                   6,935,000,000.00
# operatingIncomeRatio                                         11.48
# totalOtherIncomeExpensesNet                         488,209,000.00
# incomeBeforeTax                                   5,833,000,000.00
# incomeBeforeTaxRatio                                         12.07
# incomeTaxExpense                                  1,671,000,000.00
# netIncome_income_statement                        4,600,000,000.00
# netIncomeRatio                                               26.12
# eps                                                          53.75
# epsdiluted                                                   49.73
# weightedAverageShsOut                            13,751,391,147.00
# weightedAverageShsOutDil                         13,986,214,405.00
# rating_on_previous_fixed_quarter_date AAA is 10              10.00
# Change Since Last Fixed Quarter Date                          2.00

# %%
# Revert to default settings
pd.reset_option('display.float_format')
pd.reset_option('display.max_rows')

# %%
# Check data is unique on ticker by earnings_call_date
df['ticker_earnings_date'] = df['ticker'] + '_' + df['earnings_call_date'].astype(str)
df['ticker_earnings_date'].value_counts().max()
# Out:
# 2

# %%
# Number of unique firms (identified by ticker)
df['ticker'].nunique()
# Out:
# 313

# %%
# Histogram of count of earnings calls by ticker/firm
# Title: Histogram of Count of Earnings Calls by Ticker
plt.hist(df['ticker'].value_counts(), bins = 100)
plt.title('Histogram of Count of Earnings Calls by Ticker/Firm')
plt.show()

# %%
# How often is Sector variable missing?
print('Percent of missing values for Sector:', df['Sector'].isna().mean())
# Out:
# Percent of missing values for Sector: 0.0651875571820677

# %%
# Distribution of industry sectors
# variable sector
# Title: Calls in Each Industry Sector
df['Sector'].value_counts().plot(kind = 'barh', color = 'skyblue')
plt.title('Calls in Each Industry Sector')
plt.show()

# %%
# Number of firms in each industry sector
# Title: Number of Firms in Each Industry Sector
# Unique ticker by sector, sort by number of firms
df.groupby('Sector')['ticker'].nunique().sort_values(ascending=False).plot(kind = 'barh', color = 'green')
plt.title('Number of Firms in Each Industry Sector')
plt.show()

# %%
# Distribution of earnings_call_date
# Create call_year and call_quarter columns after converting earnings_call_date to datetime
df['call_year'] = pd.to_datetime(df['earnings_call_date']).dt.year
df['call_quarter'] = pd.to_datetime(df['earnings_call_date']).dt.quarter
# Group by year and quarter
data_grouped = df.groupby([df.call_year, df.call_quarter]).size().sort_index(ascending=False)
# Plot horizontal bar chart
# 2010 at the top
data_grouped.plot(kind='barh')
plt.title('Calls Per Year, Quarter')
plt.xlabel('Count')
plt.ylabel('Year, Quarter')
plt.show()

# %%
# Company dropout
# For each ticker, get the max value of earnings_call_date, and print out items where it is not in the last quarter of 2016
# Convert earnings_call_date to datetime
df['earnings_call_date_dt'] = pd.to_datetime(df['earnings_call_date'])
# Add column max_date to df
df['max_date'] = df.groupby('ticker')['earnings_call_date_dt'].transform('max')
# Display rows where max_date is not in the last quarter of 2016
df[df['max_date'] < '2016-10-01']
# Out:
#      ticker          fixed_quarter_date earnings_call_date Rating  \
# 0      ABBV  2014-10-01 00:00:00.000000         2014-07-25      A
# 1      ABBV  2015-01-01 00:00:00.000000         2014-10-31      A
# 2      ABBV  2015-04-01 00:00:00.000000         2015-01-30      A
# 3      ABBV  2015-07-01 00:00:00.000000         2015-04-23      A
# 4      ABBV  2015-10-01 00:00:00.000000         2015-07-24      A
# ...     ...                         ...                ...    ...
# 4367    ZTS  2015-10-01 00:00:00.000000         2015-08-04    BBB
# 4368    ZTS  2016-01-01 00:00:00.000000         2015-11-03    BBB
# 4369    ZTS  2016-04-01 00:00:00.000000         2016-02-16    BBB
# 4370    ZTS  2016-07-01 00:00:00.000000         2016-05-04    BBB
# 4371    ZTS  2016-10-01 00:00:00.000000         2016-08-03    BBB
#
#                       Rating Agency Name rating_date         Source  \
# 0     Standard & Poor's Ratings Services  2014-07-18       Original
# 1     Standard & Poor's Ratings Services  2014-07-18       Original
# 2     Standard & Poor's Ratings Services  2014-07-18       Original
# 3     Standard & Poor's Ratings Services  2014-07-18       Original
# 4     Standard & Poor's Ratings Services  2014-07-18       Original
# ...                                  ...         ...            ...
# 4367  Standard & Poor's Ratings Services  2015-01-30           Both
# 4368  Standard & Poor's Ratings Services  2015-11-03  Supplementary
# 4369  Standard & Poor's Ratings Services  2016-01-22           Both
# 4370  Standard & Poor's Ratings Services  2016-01-22           Both
# 4371  Standard & Poor's Ratings Services  2016-01-22           Both
#
#       Rating Rank AAA is 10 Next Rating Next Rating Date  ...       Sector  \
# 0                         8        None             None  ...  Health Care
# 1                         8        None             None  ...  Health Care
# 2                         8        None             None  ...  Health Care
# 3                         8        None             None  ...  Health Care
# 4                         8        None             None  ...  Health Care
# ...                     ...         ...              ...  ...          ...
# 4367                      7         BBB       2015-11-03  ...  Health Care
# 4368                      7         BBB       2016-01-22  ...  Health Care
# 4369                      7         BBB       2016-12-23  ...  Health Care
# 4370                      7         BBB       2016-12-23  ...  Health Care
# 4371                      7         BBB       2016-12-23  ...  Health Care
#
#                                       Industry Group         Industry  \
# 0     Pharmaceuticals, Biotechnology & Life Sciences    Biotechnology
# 1     Pharmaceuticals, Biotechnology & Life Sciences    Biotechnology
# 2     Pharmaceuticals, Biotechnology & Life Sciences    Biotechnology
# 3     Pharmaceuticals, Biotechnology & Life Sciences    Biotechnology
# 4     Pharmaceuticals, Biotechnology & Life Sciences    Biotechnology
# ...                                              ...              ...
# 4367  Pharmaceuticals, Biotechnology & Life Sciences  Pharmaceuticals
# 4368  Pharmaceuticals, Biotechnology & Life Sciences  Pharmaceuticals
# 4369  Pharmaceuticals, Biotechnology & Life Sciences  Pharmaceuticals
# 4370  Pharmaceuticals, Biotechnology & Life Sciences  Pharmaceuticals
# 4371  Pharmaceuticals, Biotechnology & Life Sciences  Pharmaceuticals
#
#          Sub-Industry                                            Comment  \
# 0       Biotechnology  Companies primarily engaged in the research, d...
# 1       Biotechnology  Companies primarily engaged in the research, d...
# 2       Biotechnology  Companies primarily engaged in the research, d...
# 3       Biotechnology  Companies primarily engaged in the research, d...
# 4       Biotechnology  Companies primarily engaged in the research, d...
# ...               ...                                                ...
# 4367  Pharmaceuticals  Companies engaged in the research, development...
# 4368  Pharmaceuticals  Companies engaged in the research, development...
# 4369  Pharmaceuticals  Companies engaged in the research, development...
# 4370  Pharmaceuticals  Companies engaged in the research, development...
# 4371  Pharmaceuticals  Companies engaged in the research, development...
#
#       ticker_earnings_date call_year call_quarter  earnings_call_date_dt  \
# 0          ABBV_2014-07-25      2014            3             2014-07-25
# 1          ABBV_2014-10-31      2014            4             2014-10-31
# 2          ABBV_2015-01-30      2015            1             2015-01-30
# 3          ABBV_2015-04-23      2015            2             2015-04-23
# 4          ABBV_2015-07-24      2015            3             2015-07-24
# ...                    ...       ...          ...                    ...
# 4367        ZTS_2015-08-04      2015            3             2015-08-04
# 4368        ZTS_2015-11-03      2015            4             2015-11-03
# 4369        ZTS_2016-02-16      2016            1             2016-02-16
# 4370        ZTS_2016-05-04      2016            2             2016-05-04
# 4371        ZTS_2016-08-03      2016            3             2016-08-03
#
#        max_date
# 0    2016-07-29
# 1    2016-07-29
# 2    2016-07-29
# 3    2016-07-29
# 4    2016-07-29
# ...         ...
# 4367 2016-08-03
# 4368 2016-08-03
# 4369 2016-08-03
# 4370 2016-08-03
# 4371 2016-08-03
#
# [4372 rows x 165 columns]

# %%
# Unique firms where this is the case
df[df['max_date'] < '2016-10-01'][['ticker', 'max_date']].drop_duplicates()
# Out:
#      ticker   max_date
# 0      ABBV 2016-07-29
# 9       ABC 2016-08-02
# 32      ABG 2016-07-26
# 40      ABT 2016-07-20
# 60     ACHC 2016-07-29
# ...     ...        ...
# 4294    XOM 2016-07-29
# 4314   XRAY 2016-08-05
# 4336    XYL 2016-08-02
# 4337    YUM 2016-07-14
# 4358    ZTS 2016-08-03
#
# [313 rows x 2 columns]

# %% [markdown]
# AMCR is amcor, should still exist but it's date is kind of close to the end of 2016
#
# BTU, peabody energy, seems to have gone bankrupt April 13, 2016
#
# FTI underwent a merger in 2016-2017
#
# KBH still exists, but again the date is pretty close...
#
# The other non-close one is STON. Notably, StonMor Partners had some issues with delayed SEC filings https://seekingalpha.com/article/4056108-prelude-to-bankruptcy-saving-grace-stonemor-partners-delays-10-k-again

# %%
# Distribution of Rating and rating_on_next_earnings_call_date

# Colored with gradient and ordered

# Colors AAA through D
# Used https://colordesigner.io/gradient-generator#google_vignette
# Assign hex codes from green to red
#32671d
#416703
#516600
#626400
#756000
#885b00
#9c5200
#af4500
#c33200
#d60000
hex_code_mapper = {'AAA': '#32671d', 'AA': '#416703', 'A': '#516600', 'BBB': '#626400', 'BB': '#756000', 'B': '#885b00', 'CCC': '#9c5200', 'CC': '#af4500', 'C': '#c33200', 'D': '#d60000'}

# Ordering of bars - keys from hex_code_mapper
bar_order = ['AAA', 'AA', 'A', 'BBB', 'BB', 'B', 'CCC', 'CC', 'C', 'D']
# Assign values of Rating to this ordering
df['Rating'] = pd.Categorical(df['Rating'], categories=bar_order, ordered=True)

# Create plot
# Save to "../Output/Distribution of Ratings.png"
plt.bar(df['Rating'].value_counts().sort_index().index, df['Rating'].value_counts().sort_index(), color=[hex_code_mapper[i] for i in bar_order])
plt.title('Rating on Earnings Call Date')
#plt.savefig('../../Output/Distribution of Rating Issuances.png')
plt.show()

# Rating on next earnings call date
df['rating_on_next_earnings_call_date'] = pd.Categorical(df['rating_on_next_earnings_call_date'], categories=bar_order, ordered=True)
plt.bar(df['rating_on_next_earnings_call_date'].value_counts().sort_index().index, df['rating_on_next_earnings_call_date'].value_counts().sort_index(), color=[hex_code_mapper[i] for i in bar_order])
plt.title('Rating on Next Earnings Call Date')
#plt.savefig('../../Output/Distribution of Rating on Next Earnings Call Date.png')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File c:\Users\ijyli\anaconda3\envs\capstone\Lib\site-packages\pandas\core\indexes\base.py:3791, in Index.get_loc(self, key)
#    3790 try:
# -> 3791     return self._engine.get_loc(casted_key)
#    3792 except KeyError as err:
#
# File index.pyx:152, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:181, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\_libs\hashtable_class_helper.pxi:7080, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\_libs\hashtable_class_helper.pxi:7088, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'rating_on_next_earnings_call_date'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[27], line 33
#      30 plt.show()
#      32 # Rating on next earnings call date
# ---> 33 df['rating_on_next_earnings_call_date'] = pd.Categorical(df['rating_on_next_earnings_call_date'], categories=bar_order, ordered=True)
#      34 plt.bar(df['rating_on_next_earnings_call_date'].value_counts().sort_index().index, df['rating_on_next_earnings_call_date'].value_counts().sort_index(), color=[hex_code_mapper[i] for i in bar_order])
#      35 plt.title('Rating on Next Earnings Call Date')
#
# File c:\Users\ijyli\anaconda3\envs\capstone\Lib\site-packages\pandas\core\frame.py:3893, in DataFrame.__getitem__(self, key)
#    3891 if self.columns.nlevels > 1:
#    3892     return self._getitem_multilevel(key)
# -> 3893 indexer = self.columns.get_loc(key)
#    3894 if is_integer(indexer):
#    3895     indexer = [indexer]
#
# File c:\Users\ijyli\anaconda3\envs\capstone\Lib\site-packages\pandas\core\indexes\base.py:3798, in Index.get_loc(self, key)
#    3793     if isinstance(casted_key, slice) or (
#    3794         isinstance(casted_key, abc.Iterable)
#    3795         and any(isinstance(x, slice) for x in casted_key)
#    3796     ):
#    3797         raise InvalidIndexError(key)
# -> 3798     raise KeyError(key) from err
#    3799 except TypeError:
#    3800     # If we have a listlike key, _check_indexing_error will raise
#    3801     #  InvalidIndexError. Otherwise we fall through and re-raise
#    3802     #  the TypeError.
#    3803     self._check_indexing_error(key)
#
# KeyError: 'rating_on_next_earnings_call_date'

# %%
# Bar chart of 'Change Direction Before Next Call'
df['Change Direction Before Next Call'].value_counts().plot(kind='barh')
plt.title('Change Direction Before Next Call')
plt.show()
print(df['Change Direction Before Next Call'].value_counts())

# Bar chart of 'Change Before Next Call'
df['Change Before Next Call'].value_counts().sort_index().plot(kind='barh')
plt.title('Change Before Next Call')
plt.show()
print(df['Change Before Next Call'].value_counts().sort_index())
# Out:
# Change Direction Before Next Call
# Same At Next Call             3981
# Upgrade Before Next Call       130
# Downgrade Before Next Call     102
# Name: count, dtype: int64
# Change Before Next Call
# -2.0       9
# -1.0      93
#  0.0    3981
#  1.0     117
#  2.0      13
# Name: count, dtype: int64

# %%
# Calculate the mean of "totalAssets" for each kind of "Rating"
mean_assets_by_rating = df.groupby('Rating')['totalDebt'].mean()

# Plotting
mean_assets_by_rating.plot(kind='bar')
plt.title('Mean Total Assets for each Rating')
plt.xlabel('Rating')
plt.ylabel('Mean Total Assets')
plt.show()
# Out:
# C:\Users\ijyli\AppData\Local\Temp\ipykernel_11612\3119831694.py:2: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   mean_assets_by_rating = df.groupby('Rating')['totalDebt'].mean()

# %%
# Calculate the mean of "grossProfitRatio" for each kind of "Rating"
mean_gross_profit_by_rating = df.groupby('Rating')["grossProfitRatio"].mean()

# Plotting
mean_assets_by_rating.plot(kind='bar')
plt.title('Mean Gross Profit Ratio for each Rating')
plt.xlabel('Rating')
plt.ylabel('Mean Gross Profit Ratio ')
plt.show()
# Out:
# C:\Users\ijyli\AppData\Local\Temp\ipykernel_11612\796684613.py:2: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   mean_gross_profit_by_rating = df.groupby('Rating')["grossProfitRatio"].mean()

# %% [markdown]
# We can see the relationship between rating and total assets; rating and gross profit ratio. High rating like AAA will have high mean total assets and high mean gross profit ratio.
