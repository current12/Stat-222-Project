# %% [markdown]
# # All Data EDA
#
# Description of data cleaning before this file:
#
# 1. Load and combine credit rating datasets to get unique ratings, company/tickers, and rating issue dates (unique key is credit rating, rating agency, and issuance date). Limit to S&P ratings from 2010-2016.
# 2. Load dataset of earnings call transcripts, dates, year + quarter of statement releases, companies, and sectors (unique key is company by earnings call date).
# 3. Load tabular financial statement datasets (unique key is company, year, quarter).
# 4. Use earnings call dates to transform dataset of credit ratings so there is one rating at each earnings call date. The key assumption is that a rating stays the same until a new rating is issued. Use leads to get rating at next earnings call date, date of next earnings call, rating 2 earnings call dates ahead, and date of that earnings call.
# 5. Inner join earnings call data with credit rating data. Use year and quarter from earnings calls to inner join with financial statement data. This produces the `all_data` dataset.
#
# GitHub copilot suggestions were used, primarily for plotting.

# %% [markdown]
# # Setup - Sample Path and Packages

# %%
# Flag for if you are running this on the sample dataset
# Sample comprises 100 earnings calls (transcripts included)
# Full data comprises 4532 earnings calls (transcripts included)
sample = False
# Modify this path as needed to run on your machine
sample_path = r'~\Box\STAT 222 Capstone\Intermediate Data\all_data_sample.csv'

# %%
# Packages
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# # Code

# %%
# Load in sample csv, or full parquet file
# Use inputted sample path, or ~\Box\STAT 222 Capstone\Intermediate Data\all_data.parquet
if sample:
    df = pd.read_csv(sample_path)
else:
    df = pd.read_parquet(r'~\Box\STAT 222 Capstone\Intermediate Data\all_data.parquet') 
df
# Out:
#      ticker earnings_call_date next_earnings_call_date  \
# 0      ABBV         2014-07-25              2014-10-31
# 1      ABBV         2014-10-31              2015-01-30
# 2      ABBV         2015-01-30              2015-04-23
# 3      ABBV         2015-04-23              2015-07-24
# 4      ABBV         2015-07-24              2015-10-30
# ...     ...                ...                     ...
# 4527    ZTS         2015-11-03              2016-02-16
# 4528    ZTS         2016-02-16              2016-05-04
# 4529    ZTS         2016-05-04              2016-08-03
# 4530    ZTS         2016-08-03              2016-11-02
# 4531    ZTS         2016-11-02                    None
#
#      rating_on_next_earnings_call_date  days_until_next_earnings_call Rating  \
# 0                                    A                           98.0      A
# 1                                    A                           91.0      A
# 2                                    A                           83.0      A
# 3                                    A                           92.0      A
# 4                                    A                           98.0      A
# ...                                ...                            ...    ...
# 4527                               BBB                          105.0    BBB
# 4528                               BBB                           78.0    BBB
# 4529                               BBB                           91.0    BBB
# 4530                               BBB                           91.0    BBB
# 4531                              None                            NaN    BBB
#
#                       Rating Agency Name rating_date         Source  \
# 0     Standard & Poor's Ratings Services  2014-07-18       Original
# 1     Standard & Poor's Ratings Services  2014-07-18       Original
# 2     Standard & Poor's Ratings Services  2014-07-18       Original
# 3     Standard & Poor's Ratings Services  2014-07-18       Original
# 4     Standard & Poor's Ratings Services  2014-07-18       Original
# ...                                  ...         ...            ...
# 4527  Standard & Poor's Ratings Services  2015-11-03  Supplementary
# 4528  Standard & Poor's Ratings Services  2016-01-22           Both
# 4529  Standard & Poor's Ratings Services  2016-01-22           Both
# 4530  Standard & Poor's Ratings Services  2016-01-22           Both
# 4531  Standard & Poor's Ratings Services  2016-01-22           Both
#
#       Rating Rank AAA is 10  ... netIncomeRatio   eps epsdiluted  \
# 0                         8  ...       0.222899  0.69       0.68
# 1                         8  ...       0.100817  0.32       0.31
# 2                         8  ...      -0.148569 -0.51      -0.51
# 3                         8  ...       0.202778  0.64       0.63
# 4                         8  ...       0.249498  0.84       0.83
# ...                     ...  ...            ...   ...        ...
# 4527                      7  ...       0.175559  0.41       0.41
# 4528                      7  ...       0.185430  0.45       0.45
# 4529                      7  ...       0.192587  0.48       0.48
# 4530                      7  ...       0.120595  0.31       0.31
# 4531                      7  ...       0.193339  0.48       0.48
#
#      weightedAverageShsOut weightedAverageShsOutDil  \
# 0             1.594000e+09             1.608000e+09
# 1             1.595000e+09             1.610000e+09
# 2             1.591389e+09             1.597000e+09
# 3             1.595000e+09             1.608000e+09
# 4             1.620000e+09             1.633000e+09
# ...                    ...                      ...
# 4527          4.973990e+08             4.995390e+08
# 4528          4.963000e+08             4.988000e+08
# 4529          4.952000e+08             4.979000e+08
# 4530          4.939320e+08             4.966380e+08
# 4531          4.924000e+08             4.953000e+08
#
#                                   link_income_statement  \
# 0     https://www.sec.gov/Archives/edgar/data/155115...
# 1     https://www.sec.gov/Archives/edgar/data/155115...
# 2     https://www.sec.gov/Archives/edgar/data/155115...
# 3     https://www.sec.gov/Archives/edgar/data/155115...
# 4     https://www.sec.gov/Archives/edgar/data/155115...
# ...                                                 ...
# 4527  https://www.sec.gov/Archives/edgar/data/155528...
# 4528  https://www.sec.gov/Archives/edgar/data/155528...
# 4529  https://www.sec.gov/Archives/edgar/data/155528...
# 4530  https://www.sec.gov/Archives/edgar/data/155528...
# 4531  https://www.sec.gov/Archives/edgar/data/155528...
#
#                              finalLink_income_statement  \
# 0     https://www.sec.gov/Archives/edgar/data/155115...
# 1     https://www.sec.gov/Archives/edgar/data/155115...
# 2     https://www.sec.gov/Archives/edgar/data/155115...
# 3     https://www.sec.gov/Archives/edgar/data/155115...
# 4     https://www.sec.gov/Archives/edgar/data/155115...
# ...                                                 ...
# 4527  https://www.sec.gov/Archives/edgar/data/155528...
# 4528  https://www.sec.gov/Archives/edgar/data/155528...
# 4529  https://www.sec.gov/Archives/edgar/data/155528...
# 4530  https://www.sec.gov/Archives/edgar/data/155528...
# 4531  https://www.sec.gov/Archives/edgar/data/155528...
#
#       Rating on Next Earnings Call Date Rank AAA is 10  \
# 0                                                  8.0
# 1                                                  8.0
# 2                                                  8.0
# 3                                                  8.0
# 4                                                  8.0
# ...                                                ...
# 4527                                               7.0
# 4528                                               7.0
# 4529                                               7.0
# 4530                                               7.0
# 4531                                               NaN
#
#      Change Direction Before Next Call Change Before Next Call
# 0                    Same At Next Call                     0.0
# 1                    Same At Next Call                     0.0
# 2                    Same At Next Call                     0.0
# 3                    Same At Next Call                     0.0
# 4                    Same At Next Call                     0.0
# ...                                ...                     ...
# 4527                 Same At Next Call                     0.0
# 4528                 Same At Next Call                     0.0
# 4529                 Same At Next Call                     0.0
# 4530                 Same At Next Call                     0.0
# 4531                              None                     NaN
#
# [4532 rows x 161 columns]

# %%
## summary of the raw data 

# Summarize all numeric columns
# use describe method, transpose, and print all rows
# round to two decimal places, no scientific notation, commas for thousands
pd.options.display.float_format = '{:,.2f}'.format
# pandas setting to display all rows
pd.set_option('display.max_rows', None)
df.describe().T
# Out:
#                                                     count              mean  \
# days_until_next_earnings_call                    4,213.00             93.27
# Rating Rank AAA is 10                            4,532.00              6.75
# Change in Rating                                 3,587.00              0.02
# Year                                             4,532.00          2,013.28
# year                                             4,532.00          2,014.29
# quarter                                          4,532.00              2.52
# cik                                              4,532.00        709,311.50
# calendarYear                                     4,532.00          2,014.29
# period                                           4,532.00              2.52
# cashAndCashEquivalents                           4,532.00  1,535,929,224.37
# shortTermInvestments                             4,532.00  4,988,623,266.19
# cashAndShortTermInvestments                      4,532.00  2,120,898,494.52
# netReceivables                                   4,532.00  1,921,999,022.63
# inventory                                        4,532.00  1,435,297,437.67
# otherCurrentAssets                               4,532.00    630,328,755.44
# totalCurrentAssets                               4,532.00  6,088,233,743.85
# propertyPlantEquipmentNet                        4,532.00  6,728,974,362.94
# goodwill                                         4,532.00  3,039,435,731.93
# intangibleAssets                                 4,532.00  2,325,212,577.20
# goodwillAndIntangibleAssets                      4,532.00  4,969,093,794.34
# longTermInvestments                              4,532.00    994,677,505.72
# taxAssets                                        4,532.00 -5,013,282,441.79
# otherNonCurrentAssets                            4,532.00  6,587,453,343.67
# totalNonCurrentAssets                            4,532.00 14,274,745,532.44
# otherAssets                                      4,532.00     37,279,285.53
# totalAssets                                      4,532.00 20,403,086,673.02
# accountPayables                                  4,532.00  1,678,428,355.08
# shortTermDebt                                    4,532.00    676,755,089.19
# taxPayables                                      4,532.00    252,751,663.90
# deferredRevenue                                  4,532.00    282,976,647.86
# otherCurrentLiabilities                          4,532.00  1,364,017,965.60
# totalCurrentLiabilities                          4,532.00  4,012,051,700.27
# longTermDebt                                     4,532.00  4,773,257,541.75
# deferredRevenueNonCurrent                        4,532.00    555,861,959.34
# deferredTaxLiabilitiesNonCurrent                 4,532.00  1,146,091,788.93
# otherNonCurrentLiabilities                       4,532.00  1,033,027,893.29
# totalNonCurrentLiabilities                       4,532.00  7,496,271,646.01
# otherLiabilities                                 4,532.00    234,123,409.75
# capitalLeaseObligations                          4,532.00  3,930,590,347.10
# totalLiabilities                                 4,532.00 11,755,157,553.91
# preferredStock                                   4,532.00     30,252,917.70
# commonStock                                      4,532.00  3,329,870,100.17
# retainedEarnings                                 4,532.00  8,065,496,764.51
# accumulatedOtherComprehensiveIncomeLoss          4,532.00   -664,485,264.58
# othertotalStockholdersEquity                     4,532.00   -316,108,664.45
# totalStockholdersEquity                          4,532.00  8,419,207,530.98
# totalEquity                                      4,532.00  8,442,168,854.46
# totalLiabilitiesAndStockholdersEquity            4,532.00 20,393,655,691.78
# minorityInterest                                 4,532.00    419,426,378.95
# totalLiabilitiesAndTotalEquity                   4,532.00 20,393,655,691.78
# totalInvestments                                 4,532.00  5,993,122,725.57
# totalDebt                                        4,532.00  5,405,676,109.32
# netDebt                                          4,532.00  3,869,583,041.62
# cik_cash_flow_statement                          4,532.00        709,311.50
# calendarYear_cash_flow_statement                 4,532.00          2,014.29
# period_cash_flow_statement                       4,532.00              2.52
# netIncome                                        4,532.00    302,995,573.48
# depreciationAndAmortization                      4,532.00    223,932,147.44
# deferredIncomeTax                                4,532.00    676,895,673.19
# stockBasedCompensation                           4,532.00     32,500,847.64
# changeInWorkingCapital                           4,532.00    -12,002,234.47
# accountsReceivables                              4,532.00    -37,435,887.34
# inventory_cash_flow_statement                    4,532.00    -10,036,094.41
# accountsPayables                                 4,532.00    321,600,846.26
# otherWorkingCapital                              4,532.00   -285,813,132.41
# otherNonCashItems                                4,532.00   -655,251,768.40
# netCashProvidedByOperatingActivities             4,532.00    567,951,074.49
# investmentsInPropertyPlantAndEquipment           4,532.00   -298,219,160.97
# acquisitionsNet                                  4,532.00   -250,093,403.38
# purchasesOfInvestments                           4,532.00 -3,984,689,962.39
# salesMaturitiesOfInvestments                     4,532.00  3,455,908,870.96
# otherInvestingActivites                          4,532.00    674,424,669.55
# netCashUsedForInvestingActivites                 4,532.00   -417,764,666.07
# debtRepayment                                    4,532.00   -639,091,462.99
# commonStockIssued                                4,532.00    466,715,172.07
# commonStockRepurchased                           4,532.00   -542,098,530.08
# dividendsPaid                                    4,532.00   -211,122,312.78
# otherFinancingActivites                          4,532.00    793,501,339.24
# netCashUsedProvidedByFinancingActivities         4,532.00   -125,704,187.53
# effectOfForexChangesOnCash                       4,532.00     -1,860,099.42
# netChangeInCash                                  4,532.00     25,396,807.52
# cashAtEndOfPeriod                                4,532.00  1,539,855,313.77
# cashAtBeginningOfPeriod                          4,532.00  1,519,102,350.03
# operatingCashFlow                                4,532.00    567,951,074.49
# capitalExpenditure                               4,532.00   -298,219,160.97
# freeCashFlow                                     4,532.00    269,731,913.52
# cik_income_statement                             4,532.00        709,311.50
# calendarYear_income_statement                    4,532.00          2,014.29
# period_income_statement                          4,532.00              2.52
# revenue                                          4,532.00  4,204,178,860.63
# costOfRevenue                                    4,532.00  2,855,652,233.55
# grossProfit                                      4,532.00  1,350,604,620.01
# grossProfitRatio                                 4,532.00              0.35
# researchAndDevelopmentExpenses                   4,532.00     87,732,766.97
# generalAndAdministrativeExpenses                 4,532.00    292,200,330.66
# sellingAndMarketingExpenses                      4,532.00     96,685,322.94
# sellingGeneralAndAdministrativeExpenses          4,532.00    542,701,563.99
# otherExpenses                                    4,532.00  7,126,960,541.04
# operatingExpenses                                4,532.00    873,182,276.73
# costAndExpenses                                  4,532.00  3,722,391,730.50
# interestIncome                                   4,532.00     12,209,526.00
# interestExpense                                  4,532.00     51,561,580.00
# depreciationAndAmortization_income_statement     4,532.00    214,845,085.78
# ebitda                                           4,532.00    678,592,874.14
# ebitdaratio                                      4,532.00              0.18
# operatingIncome                                  4,532.00    450,015,000.41
# operatingIncomeRatio                             4,532.00              0.09
# totalOtherIncomeExpensesNet                      4,532.00    -13,008,621.64
# incomeBeforeTax                                  4,532.00    426,471,164.85
# incomeBeforeTaxRatio                             4,532.00              0.07
# incomeTaxExpense                                 4,532.00    123,259,510.94
# netIncome_income_statement                       4,532.00    303,307,353.12
# netIncomeRatio                                   4,532.00              0.05
# eps                                              4,532.00              0.54
# epsdiluted                                       4,532.00              0.55
# weightedAverageShsOut                            4,532.00    470,251,451.86
# weightedAverageShsOutDil                         4,532.00    477,493,023.07
# Rating on Next Earnings Call Date Rank AAA is 10 4,213.00              6.77
# Change Before Next Call                          4,213.00              0.01
#
#                                                                 std  \
# days_until_next_earnings_call                                 24.64
# Rating Rank AAA is 10                                          1.28
# Change in Rating                                               0.53
# Year                                                           1.64
# year                                                           1.57
# quarter                                                        1.12
# cik                                                      549,506.65
# calendarYear                                                   1.57
# period                                                         1.12
# cashAndCashEquivalents                             5,523,419,258.67
# shortTermInvestments                             210,069,282,993.89
# cashAndShortTermInvestments                        7,525,146,382.75
# netReceivables                                     3,524,348,166.20
# inventory                                          2,598,581,290.63
# otherCurrentAssets                                 1,757,252,133.71
# totalCurrentAssets                                11,751,660,628.07
# propertyPlantEquipmentNet                         21,093,978,673.90
# goodwill                                           8,921,591,906.45
# intangibleAssets                                   8,903,990,647.55
# goodwillAndIntangibleAssets                       27,449,282,248.43
# longTermInvestments                                6,987,172,497.54
# taxAssets                                        102,067,956,917.94
# otherNonCurrentAssets                             99,099,039,111.32
# totalNonCurrentAssets                             31,580,342,771.36
# otherAssets                                          644,947,874.93
# totalAssets                                       41,000,881,771.28
# accountPayables                                    4,262,431,485.12
# shortTermDebt                                      1,787,885,632.54
# taxPayables                                        4,584,983,498.83
# deferredRevenue                                    2,494,964,471.94
# otherCurrentLiabilities                            3,593,550,562.73
# totalCurrentLiabilities                            7,756,553,938.35
# longTermDebt                                       7,464,001,970.49
# deferredRevenueNonCurrent                          6,673,727,887.05
# deferredTaxLiabilitiesNonCurrent                   3,917,907,632.54
# otherNonCurrentLiabilities                         6,811,650,367.74
# totalNonCurrentLiabilities                        13,084,046,755.07
# otherLiabilities                                   3,268,113,305.73
# capitalLeaseObligations                          181,765,681,032.51
# totalLiabilities                                  20,449,574,343.05
# preferredStock                                       236,416,285.14
# commonStock                                      148,117,367,392.35
# retainedEarnings                                  30,540,236,426.00
# accumulatedOtherComprehensiveIncomeLoss            2,009,909,149.91
# othertotalStockholdersEquity                     152,960,148,216.58
# totalStockholdersEquity                           22,006,447,751.14
# totalEquity                                       22,015,882,160.19
# totalLiabilitiesAndStockholdersEquity             41,003,408,217.68
# minorityInterest                                   2,598,610,015.15
# totalLiabilitiesAndTotalEquity                    41,003,408,217.68
# totalInvestments                                 210,191,911,022.34
# totalDebt                                          8,628,977,423.40
# netDebt                                            7,424,227,884.30
# cik_cash_flow_statement                                  549,506.65
# calendarYear_cash_flow_statement                               1.57
# period_cash_flow_statement                                     1.12
# netIncome                                          1,041,969,993.59
# depreciationAndAmortization                          584,681,733.18
# deferredIncomeTax                                 31,297,659,476.39
# stockBasedCompensation                               383,138,471.64
# changeInWorkingCapital                               476,056,840.81
# accountsReceivables                                  491,842,157.04
# inventory_cash_flow_statement                        307,450,762.43
# accountsPayables                                  27,470,206,813.37
# otherWorkingCapital                               27,462,190,803.97
# otherNonCashItems                                 31,284,658,871.87
# netCashProvidedByOperatingActivities               1,494,377,506.79
# investmentsInPropertyPlantAndEquipment               964,072,855.03
# acquisitionsNet                                   10,158,886,497.41
# purchasesOfInvestments                           193,699,941,835.10
# salesMaturitiesOfInvestments                     157,025,636,938.15
# otherInvestingActivites                           45,541,049,692.38
# netCashUsedForInvestingActivites                   1,647,947,792.53
# debtRepayment                                     13,782,655,127.75
# commonStockIssued                                 16,663,884,471.91
# commonStockRepurchased                            31,403,806,519.85
# dividendsPaid                                      2,042,618,962.79
# otherFinancingActivites                           27,642,923,224.07
# netCashUsedProvidedByFinancingActivities           1,226,280,898.58
# effectOfForexChangesOnCash                           298,283,302.45
# netChangeInCash                                    1,229,136,221.02
# cashAtEndOfPeriod                                  5,525,465,099.40
# cashAtBeginningOfPeriod                            5,311,680,525.31
# operatingCashFlow                                  1,494,377,506.79
# capitalExpenditure                                   964,072,855.03
# freeCashFlow                                       1,253,828,258.94
# cik_income_statement                                     549,506.65
# calendarYear_income_statement                                  1.57
# period_income_statement                                        1.12
# revenue                                            8,899,635,853.87
# costOfRevenue                                      6,575,020,857.80
# grossProfit                                        3,066,968,631.90
# grossProfitRatio                                               0.39
# researchAndDevelopmentExpenses                       362,379,838.43
# generalAndAdministrativeExpenses                     775,412,436.44
# sellingAndMarketingExpenses                          387,151,964.22
# sellingGeneralAndAdministrativeExpenses            1,071,459,892.15
# otherExpenses                                    331,745,140,306.40
# operatingExpenses                                  1,967,764,774.15
# costAndExpenses                                    7,986,868,404.87
# interestIncome                                       297,194,211.59
# interestExpense                                       94,690,315.36
# depreciationAndAmortization_income_statement         550,674,715.81
# ebitda                                             1,634,603,182.87
# ebitdaratio                                                    0.71
# operatingIncome                                    1,240,158,158.24
# operatingIncomeRatio                                           0.50
# totalOtherIncomeExpensesNet                          504,315,281.82
# incomeBeforeTax                                    1,479,028,977.89
# incomeBeforeTaxRatio                                           0.42
# incomeTaxExpense                                     485,200,991.80
# netIncome_income_statement                         1,038,326,149.05
# netIncomeRatio                                                 0.54
# eps                                                            3.99
# epsdiluted                                                     3.81
# weightedAverageShsOut                              1,157,062,911.64
# weightedAverageShsOutDil                           1,175,446,913.33
# Rating on Next Earnings Call Date Rank AAA is 10               1.28
# Change Before Next Call                                        0.27
#
#                                                                     min  \
# days_until_next_earnings_call                                     26.00
# Rating Rank AAA is 10                                              2.00
# Change in Rating                                                  -2.00
# Year                                                           2,010.00
# year                                                           2,010.00
# quarter                                                            1.00
# cik                                                            1,800.00
# calendarYear                                                   2,010.00
# period                                                             1.00
# cashAndCashEquivalents                                             0.00
# shortTermInvestments                                    -515,000,000.00
# cashAndShortTermInvestments                                        0.00
# netReceivables                                        -4,199,600,000.00
# inventory                                            -27,358,000,000.00
# otherCurrentAssets                                       -98,000,000.00
# totalCurrentAssets                                             8,000.00
# propertyPlantEquipmentNet                                -25,785,000.00
# goodwill                                            -202,702,100,000.00
# intangibleAssets                                                   0.00
# goodwillAndIntangibleAssets                       -1,618,944,000,000.00
# longTermInvestments                                  -61,869,718,000.00
# taxAssets                                         -2,310,712,000,000.00
# otherNonCurrentAssets                                -68,662,600,000.00
# totalNonCurrentAssets                                              0.00
# otherAssets                                           -3,918,000,000.00
# totalAssets                                                    8,000.00
# accountPayables                                          -97,284,000.00
# shortTermDebt                                         -8,741,000,000.00
# taxPayables                                              -84,089,000.00
# deferredRevenue                                      -45,145,000,000.00
# otherCurrentLiabilities                              -18,528,000,000.00
# totalCurrentLiabilities                                            0.00
# longTermDebt                                                       0.00
# deferredRevenueNonCurrent                            -43,874,000,000.00
# deferredTaxLiabilitiesNonCurrent                      -1,300,000,000.00
# otherNonCurrentLiabilities                          -233,364,494,000.00
# totalNonCurrentLiabilities                                         0.00
# otherLiabilities                                      -2,000,224,000.00
# capitalLeaseObligations                                            0.00
# totalLiabilities                                                   0.00
# preferredStock                                                     0.00
# commonStock                                             -725,200,000.00
# retainedEarnings                                     -17,049,000,000.00
# accumulatedOtherComprehensiveIncomeLoss              -24,336,000,000.00
# othertotalStockholdersEquity                      -9,811,004,344,000.00
# totalStockholdersEquity                              -13,616,000,000.00
# totalEquity                                          -13,616,000,000.00
# totalLiabilitiesAndStockholdersEquity                          8,000.00
# minorityInterest                                        -286,000,000.00
# totalLiabilitiesAndTotalEquity                                 8,000.00
# totalInvestments                                     -27,337,000,000.00
# totalDebt                                                          0.00
# netDebt                                              -53,785,000,000.00
# cik_cash_flow_statement                                        1,800.00
# calendarYear_cash_flow_statement                               2,010.00
# period_cash_flow_statement                                         1.00
# netIncome                                             -7,870,000,000.00
# depreciationAndAmortization                             -876,000,000.00
# deferredIncomeTax                                    -53,034,000,000.00
# stockBasedCompensation                               -11,760,000,000.00
# changeInWorkingCapital                                -5,424,000,000.00
# accountsReceivables                                  -11,553,000,000.00
# inventory_cash_flow_statement                         -5,580,000,000.00
# accountsPayables                                    -252,402,000,000.00
# otherWorkingCapital                               -1,788,851,160,000.00
# otherNonCashItems                                 -1,848,719,007,000.00
# netCashProvidedByOperatingActivities                  -3,632,000,000.00
# investmentsInPropertyPlantAndEquipment               -29,876,000,000.00
# acquisitionsNet                                     -671,827,500,000.00
# purchasesOfInvestments                           -11,997,654,000,000.00
# salesMaturitiesOfInvestments                          -3,419,000,000.00
# otherInvestingActivites                              -61,468,000,000.00
# netCashUsedForInvestingActivites                     -61,468,000,000.00
# debtRepayment                                       -852,427,427,000.00
# commonStockIssued                                     -3,572,000,000.00
# commonStockRepurchased                            -2,086,545,366,000.00
# dividendsPaid                                        -98,706,821,000.00
# otherFinancingActivites                              -67,428,702,000.00
# netCashUsedProvidedByFinancingActivities             -17,235,000,000.00
# effectOfForexChangesOnCash                            -1,201,000,000.00
# netChangeInCash                                      -24,572,000,000.00
# cashAtEndOfPeriod                                             18,000.00
# cashAtBeginningOfPeriod                               -2,556,000,000.00
# operatingCashFlow                                     -3,632,000,000.00
# capitalExpenditure                                   -29,876,000,000.00
# freeCashFlow                                         -28,286,000,000.00
# cik_income_statement                                           1,800.00
# calendarYear_income_statement                                  2,010.00
# period_income_statement                                            1.00
# revenue                                               -6,646,000,000.00
# costOfRevenue                                         -4,822,000,000.00
# grossProfit                                           -7,195,000,000.00
# grossProfitRatio                                                 -17.88
# researchAndDevelopmentExpenses                          -214,000,000.00
# generalAndAdministrativeExpenses                      -2,738,500,000.00
# sellingAndMarketingExpenses                           -3,003,000,000.00
# sellingGeneralAndAdministrativeExpenses              -11,283,000,000.00
# otherExpenses                                         -3,318,538,000.00
# operatingExpenses                                     -2,976,356,000.00
# costAndExpenses                                       -5,794,000,000.00
# interestIncome                                          -204,000,000.00
# interestExpense                                         -669,000,000.00
# depreciationAndAmortization_income_statement          -1,550,000,000.00
# ebitda                                                -7,390,000,000.00
# ebitdaratio                                                      -44.29
# operatingIncome                                       -7,390,000,000.00
# operatingIncomeRatio                                             -20.35
# totalOtherIncomeExpensesNet                           -6,511,000,000.00
# incomeBeforeTax                                       -8,668,000,000.00
# incomeBeforeTaxRatio                                              -9.38
# incomeTaxExpense                                      -3,179,000,000.00
# netIncome_income_statement                            -7,213,000,000.00
# netIncomeRatio                                                    -8.88
# eps                                                             -156.36
# epsdiluted                                                      -156.36
# weightedAverageShsOut                                              0.00
# weightedAverageShsOutDil                                           0.00
# Rating on Next Earnings Call Date Rank AAA is 10                   2.00
# Change Before Next Call                                           -2.00
#
#                                                               25%  \
# days_until_next_earnings_call                               88.00
# Rating Rank AAA is 10                                        6.00
# Change in Rating                                             0.00
# Year                                                     2,012.00
# year                                                     2,013.00
# quarter                                                      2.00
# cik                                                     75,677.00
# calendarYear                                             2,013.00
# period                                                       2.00
# cashAndCashEquivalents                             133,942,000.00
# shortTermInvestments                                         0.00
# cashAndShortTermInvestments                        134,574,250.00
# netReceivables                                     293,770,250.00
# inventory                                          166,375,000.00
# otherCurrentAssets                                  51,598,750.00
# totalCurrentAssets                               1,053,683,250.00
# propertyPlantEquipmentNet                          577,575,000.00
# goodwill                                           154,275,000.00
# intangibleAssets                                    14,045,000.00
# goodwillAndIntangibleAssets                        330,725,000.00
# longTermInvestments                                          0.00
# taxAssets                                                    0.00
# otherNonCurrentAssets                               45,429,000.00
# totalNonCurrentAssets                            2,071,209,250.00
# otherAssets                                                  0.00
# totalAssets                                      3,496,069,750.00
# accountPayables                                    149,200,000.00
# shortTermDebt                                        7,787,250.00
# taxPayables                                                  0.00
# deferredRevenue                                              0.00
# otherCurrentLiabilities                            143,771,500.00
# totalCurrentLiabilities                            540,770,500.00
# longTermDebt                                       970,825,000.00
# deferredRevenueNonCurrent                                    0.00
# deferredTaxLiabilitiesNonCurrent                             0.00
# otherNonCurrentLiabilities                         111,630,500.00
# totalNonCurrentLiabilities                       1,437,500,000.00
# otherLiabilities                                             0.00
# capitalLeaseObligations                                      0.00
# totalLiabilities                                 2,170,291,750.00
# preferredStock                                               0.00
# commonStock                                            849,750.00
# retainedEarnings                                   324,558,000.00
# accumulatedOtherComprehensiveIncomeLoss           -502,925,000.00
# othertotalStockholdersEquity                      -110,156,250.00
# totalStockholdersEquity                          1,045,520,500.00
# totalEquity                                      1,045,520,500.00
# totalLiabilitiesAndStockholdersEquity            3,496,069,750.00
# minorityInterest                                             0.00
# totalLiabilitiesAndTotalEquity                   3,496,069,750.00
# totalInvestments                                             0.00
# totalDebt                                        1,068,780,250.00
# netDebt                                            573,851,405.07
# cik_cash_flow_statement                                 75,677.00
# calendarYear_cash_flow_statement                         2,013.00
# period_cash_flow_statement                                   2.00
# netIncome                                           22,000,000.00
# depreciationAndAmortization                         26,700,000.00
# deferredIncomeTax                                   -9,994,000.00
# stockBasedCompensation                               2,255,000.00
# changeInWorkingCapital                             -79,008,750.00
# accountsReceivables                                -33,925,000.00
# inventory_cash_flow_statement                      -24,003,250.00
# accountsPayables                                   -14,299,250.00
# otherWorkingCapital                                -29,934,750.00
# otherNonCashItems                                   -8,751,750.00
# netCashProvidedByOperatingActivities                56,124,750.00
# investmentsInPropertyPlantAndEquipment            -222,250,000.00
# acquisitionsNet                                    -18,764,750.00
# purchasesOfInvestments                              -9,925,000.00
# salesMaturitiesOfInvestments                                 0.00
# otherInvestingActivites                             -4,032,500.00
# netCashUsedForInvestingActivites                  -301,550,000.00
# debtRepayment                                     -309,500,000.00
# commonStockIssued                                            0.00
# commonStockRepurchased                             -94,925,000.00
# dividendsPaid                                      -98,350,000.00
# otherFinancingActivites                             -2,000,000.00
# netCashUsedProvidedByFinancingActivities          -235,121,750.00
# effectOfForexChangesOnCash                          -4,466,500.00
# netChangeInCash                                    -74,231,000.00
# cashAtEndOfPeriod                                  133,696,250.00
# cashAtBeginningOfPeriod                            132,530,000.00
# operatingCashFlow                                   56,124,750.00
# capitalExpenditure                                -222,250,000.00
# freeCashFlow                                        -6,923,000.00
# cik_income_statement                                    75,677.00
# calendarYear_income_statement                            2,013.00
# period_income_statement                                      2.00
# revenue                                            632,090,750.00
# costOfRevenue                                      361,758,500.00
# grossProfit                                        187,950,000.00
# grossProfitRatio                                             0.20
# researchAndDevelopmentExpenses                               0.00
# generalAndAdministrativeExpenses                             0.00
# sellingAndMarketingExpenses                                  0.00
# sellingGeneralAndAdministrativeExpenses             67,340,500.00
# otherExpenses                                         -536,500.00
# operatingExpenses                                  105,150,000.00
# costAndExpenses                                    539,946,000.00
# interestIncome                                               0.00
# interestExpense                                     11,506,500.00
# depreciationAndAmortization_income_statement        27,000,000.00
# ebitda                                              92,460,000.00
# ebitdaratio                                                  0.10
# operatingIncome                                     54,515,750.00
# operatingIncomeRatio                                         0.05
# totalOtherIncomeExpensesNet                        -24,058,750.00
# incomeBeforeTax                                     32,185,250.00
# incomeBeforeTaxRatio                                         0.03
# incomeTaxExpense                                     6,321,750.00
# netIncome_income_statement                          22,461,500.00
# netIncomeRatio                                               0.02
# eps                                                          0.21
# epsdiluted                                                   0.21
# weightedAverageShsOut                               75,697,500.00
# weightedAverageShsOutDil                            76,834,750.00
# Rating on Next Earnings Call Date Rank AAA is 10             6.00
# Change Before Next Call                                      0.00
#
#                                                               50%  \
# days_until_next_earnings_call                               91.00
# Rating Rank AAA is 10                                        7.00
# Change in Rating                                             0.00
# Year                                                     2,013.00
# year                                                     2,015.00
# quarter                                                      3.00
# cik                                                    833,079.00
# calendarYear                                             2,015.00
# period                                                       3.00
# cashAndCashEquivalents                             432,800,000.00
# shortTermInvestments                                         0.00
# cashAndShortTermInvestments                        478,750,000.00
# netReceivables                                     703,726,000.00
# inventory                                          575,900,000.00
# otherCurrentAssets                                 146,800,000.00
# totalCurrentAssets                               2,397,358,500.00
# propertyPlantEquipmentNet                        1,617,229,500.00
# goodwill                                           935,900,000.00
# intangibleAssets                                   295,000,000.00
# goodwillAndIntangibleAssets                      1,427,458,500.00
# longTermInvestments                                    404,500.00
# taxAssets                                           51,692,000.00
# otherNonCurrentAssets                              202,000,000.00
# totalNonCurrentAssets                            5,075,849,000.00
# otherAssets                                                  0.00
# totalAssets                                      7,838,862,500.00
# accountPayables                                    433,450,000.00
# shortTermDebt                                       89,027,000.00
# taxPayables                                          2,093,000.00
# deferredRevenue                                     29,967,500.00
# otherCurrentLiabilities                            390,850,000.00
# totalCurrentLiabilities                          1,345,331,000.00
# longTermDebt                                     2,339,100,000.00
# deferredRevenueNonCurrent                                    0.00
# deferredTaxLiabilitiesNonCurrent                   143,616,000.00
# otherNonCurrentLiabilities                         382,550,000.00
# totalNonCurrentLiabilities                       3,323,471,500.00
# otherLiabilities                                             0.00
# capitalLeaseObligations                                      0.00
# totalLiabilities                                 4,967,834,000.00
# preferredStock                                               0.00
# commonStock                                          4,786,000.00
# retainedEarnings                                 1,691,531,000.00
# accumulatedOtherComprehensiveIncomeLoss           -133,049,500.00
# othertotalStockholdersEquity                       418,850,000.00
# totalStockholdersEquity                          2,442,324,000.00
# totalEquity                                      2,442,324,000.00
# totalLiabilitiesAndStockholdersEquity            7,838,862,500.00
# minorityInterest                                     4,859,000.00
# totalLiabilitiesAndTotalEquity                   7,838,862,500.00
# totalInvestments                                    24,054,500.00
# totalDebt                                        2,550,009,500.00
# netDebt                                          1,687,450,000.00
# cik_cash_flow_statement                                833,079.00
# calendarYear_cash_flow_statement                         2,015.00
# period_cash_flow_statement                                   3.00
# netIncome                                           84,606,500.00
# depreciationAndAmortization                         67,926,500.00
# deferredIncomeTax                                            0.00
# stockBasedCompensation                               7,000,000.00
# changeInWorkingCapital                              -4,000,000.00
# accountsReceivables                                          0.00
# inventory_cash_flow_statement                                0.00
# accountsPayables                                             0.00
# otherWorkingCapital                                          0.00
# otherNonCashItems                                    2,500,000.00
# netCashProvidedByOperatingActivities               175,674,000.00
# investmentsInPropertyPlantAndEquipment             -65,297,000.00
# acquisitionsNet                                              0.00
# purchasesOfInvestments                                       0.00
# salesMaturitiesOfInvestments                                 0.00
# otherInvestingActivites                                100,000.00
# netCashUsedForInvestingActivites                   -77,620,000.00
# debtRepayment                                      -41,309,500.00
# commonStockIssued                                            0.00
# commonStockRepurchased                              -2,252,500.00
# dividendsPaid                                      -24,613,500.00
# otherFinancingActivites                              8,400,000.00
# netCashUsedProvidedByFinancingActivities           -50,314,332.02
# effectOfForexChangesOnCash                                   0.00
# netChangeInCash                                        855,500.00
# cashAtEndOfPeriod                                  436,165,500.00
# cashAtBeginningOfPeriod                            431,629,500.00
# operatingCashFlow                                  175,674,000.00
# capitalExpenditure                                 -65,297,000.00
# freeCashFlow                                        76,000,000.00
# cik_income_statement                                   833,079.00
# calendarYear_income_statement                            2,015.00
# period_income_statement                                      3.00
# revenue                                          1,539,994,500.00
# costOfRevenue                                      933,300,000.00
# grossProfit                                        434,840,500.00
# grossProfitRatio                                             0.33
# researchAndDevelopmentExpenses                               0.00
# generalAndAdministrativeExpenses                    53,799,000.00
# sellingAndMarketingExpenses                                  0.00
# sellingGeneralAndAdministrativeExpenses            186,129,500.00
# otherExpenses                                          300,000.00
# operatingExpenses                                  253,823,468.78
# costAndExpenses                                  1,354,553,000.00
# interestIncome                                               0.00
# interestExpense                                     24,958,500.00
# depreciationAndAmortization_income_statement        68,340,000.00
# ebitda                                             232,000,000.00
# ebitdaratio                                                  0.16
# operatingIncome                                    155,111,500.00
# operatingIncomeRatio                                         0.11
# totalOtherIncomeExpensesNet                         -2,386,000.00
# incomeBeforeTax                                    116,384,000.00
# incomeBeforeTaxRatio                                         0.09
# incomeTaxExpense                                    33,000,000.00
# netIncome_income_statement                          86,000,000.00
# netIncomeRatio                                               0.06
# eps                                                          0.59
# epsdiluted                                                   0.58
# weightedAverageShsOut                              152,439,026.00
# weightedAverageShsOutDil                           156,455,500.00
# Rating on Next Earnings Call Date Rank AAA is 10             7.00
# Change Before Next Call                                      0.00
#
#                                                                75%  \
# days_until_next_earnings_call                                96.00
# Rating Rank AAA is 10                                         8.00
# Change in Rating                                              0.00
# Year                                                      2,015.00
# year                                                      2,016.00
# quarter                                                       4.00
# cik                                                   1,101,239.00
# calendarYear                                              2,016.00
# period                                                        4.00
# cashAndCashEquivalents                            1,367,546,250.00
# shortTermInvestments                                 17,900,000.00
# cashAndShortTermInvestments                       1,566,396,250.00
# netReceivables                                    1,865,898,000.00
# inventory                                         1,591,138,000.00
# otherCurrentAssets                                  453,372,250.00
# totalCurrentAssets                                5,761,285,250.00
# propertyPlantEquipmentNet                         5,346,944,000.00
# goodwill                                          3,070,700,000.00
# intangibleAssets                                  1,196,100,000.00
# goodwillAndIntangibleAssets                       4,454,029,450.23
# longTermInvestments                                 260,197,500.00
# taxAssets                                           341,850,000.00
# otherNonCurrentAssets                               668,000,000.00
# totalNonCurrentAssets                            13,013,712,250.00
# otherAssets                                                   0.00
# totalAssets                                      19,988,500,000.00
# accountPayables                                   1,378,950,750.00
# shortTermDebt                                       516,400,000.00
# taxPayables                                          52,000,000.00
# deferredRevenue                                     305,000,000.00
# otherCurrentLiabilities                           1,184,600,500.00
# totalCurrentLiabilities                           3,957,850,000.00
# longTermDebt                                      5,224,625,000.00
# deferredRevenueNonCurrent                           104,012,750.00
# deferredTaxLiabilitiesNonCurrent                    741,875,000.00
# otherNonCurrentLiabilities                        1,111,786,250.00
# totalNonCurrentLiabilities                        7,880,925,000.00
# otherLiabilities                                              0.00
# capitalLeaseObligations                                       0.00
# totalLiabilities                                 12,635,349,500.00
# preferredStock                                                0.00
# commonStock                                         151,229,500.00
# retainedEarnings                                  5,695,875,000.00
# accumulatedOtherComprehensiveIncomeLoss              -5,882,000.00
# othertotalStockholdersEquity                      2,283,250,000.00
# totalStockholdersEquity                           6,734,464,000.00
# totalEquity                                       6,781,925,000.00
# totalLiabilitiesAndStockholdersEquity            19,988,500,000.00
# minorityInterest                                     84,150,250.00
# totalLiabilitiesAndTotalEquity                   19,988,500,000.00
# totalInvestments                                    447,300,000.00
# totalDebt                                         5,928,608,500.00
# netDebt                                           4,208,547,750.00
# cik_cash_flow_statement                               1,101,239.00
# calendarYear_cash_flow_statement                          2,016.00
# period_cash_flow_statement                                    4.00
# netIncome                                           275,041,750.00
# depreciationAndAmortization                         195,388,500.00
# deferredIncomeTax                                    11,871,750.00
# stockBasedCompensation                               17,000,000.00
# changeInWorkingCapital                               57,000,000.00
# accountsReceivables                                  13,448,000.00
# inventory_cash_flow_statement                        10,000,500.00
# accountsPayables                                     24,610,750.00
# otherWorkingCapital                                  37,149,750.00
# otherNonCashItems                                    30,028,750.00
# netCashProvidedByOperatingActivities                524,325,000.00
# investmentsInPropertyPlantAndEquipment              -24,399,750.00
# acquisitionsNet                                               0.00
# purchasesOfInvestments                                        0.00
# salesMaturitiesOfInvestments                         15,224,250.00
# otherInvestingActivites                               7,700,000.00
# netCashUsedForInvestingActivites                    -21,130,500.00
# debtRepayment                                        -1,000,000.00
# commonStockIssued                                    22,152,500.00
# commonStockRepurchased                                        0.00
# dividendsPaid                                        -1,800,000.00
# otherFinancingActivites                             211,100,000.00
# netCashUsedProvidedByFinancingActivities              6,639,000.00
# effectOfForexChangesOnCash                              600,000.00
# netChangeInCash                                      77,994,750.00
# cashAtEndOfPeriod                                 1,368,138,500.00
# cashAtBeginningOfPeriod                           1,347,472,750.00
# operatingCashFlow                                   524,325,000.00
# capitalExpenditure                                  -24,399,750.00
# freeCashFlow                                        273,150,250.00
# cik_income_statement                                  1,101,239.00
# calendarYear_income_statement                             2,016.00
# period_income_statement                                       4.00
# revenue                                           3,787,500,000.00
# costOfRevenue                                     2,170,154,819.53
# grossProfit                                       1,187,304,000.00
# grossProfitRatio                                              0.49
# researchAndDevelopmentExpenses                                0.00
# generalAndAdministrativeExpenses                    240,024,500.00
# sellingAndMarketingExpenses                                   0.00
# sellingGeneralAndAdministrativeExpenses             465,398,250.00
# otherExpenses                                        10,952,750.00
# operatingExpenses                                   687,950,000.00
# costAndExpenses                                   3,190,175,000.00
# interestIncome                                        1,525,250.00
# interestExpense                                      57,000,000.00
# depreciationAndAmortization_income_statement        192,472,750.00
# ebitda                                              643,600,000.00
# ebitdaratio                                                   0.24
# operatingIncome                                     433,700,000.00
# operatingIncomeRatio                                          0.17
# totalOtherIncomeExpensesNet                           3,900,000.00
# incomeBeforeTax                                     387,473,250.00
# incomeBeforeTaxRatio                                          0.15
# incomeTaxExpense                                    110,000,000.00
# netIncome_income_statement                          279,498,250.00
# netIncomeRatio                                                0.11
# eps                                                           1.10
# epsdiluted                                                    1.07
# weightedAverageShsOut                               421,025,000.00
# weightedAverageShsOutDil                            426,947,500.00
# Rating on Next Earnings Call Date Rank AAA is 10              8.00
# Change Before Next Call                                       0.00
#
#                                                                    max
# days_until_next_earnings_call                                   840.00
# Rating Rank AAA is 10                                            10.00
# Change in Rating                                                  3.00
# Year                                                          2,016.00
# year                                                          2,019.00
# quarter                                                           4.00
# cik                                                       1,841,666.00
# calendarYear                                                  2,019.00
# period                                                            4.00
# cashAndCashEquivalents                              145,144,000,000.00
# shortTermInvestments                             10,000,000,000,000.00
# cashAndShortTermInvestments                         152,614,000,000.00
# netReceivables                                       36,635,000,000.00
# inventory                                            18,568,000,000.00
# otherCurrentAssets                                   30,569,000,000.00
# totalCurrentAssets                                  186,394,000,000.00
# propertyPlantEquipmentNet                           255,257,000,000.00
# goodwill                                            129,539,000,000.00
# intangibleAssets                                    202,835,000,000.00
# goodwillAndIntangibleAssets                         152,412,000,000.00
# longTermInvestments                                 157,432,000,000.00
# taxAssets                                         1,618,944,000,000.00
# otherNonCurrentAssets                             2,310,712,000,000.00
# totalNonCurrentAssets                               357,320,000,000.00
# otherAssets                                          13,789,000,000.00
# totalAssets                                         543,714,000,000.00
# accountPayables                                      59,084,000,000.00
# shortTermDebt                                        25,374,000,000.00
# taxPayables                                         214,934,000,000.00
# deferredRevenue                                      28,143,000,000.00
# otherCurrentLiabilities                              59,084,000,000.00
# totalCurrentLiabilities                             107,006,000,000.00
# longTermDebt                                         82,575,000,000.00
# deferredRevenueNonCurrent                           233,475,000,000.00
# deferredTaxLiabilitiesNonCurrent                     41,132,000,000.00
# otherNonCurrentLiabilities                           46,718,000,000.00
# totalNonCurrentLiabilities                          115,565,000,000.00
# otherLiabilities                                     53,949,000,000.00
# capitalLeaseObligations                           9,056,234,000,000.00
# totalLiabilities                                    199,309,000,000.00
# preferredStock                                        8,320,000,000.00
# commonStock                                       9,817,134,000,000.00
# retainedEarnings                                    412,718,000,000.00
# accumulatedOtherComprehensiveIncomeLoss              14,109,000,000.00
# othertotalStockholdersEquity                      1,133,816,000,000.00
# totalStockholdersEquity                             298,620,000,000.00
# totalEquity                                         298,620,000,000.00
# totalLiabilitiesAndStockholdersEquity               543,714,000,000.00
# minorityInterest                                     59,194,000,000.00
# totalLiabilitiesAndTotalEquity                      543,714,000,000.00
# totalInvestments                                 10,000,800,995,000.00
# totalDebt                                            93,318,000,000.00
# netDebt                                              63,168,000,000.00
# cik_cash_flow_statement                                   1,841,666.00
# calendarYear_cash_flow_statement                              2,019.00
# period_cash_flow_statement                                        4.00
# netIncome                                            22,754,000,000.00
# depreciationAndAmortization                           9,255,000,000.00
# deferredIncomeTax                                 1,850,454,000,000.00
# stockBasedCompensation                                9,093,000,000.00
# changeInWorkingCapital                                7,877,000,000.00
# accountsReceivables                                   9,572,000,000.00
# inventory_cash_flow_statement                         6,514,000,000.00
# accountsPayables                                  1,789,652,000,000.00
# otherWorkingCapital                                 252,155,313,000.00
# otherNonCashItems                                    52,974,615,000.00
# netCashProvidedByOperatingActivities                 37,416,000,000.00
# investmentsInPropertyPlantAndEquipment                  546,000,000.00
# acquisitionsNet                                      13,891,000,000.00
# purchasesOfInvestments                               81,823,000,000.00
# salesMaturitiesOfInvestments                      8,936,406,000,000.00
# otherInvestingActivites                           3,060,433,659,000.00
# netCashUsedForInvestingActivites                     11,398,000,000.00
# debtRepayment                                            54,579,000.00
# commonStockIssued                                 1,111,490,728,000.00
# commonStockRepurchased                              310,240,449,000.00
# dividendsPaid                                                     0.00
# otherFinancingActivites                           1,845,316,165,000.00
# netCashUsedProvidedByFinancingActivities             25,372,000,000.00
# effectOfForexChangesOnCash                           19,418,000,000.00
# netChangeInCash                                      30,305,000,000.00
# cashAtEndOfPeriod                                   145,144,000,000.00
# cashAtBeginningOfPeriod                             143,736,000,000.00
# operatingCashFlow                                    37,416,000,000.00
# capitalExpenditure                                      546,000,000.00
# freeCashFlow                                         37,416,000,000.00
# cik_income_statement                                      1,841,666.00
# calendarYear_income_statement                                 2,019.00
# period_income_statement                                           4.00
# revenue                                             123,712,000,000.00
# costOfRevenue                                        88,168,000,000.00
# grossProfit                                          47,581,000,000.00
# grossProfitRatio                                                  5.00
# researchAndDevelopmentExpenses                        4,696,000,000.00
# generalAndAdministrativeExpenses                     11,283,000,000.00
# sellingAndMarketingExpenses                           4,850,000,000.00
# sellingGeneralAndAdministrativeExpenses               8,529,000,000.00
# otherExpenses                                    16,189,674,590,000.00
# operatingExpenses                                    22,217,000,000.00
# costAndExpenses                                     106,431,000,000.00
# interestIncome                                       18,150,000,000.00
# interestExpense                                       1,873,900,000.00
# depreciationAndAmortization_income_statement          9,255,000,000.00
# ebitda                                               26,439,000,000.00
# ebitdaratio                                                       6.05
# operatingIncome                                      22,540,000,000.00
# operatingIncomeRatio                                             11.48
# totalOtherIncomeExpensesNet                          10,373,000,000.00
# incomeBeforeTax                                      26,191,000,000.00
# incomeBeforeTaxRatio                                             12.07
# incomeTaxExpense                                      8,537,000,000.00
# netIncome_income_statement                           22,754,000,000.00
# netIncomeRatio                                                   26.12
# eps                                                              53.75
# epsdiluted                                                       49.73
# weightedAverageShsOut                                13,752,711,890.00
# weightedAverageShsOutDil                             13,986,214,405.00
# Rating on Next Earnings Call Date Rank AAA is 10                 10.00
# Change Before Next Call                                           2.00

# %%
# Revert to default settings
pd.reset_option('display.float_format')
pd.reset_option('display.max_rows')

# %%
# Check data is unique on ticker by earnings_call_date
df['ticker_earnings_date'] = df['ticker'] + '_' + df['earnings_call_date'].astype(str)
df['ticker_earnings_date'].value_counts().max()
# Out:
# 1

# %%
# Number of unique firms (identified by ticker)
df['ticker'].nunique()
# Out:
# 319

# %%
# Histogram of count of earnings calls by ticker/firm
# Title: Histogram of Count of Earnings Calls by Ticker
plt.hist(df['ticker'].value_counts(), bins = 100)
plt.title('Histogram of Count of Earnings Calls by Ticker/Firm')
plt.show()

# %%
# Distribution of industry sectors
# variable sector
# Title: Calls in Each Industry Sector
df['sector'].value_counts().plot(kind = 'barh', color = 'skyblue')
plt.title('Calls in Each Industry Sector')
plt.show()

# %%
# Number of firms in each industry sector
# Title: Number of Firms in Each Industry Sector
# Unique ticker by sector, sort by number of firms
df.groupby('sector')['ticker'].nunique().sort_values(ascending=False).plot(kind = 'barh', color = 'green')
plt.title('Number of Firms in Each Industry Sector')
plt.show()

# %%
# Distribution of earnings_call_date
# Create call_year and call_quarter columns after converting earnings_call_date to datetime
df['call_year'] = pd.to_datetime(df['earnings_call_date']).dt.year
df['call_quarter'] = pd.to_datetime(df['earnings_call_date']).dt.quarter
# Group by year and quarter
data_grouped = df.groupby([df.call_year, df.call_quarter]).size().sort_index(ascending=False)
# Plot horizontal bar chart
# 2010 at the top
data_grouped.plot(kind='barh')
plt.title('Calls Per Year, Quarter')
plt.xlabel('Count')
plt.ylabel('Year, Quarter')
plt.show()

# %%
# Company dropout
# For each ticker, get the max value of earnings_call_date, and print out items where it is not in the last quarter of 2016
# Convert earnings_call_date to datetime
df['earnings_call_date_dt'] = pd.to_datetime(df['earnings_call_date'])
# Add column max_date to df
df['max_date'] = df.groupby('ticker')['earnings_call_date_dt'].transform('max')
# Display rows where max_date is not in the last quarter of 2016
df[df['max_date'] < '2016-10-01']
# Out:
#      ticker earnings_call_date next_earnings_call_date  \
# 143    AMCR         2016-08-25                    None
# 495     BTU         2011-10-25              2012-04-19
# 496     BTU         2012-04-19              2012-07-24
# 497     BTU         2012-07-24              2012-10-22
# 498     BTU         2012-10-22              2013-01-29
# ...     ...                ...                     ...
# 3887   STON         2013-08-07              2013-11-08
# 3888   STON         2013-11-08              2014-03-14
# 3889   STON         2014-03-14              2014-05-08
# 3890   STON         2014-05-08              2015-05-08
# 3891   STON         2015-05-08                    None
#
#      rating_on_next_earnings_call_date  days_until_next_earnings_call Rating  \
# 143                               None                            NaN    BBB
# 495                                 BB                          177.0     BB
# 496                                 BB                           96.0     BB
# 497                                  B                           90.0     BB
# 498                                  B                           99.0      B
# ...                                ...                            ...    ...
# 3887                                 B                           93.0      B
# 3888                                 B                          126.0      B
# 3889                                 B                           55.0      B
# 3890                                 B                          365.0      B
# 3891                              None                            NaN      B
#
#                       Rating Agency Name rating_date         Source  \
# 143   Standard & Poor's Ratings Services  2016-03-23  Supplementary
# 495   Standard & Poor's Ratings Services  2011-08-31  Supplementary
# 496   Standard & Poor's Ratings Services  2011-08-31  Supplementary
# 497   Standard & Poor's Ratings Services  2011-08-31  Supplementary
# 498   Standard & Poor's Ratings Services  2012-08-31  Supplementary
# ...                                  ...         ...            ...
# 3887  Standard & Poor's Ratings Services  2013-05-13  Supplementary
# 3888  Standard & Poor's Ratings Services  2013-09-11  Supplementary
# 3889  Standard & Poor's Ratings Services  2014-03-06  Supplementary
# 3890  Standard & Poor's Ratings Services  2014-03-06  Supplementary
# 3891  Standard & Poor's Ratings Services  2015-03-10  Supplementary
#
#       Rating Rank AAA is 10  ...  \
# 143                       7  ...
# 495                       6  ...
# 496                       6  ...
# 497                       6  ...
# 498                       5  ...
# ...                     ...  ...
# 3887                      5  ...
# 3888                      5  ...
# 3889                      5  ...
# 3890                      5  ...
# 3891                      5  ...
#
#                                   link_income_statement  \
# 143   https://www.sec.gov/Archives/edgar/data/174879...
# 495   https://www.sec.gov/Archives/edgar/data/106472...
# 496   https://www.sec.gov/Archives/edgar/data/106472...
# 497   https://www.sec.gov/Archives/edgar/data/106472...
# 498   https://www.sec.gov/Archives/edgar/data/106472...
# ...                                                 ...
# 3887                                               None
# 3888                                               None
# 3889                                               None
# 3890                                               None
# 3891                                               None
#
#                              finalLink_income_statement  \
# 143   https://www.sec.gov/Archives/edgar/data/174879...
# 495   https://www.sec.gov/Archives/edgar/data/106472...
# 496   https://www.sec.gov/Archives/edgar/data/106472...
# 497   https://www.sec.gov/Archives/edgar/data/106472...
# 498   https://www.sec.gov/Archives/edgar/data/106472...
# ...                                                 ...
# 3887                                               None
# 3888                                               None
# 3889                                               None
# 3890                                               None
# 3891                                               None
#
#      Rating on Next Earnings Call Date Rank AAA is 10  \
# 143                                               NaN
# 495                                               6.0
# 496                                               6.0
# 497                                               5.0
# 498                                               5.0
# ...                                               ...
# 3887                                              5.0
# 3888                                              5.0
# 3889                                              5.0
# 3890                                              5.0
# 3891                                              NaN
#
#      Change Direction Before Next Call Change Before Next Call  \
# 143                               None                     NaN
# 495                  Same At Next Call                     0.0
# 496                  Same At Next Call                     0.0
# 497         Downgrade Before Next Call                    -1.0
# 498                  Same At Next Call                     0.0
# ...                                ...                     ...
# 3887                 Same At Next Call                     0.0
# 3888                 Same At Next Call                     0.0
# 3889                 Same At Next Call                     0.0
# 3890                 Same At Next Call                     0.0
# 3891                              None                     NaN
#
#      ticker_earnings_date  call_year  call_quarter earnings_call_date_dt  \
# 143       AMCR_2016-08-25       2016             3            2016-08-25
# 495        BTU_2011-10-25       2011             4            2011-10-25
# 496        BTU_2012-04-19       2012             2            2012-04-19
# 497        BTU_2012-07-24       2012             3            2012-07-24
# 498        BTU_2012-10-22       2012             4            2012-10-22
# ...                   ...        ...           ...                   ...
# 3887      STON_2013-08-07       2013             3            2013-08-07
# 3888      STON_2013-11-08       2013             4            2013-11-08
# 3889      STON_2014-03-14       2014             1            2014-03-14
# 3890      STON_2014-05-08       2014             2            2014-05-08
# 3891      STON_2015-05-08       2015             2            2015-05-08
#
#        max_date
# 143  2016-08-25
# 495  2016-02-11
# 496  2016-02-11
# 497  2016-02-11
# 498  2016-02-11
# ...         ...
# 3887 2015-05-08
# 3888 2015-05-08
# 3889 2015-05-08
# 3890 2015-05-08
# 3891 2015-05-08
#
# [177 rows x 166 columns]

# %%
# Unique firms where this is the case
df[df['max_date'] < '2016-10-01'][['ticker', 'max_date']].drop_duplicates()
# Out:
#      ticker   max_date
# 143    AMCR 2016-08-25
# 495     BTU 2016-02-11
# 1598    FTI 2016-04-30
# 2257    KBH 2016-09-21
# 2687    MKC 2016-09-30
# 2742    MOS 2016-08-02
# 3056    NUE 2016-07-22
# 3267    PEP 2016-09-29
# 3318    PKG 2016-07-21
# 3496    RFP 2016-08-06
# 3887   STON 2015-05-08

# %% [markdown]
# AMCR is amcor, should still exist but it's date is kind of close to the end of 2016
#
# BTU, peabody energy, seems to have gone bankrupt April 13, 2016
#
# FTI underwent a merger in 2016-2017
#
# KBH still exists, but again the date is pretty close...
#
# The other non-close one is STON. Notably, StonMor Partners had some issues with delayed SEC filings https://seekingalpha.com/article/4056108-prelude-to-bankruptcy-saving-grace-stonemor-partners-delays-10-k-again

# %%
# Distribution of Rating and rating_on_next_earnings_call_date

# Colored with gradient and ordered

# Colors AAA through D
# Used https://colordesigner.io/gradient-generator#google_vignette
# Assign hex codes from green to red
#32671d
#416703
#516600
#626400
#756000
#885b00
#9c5200
#af4500
#c33200
#d60000
hex_code_mapper = {'AAA': '#32671d', 'AA': '#416703', 'A': '#516600', 'BBB': '#626400', 'BB': '#756000', 'B': '#885b00', 'CCC': '#9c5200', 'CC': '#af4500', 'C': '#c33200', 'D': '#d60000'}

# Ordering of bars - keys from hex_code_mapper
bar_order = ['AAA', 'AA', 'A', 'BBB', 'BB', 'B', 'CCC', 'CC', 'C', 'D']
# Assign values of Rating to this ordering
df['Rating'] = pd.Categorical(df['Rating'], categories=bar_order, ordered=True)

# Create plot
# Save to "../Output/Distribution of Ratings.png"
plt.bar(df['Rating'].value_counts().sort_index().index, df['Rating'].value_counts().sort_index(), color=[hex_code_mapper[i] for i in bar_order])
plt.title('Rating on Earnings Call Date')
#plt.savefig('../../Output/Distribution of Rating Issuances.png')
plt.show()

# Rating on next earnings call date
df['rating_on_next_earnings_call_date'] = pd.Categorical(df['rating_on_next_earnings_call_date'], categories=bar_order, ordered=True)
plt.bar(df['rating_on_next_earnings_call_date'].value_counts().sort_index().index, df['rating_on_next_earnings_call_date'].value_counts().sort_index(), color=[hex_code_mapper[i] for i in bar_order])
plt.title('Rating on Next Earnings Call Date')
#plt.savefig('../../Output/Distribution of Rating on Next Earnings Call Date.png')
plt.show()

# %%
# Bar chart of 'Change Direction Before Next Call'
df['Change Direction Before Next Call'].value_counts().plot(kind='barh')
plt.title('Change Direction Before Next Call')
plt.show()
print(df['Change Direction Before Next Call'].value_counts())

# Bar chart of 'Change Before Next Call'
df['Change Before Next Call'].value_counts().sort_index().plot(kind='barh')
plt.title('Change Before Next Call')
plt.show()
print(df['Change Before Next Call'].value_counts().sort_index())
# Out:
# Change Direction Before Next Call
# Same At Next Call             3981
# Upgrade Before Next Call       130
# Downgrade Before Next Call     102
# Name: count, dtype: int64
# Change Before Next Call
# -2.0       9
# -1.0      93
#  0.0    3981
#  1.0     117
#  2.0      13
# Name: count, dtype: int64

# %%
# Calculate the mean of "totalAssets" for each kind of "Rating"
mean_assets_by_rating = df.groupby('Rating')['totalDebt'].mean()

# Plotting
mean_assets_by_rating.plot(kind='bar')
plt.title('Mean Total Assets for each Rating')
plt.xlabel('Rating')
plt.ylabel('Mean Total Assets')
plt.show()
# Out:
# C:\Users\ijyli\AppData\Local\Temp\ipykernel_11612\3119831694.py:2: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   mean_assets_by_rating = df.groupby('Rating')['totalDebt'].mean()

# %%
# Calculate the mean of "grossProfitRatio" for each kind of "Rating"
mean_gross_profit_by_rating = df.groupby('Rating')["grossProfitRatio"].mean()

# Plotting
mean_assets_by_rating.plot(kind='bar')
plt.title('Mean Gross Profit Ratio for each Rating')
plt.xlabel('Rating')
plt.ylabel('Mean Gross Profit Ratio ')
plt.show()
# Out:
# C:\Users\ijyli\AppData\Local\Temp\ipykernel_11612\796684613.py:2: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   mean_gross_profit_by_rating = df.groupby('Rating')["grossProfitRatio"].mean()

# %% [markdown]
# We can see the relationship between rating and total assets; rating and gross profit ratio. High rating like AAA will have high mean total assets and high mean gross profit ratio.
