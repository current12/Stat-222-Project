# %% [markdown]
# # Credit Ratings EDA

# %%
# Packages
import pandas as pd
import matplotlib.pyplot as plt

# %%
# Load combined data into pandas
# C:\Users\ijyli\Box\STAT 222 Capstone\Intermediate Data\combined_credit_rating_data.csv
corporate_rating = pd.read_csv('~\Box\STAT 222 Capstone\Intermediate Data/Credit_Rating\combined_credit_rating_data.csv')
corporate_rating
# Out:
#      Rating Symbol                  Rating Agency Name        Date  \
# 0       BBB    BCE                                DBRS  2016-08-08
# 1       BBB    BEP                                DBRS  2015-11-09
# 2       BBB    BEP                                DBRS  2015-11-25
# 3         A    CCJ                                DBRS  2016-06-03
# 4         A   COST                                DBRS  2014-05-20
# ...     ...    ...                                 ...         ...
# 8727    BBB    ZTS  Standard & Poor's Ratings Services  2014-01-31
# 8728    BBB    ZTS  Standard & Poor's Ratings Services  2015-01-30
# 8729    BBB    ZTS  Standard & Poor's Ratings Services  2015-11-03
# 8730    BBB    ZTS  Standard & Poor's Ratings Services  2016-01-22
# 8731    BBB    ZTS  Standard & Poor's Ratings Services  2016-12-23
#
#              Source  Rating Rank AAA is 10 Next Rating Next Rating Date  \
# 0              Both                      7         NaN              NaN
# 1     Supplementary                      7         BBB       2015-11-25
# 2     Supplementary                      7         NaN              NaN
# 3     Supplementary                      8         NaN              NaN
# 4     Supplementary                      8         NaN              NaN
# ...             ...                    ...         ...              ...
# 8727           Both                      7         BBB       2015-01-30
# 8728           Both                      7         BBB       2015-11-03
# 8729  Supplementary                      7         BBB       2016-01-22
# 8730           Both                      7         BBB       2016-12-23
# 8731       Original                      7         NaN              NaN
#
#      Previous Rating Previous Rating Date Next Rating Date or End of Data  \
# 0                NaN                  NaN                      2016-12-31
# 1                NaN                  NaN                      2015-11-25
# 2                BBB           2015-11-09                      2016-12-31
# 3                NaN                  NaN                      2016-12-31
# 4                NaN                  NaN                      2016-12-31
# ...              ...                  ...                             ...
# 8727             BBB           2013-10-11                      2015-01-30
# 8728             BBB           2014-01-31                      2015-11-03
# 8729             BBB           2015-01-30                      2016-01-22
# 8730             BBB           2015-11-03                      2016-12-23
# 8731             BBB           2016-01-22                      2016-12-31
#
#              Type  Change in Rating
# 0       Ambiguous               NaN
# 1       Ambiguous               NaN
# 2     Affirmation               0.0
# 3       Ambiguous               NaN
# 4       Ambiguous               NaN
# ...           ...               ...
# 8727  Affirmation               0.0
# 8728  Affirmation               0.0
# 8729  Affirmation               0.0
# 8730  Affirmation               0.0
# 8731  Affirmation               0.0
#
# [8732 rows x 13 columns]

# %%
# Load Sectors
company_sectors = pd.read_csv('~/Box\STAT 222 Capstone\Intermediate Data\Sectors\combined_sector_data.csv')
company_sectors
# Out:
#      Ticker                                        Description  \
# 0      CTVA  Corteva, Inc. is a global provider of seed and...
# 1      ALCO  Alico, Inc. is an agribusiness and land manage...
# 2      LMNR  Limoneira Company is primarily an agribusiness...
# 3      SANW  S&W Seed Company (S&W) is a multi-crop and mid...
# 4       TRC  Tejon Ranch Co. is a diversified real estate d...
# ...     ...                                                ...
# 3384   RELX                                                NaN
# 3385    TAL                                                NaN
# 3386   TRTN                                                NaN
# 3387   VLRS                                                NaN
# 3388    XIN                                                NaN
#
#         Company Name                  Sector            Industry Group  \
# 0        CORTEVA INC               Materials                 Materials
# 1          ALICO INC        Consumer Staples  Food, Beverage & Tobacco
# 2       LIMONEIRA CO        Consumer Staples  Food, Beverage & Tobacco
# 3        S&W SEED CO        Consumer Staples  Food, Beverage & Tobacco
# 4     TEJON RANCH CO             Real Estate               Real Estate
# ...              ...                     ...                       ...
# 3384             NaN  Information Technology                       NaN
# 3385             NaN  Consumer Discretionary                       NaN
# 3386             NaN             Industrials                       NaN
# 3387             NaN             Industrials                       NaN
# 3388             NaN             Real Estate                       NaN
#
#                                   Industry  \
# 0                                Chemicals
# 1                            Food Products
# 2                            Food Products
# 3                            Food Products
# 4     Real Estate Management & Development
# ...                                    ...
# 3384                                   NaN
# 3385                                   NaN
# 3386                                   NaN
# 3387                                   NaN
# 3388                                   NaN
#
#                               Sub-Industry  \
# 0     Fertilizers & Agricultural Chemicals
# 1                    Agricultural Products
# 2                    Agricultural Products
# 3                    Agricultural Products
# 4      Diversified Real Estate Activities
# ...                                    ...
# 3384                                   NaN
# 3385                                   NaN
# 3386                                   NaN
# 3387                                   NaN
# 3388                                   NaN
#
#                                                 Comment
# 0     Producers of fertilizers, pesticides, potash o...
# 1     Producers of agricultural products. Includes c...
# 2     Producers of agricultural products. Includes c...
# 3     Producers of agricultural products. Includes c...
# 4     Companies engaged in a diverse spectrum of rea...
# ...                                                 ...
# 3384                                                NaN
# 3385                                                NaN
# 3386                                                NaN
# 3387                                                NaN
# 3388                                                NaN
#
# [3389 rows x 8 columns]

# %%
# Merge on Symbol and company
corporate_rating = corporate_rating.merge(company_sectors, how='left', left_on='Symbol', right_on='Ticker')
corporate_rating
# Out:
#      Rating Symbol                  Rating Agency Name        Date  \
# 0       BBB    BCE                                DBRS  2016-08-08
# 1       BBB    BEP                                DBRS  2015-11-09
# 2       BBB    BEP                                DBRS  2015-11-25
# 3         A    CCJ                                DBRS  2016-06-03
# 4         A   COST                                DBRS  2014-05-20
# ...     ...    ...                                 ...         ...
# 8727    BBB    ZTS  Standard & Poor's Ratings Services  2014-01-31
# 8728    BBB    ZTS  Standard & Poor's Ratings Services  2015-01-30
# 8729    BBB    ZTS  Standard & Poor's Ratings Services  2015-11-03
# 8730    BBB    ZTS  Standard & Poor's Ratings Services  2016-01-22
# 8731    BBB    ZTS  Standard & Poor's Ratings Services  2016-12-23
#
#              Source  Rating Rank AAA is 10 Next Rating Next Rating Date  \
# 0              Both                      7         NaN              NaN
# 1     Supplementary                      7         BBB       2015-11-25
# 2     Supplementary                      7         NaN              NaN
# 3     Supplementary                      8         NaN              NaN
# 4     Supplementary                      8         NaN              NaN
# ...             ...                    ...         ...              ...
# 8727           Both                      7         BBB       2015-01-30
# 8728           Both                      7         BBB       2015-11-03
# 8729  Supplementary                      7         BBB       2016-01-22
# 8730           Both                      7         BBB       2016-12-23
# 8731       Original                      7         NaN              NaN
#
#      Previous Rating Previous Rating Date  ...         Type Change in Rating  \
# 0                NaN                  NaN  ...    Ambiguous              NaN
# 1                NaN                  NaN  ...    Ambiguous              NaN
# 2                BBB           2015-11-09  ...  Affirmation              0.0
# 3                NaN                  NaN  ...    Ambiguous              NaN
# 4                NaN                  NaN  ...    Ambiguous              NaN
# ...              ...                  ...  ...          ...              ...
# 8727             BBB           2013-10-11  ...  Affirmation              0.0
# 8728             BBB           2014-01-31  ...  Affirmation              0.0
# 8729             BBB           2015-01-30  ...  Affirmation              0.0
# 8730             BBB           2015-11-03  ...  Affirmation              0.0
# 8731             BBB           2016-01-22  ...  Affirmation              0.0
#
#       Ticker                                        Description  \
# 0        BCE                                                NaN
# 1        BEP                                                NaN
# 2        BEP                                                NaN
# 3        CCJ                                                NaN
# 4       COST  Costco Wholesale Corporation is engaged in the...
# ...      ...                                                ...
# 8727     ZTS  Zoetis Inc. is focused on the discovery, devel...
# 8728     ZTS  Zoetis Inc. is focused on the discovery, devel...
# 8729     ZTS  Zoetis Inc. is focused on the discovery, devel...
# 8730     ZTS  Zoetis Inc. is focused on the discovery, devel...
# 8731     ZTS  Zoetis Inc. is focused on the discovery, devel...
#
#                Company Name                  Sector  \
# 0                       NaN  Communication Services
# 1                       NaN                  Energy
# 2                       NaN                  Energy
# 3                       NaN                  Energy
# 4     COSTCO WHOLESALE CORP        Consumer Staples
# ...                     ...                     ...
# 8727             ZOETIS INC             Health Care
# 8728             ZOETIS INC             Health Care
# 8729             ZOETIS INC             Health Care
# 8730             ZOETIS INC             Health Care
# 8731             ZOETIS INC             Health Care
#
#                                       Industry Group  \
# 0                                                NaN
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN
# 4                           Food & Staples Retailing
# ...                                              ...
# 8727  Pharmaceuticals, Biotechnology & Life Sciences
# 8728  Pharmaceuticals, Biotechnology & Life Sciences
# 8729  Pharmaceuticals, Biotechnology & Life Sciences
# 8730  Pharmaceuticals, Biotechnology & Life Sciences
# 8731  Pharmaceuticals, Biotechnology & Life Sciences
#
#                       Industry                  Sub-Industry  \
# 0                          NaN                           NaN
# 1                          NaN                           NaN
# 2                          NaN                           NaN
# 3                          NaN                           NaN
# 4     Food & Staples Retailing  Hypermarkets & Super Centers
# ...                        ...                           ...
# 8727           Pharmaceuticals               Pharmaceuticals
# 8728           Pharmaceuticals               Pharmaceuticals
# 8729           Pharmaceuticals               Pharmaceuticals
# 8730           Pharmaceuticals               Pharmaceuticals
# 8731           Pharmaceuticals               Pharmaceuticals
#
#                                                 Comment
# 0                                                   NaN
# 1                                                   NaN
# 2                                                   NaN
# 3                                                   NaN
# 4     Owners and operators of hypermarkets and super...
# ...                                                 ...
# 8727  Companies engaged in the research, development...
# 8728  Companies engaged in the research, development...
# 8729  Companies engaged in the research, development...
# 8730  Companies engaged in the research, development...
# 8731  Companies engaged in the research, development...
#
# [8732 rows x 21 columns]

# %%
# Convert Date to datetime in pandas
corporate_rating['Date'] = pd.to_datetime(corporate_rating['Date'])

# %%
# All columns
print(corporate_rating.columns)
# Out:
# Index(['Rating', 'Symbol', 'Rating Agency Name', 'Date', 'Source',
#        'Rating Rank AAA is 10', 'Next Rating', 'Next Rating Date',
#        'Previous Rating', 'Previous Rating Date',
#        'Next Rating Date or End of Data', 'Type', 'Change in Rating', 'Ticker',
#        'Description', 'Company Name', 'Sector', 'Industry Group', 'Industry',
#        'Sub-Industry', 'Comment'],
#       dtype='object')

# %%
# Summarize variables
corporate_rating.describe()
# Out:
#                                 Date  Rating Rank AAA is 10  Change in Rating
# count                           8732            8732.000000       6781.000000
# mean   2014-06-11 15:19:22.620247552               6.838983          0.000885
# min              2005-08-16 00:00:00               1.000000         -4.000000
# 25%              2013-07-08 18:00:00               6.000000          0.000000
# 50%              2014-07-25 00:00:00               7.000000          0.000000
# 75%              2015-07-27 06:00:00               8.000000          0.000000
# max              2016-12-27 00:00:00              10.000000          4.000000
# std                              NaN               1.290282          0.511230

# %%
# Create Year variable
corporate_rating['Year'] = corporate_rating['Date'].dt.year

# Bar chart, sorted by Year
print(corporate_rating['Year'].value_counts().sort_index().plot(kind='bar', title='Number of Credit Ratings Issued by Year'))

# Table of values of Year
print(corporate_rating['Year'].value_counts().sort_index())
# Out:
# Axes(0.125,0.11;0.775x0.77)
# Year
# 2005       1
# 2009       1
# 2010      47
# 2011     355
# 2012    1250
# 2013    1516
# 2014    2109
# 2015    2259
# 2016    1194
# Name: count, dtype: int64

# %%
# How many observations/ratings per company? Create histogram with bin width of 1 and axis ticks every 1
# Bars centered over ticks
# Bar width of 0.5
plt.hist(corporate_rating['Symbol'].value_counts(), bins=range(10), align='left', rwidth=0.5)
plt.xticks(range(10))
plt.title('Number of Rating Issuances per Company')
plt.show()

# %%
# Bar chart of Rating
corporate_rating['Rating'].value_counts().plot(kind='bar', title='Issuances of Each Rating')
# Out:
# <Axes: title={'center': 'Issuances of Each Rating'}, xlabel='Rating'>

# %%
# Colored with gradient and ordered

# Colors AAA through D
# Used https://colordesigner.io/gradient-generator#google_vignette
# Assign hex codes from green to red
#32671d
#416703
#516600
#626400
#756000
#885b00
#9c5200
#af4500
#c33200
#d60000
hex_code_mapper = {'AAA': '#32671d', 'AA': '#416703', 'A': '#516600', 'BBB': '#626400', 'BB': '#756000', 'B': '#885b00', 'CCC': '#9c5200', 'CC': '#af4500', 'C': '#c33200', 'D': '#d60000'}

# Ordering of bars - keys from hex_code_mapper
bar_order = ['AAA', 'AA', 'A', 'BBB', 'BB', 'B', 'CCC', 'CC', 'C', 'D']
# Assign values of Rating to this ordering
corporate_rating['Rating'] = pd.Categorical(corporate_rating['Rating'], categories=bar_order, ordered=True)

# Create plot
# Save to "../Output/Distribution of Ratings.png"
plt.bar(corporate_rating['Rating'].value_counts().sort_index().index, corporate_rating['Rating'].value_counts().sort_index(), color=[hex_code_mapper[i] for i in bar_order])
plt.title('Issuances of Each Rating')
#plt.savefig('../../Output/Distribution of Rating Issuances.png')
plt.show()

# %%
# Plot of Rating Agency Name
plt.bar(corporate_rating['Rating Agency Name'].value_counts().index, corporate_rating['Rating Agency Name'].value_counts())
plt.title('Number of Rating Issuances by Rating Agency')
#plt.savefig('../../Output/Rating Issuances by Rating Agency.png')
import textwrap
f = lambda x: textwrap.fill(x.get_text(), 8)
plt.gca().set_xticklabels(map(f, plt.gca().get_xticklabels()))
plt.show()
# Out:
# C:\Users\ijyli\AppData\Local\Temp\ipykernel_18216\2179924635.py:7: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   plt.gca().set_xticklabels(map(f, plt.gca().get_xticklabels()))

# %%
# Count of firms
corporate_rating['Symbol'].nunique()
# Out:
# 886

# %%
# Distribution of Sector
corporate_rating['Sector'].value_counts().plot(kind='barh', title='Number of Rating Issuances by GICS Sector')
# Out:
# <Axes: title={'center': 'Number of Rating Issuances by GICS Sector'}, ylabel='Sector'>

# %%
# Distribution of firm by Sector
corporate_rating[['Symbol', 'Sector']].drop_duplicates()['Sector'].value_counts().plot(kind='barh', title='Number of Firms by GICS Sector')
# Out:
# <Axes: title={'center': 'Number of Firms by GICS Sector'}, ylabel='Sector'>

# %% [markdown]
# # Limited Scope - S&P Ratings 2010-2016

# %%
# Regex search for Standard & Poor's
# Limit on years
s_and_p_2010_2016_data = corporate_rating[corporate_rating['Rating Agency Name'].str.contains('Standard & Poor\'s') & (corporate_rating['Year'] >= 2010) & (corporate_rating['Year'] <= 2016)]

s_and_p_2010_2016_data
# Out:
#      Rating Symbol                  Rating Agency Name       Date  \
# 5560    AAA   AAPL  Standard & Poor's Ratings Services 2014-04-24
# 5561     AA   AAPL  Standard & Poor's Ratings Services 2014-05-27
# 5562     AA   AAPL  Standard & Poor's Ratings Services 2015-02-18
# 5563     AA   AAPL  Standard & Poor's Ratings Services 2015-05-28
# 5564     AA   AAPL  Standard & Poor's Ratings Services 2015-06-02
# ...     ...    ...                                 ...        ...
# 8727    BBB    ZTS  Standard & Poor's Ratings Services 2014-01-31
# 8728    BBB    ZTS  Standard & Poor's Ratings Services 2015-01-30
# 8729    BBB    ZTS  Standard & Poor's Ratings Services 2015-11-03
# 8730    BBB    ZTS  Standard & Poor's Ratings Services 2016-01-22
# 8731    BBB    ZTS  Standard & Poor's Ratings Services 2016-12-23
#
#              Source  Rating Rank AAA is 10 Next Rating Next Rating Date  \
# 5560  Supplementary                     10          AA       2014-05-27
# 5561  Supplementary                      9          AA       2015-02-18
# 5562  Supplementary                      9          AA       2015-05-28
# 5563           Both                      9          AA       2015-06-02
# 5564  Supplementary                      9          AA       2015-08-25
# ...             ...                    ...         ...              ...
# 8727           Both                      7         BBB       2015-01-30
# 8728           Both                      7         BBB       2015-11-03
# 8729  Supplementary                      7         BBB       2016-01-22
# 8730           Both                      7         BBB       2016-12-23
# 8731       Original                      7         NaN              NaN
#
#      Previous Rating Previous Rating Date  ... Change in Rating Ticker  \
# 5560             NaN                  NaN  ...              NaN   AAPL
# 5561             AAA           2014-04-24  ...             -1.0   AAPL
# 5562              AA           2014-05-27  ...              0.0   AAPL
# 5563              AA           2015-02-18  ...              0.0   AAPL
# 5564              AA           2015-05-28  ...              0.0   AAPL
# ...              ...                  ...  ...              ...    ...
# 8727             BBB           2013-10-11  ...              0.0    ZTS
# 8728             BBB           2014-01-31  ...              0.0    ZTS
# 8729             BBB           2015-01-30  ...              0.0    ZTS
# 8730             BBB           2015-11-03  ...              0.0    ZTS
# 8731             BBB           2016-01-22  ...              0.0    ZTS
#
#                                             Description Company Name  \
# 5560  Apple Inc. (Apple) designs, manufactures and m...    APPLE INC
# 5561  Apple Inc. (Apple) designs, manufactures and m...    APPLE INC
# 5562  Apple Inc. (Apple) designs, manufactures and m...    APPLE INC
# 5563  Apple Inc. (Apple) designs, manufactures and m...    APPLE INC
# 5564  Apple Inc. (Apple) designs, manufactures and m...    APPLE INC
# ...                                                 ...          ...
# 8727  Zoetis Inc. is focused on the discovery, devel...   ZOETIS INC
# 8728  Zoetis Inc. is focused on the discovery, devel...   ZOETIS INC
# 8729  Zoetis Inc. is focused on the discovery, devel...   ZOETIS INC
# 8730  Zoetis Inc. is focused on the discovery, devel...   ZOETIS INC
# 8731  Zoetis Inc. is focused on the discovery, devel...   ZOETIS INC
#
#                       Sector                                  Industry Group  \
# 5560  Information Technology                 Technology Hardware & Equipment
# 5561  Information Technology                 Technology Hardware & Equipment
# 5562  Information Technology                 Technology Hardware & Equipment
# 5563  Information Technology                 Technology Hardware & Equipment
# 5564  Information Technology                 Technology Hardware & Equipment
# ...                      ...                                             ...
# 8727             Health Care  Pharmaceuticals, Biotechnology & Life Sciences
# 8728             Health Care  Pharmaceuticals, Biotechnology & Life Sciences
# 8729             Health Care  Pharmaceuticals, Biotechnology & Life Sciences
# 8730             Health Care  Pharmaceuticals, Biotechnology & Life Sciences
# 8731             Health Care  Pharmaceuticals, Biotechnology & Life Sciences
#
#                                         Industry  \
# 5560  Technology Hardware, Storage & Peripherals
# 5561  Technology Hardware, Storage & Peripherals
# 5562  Technology Hardware, Storage & Peripherals
# 5563  Technology Hardware, Storage & Peripherals
# 5564  Technology Hardware, Storage & Peripherals
# ...                                          ...
# 8727                             Pharmaceuticals
# 8728                             Pharmaceuticals
# 8729                             Pharmaceuticals
# 8730                             Pharmaceuticals
# 8731                             Pharmaceuticals
#
#                                     Sub-Industry  \
# 5560  Technology Hardware, Storage & Peripherals
# 5561  Technology Hardware, Storage & Peripherals
# 5562  Technology Hardware, Storage & Peripherals
# 5563  Technology Hardware, Storage & Peripherals
# 5564  Technology Hardware, Storage & Peripherals
# ...                                          ...
# 8727                             Pharmaceuticals
# 8728                             Pharmaceuticals
# 8729                             Pharmaceuticals
# 8730                             Pharmaceuticals
# 8731                             Pharmaceuticals
#
#                                                 Comment  Year
# 5560  Manufacturers of cellular phones, personal com...  2014
# 5561  Manufacturers of cellular phones, personal com...  2014
# 5562  Manufacturers of cellular phones, personal com...  2015
# 5563  Manufacturers of cellular phones, personal com...  2015
# 5564  Manufacturers of cellular phones, personal com...  2015
# ...                                                 ...   ...
# 8727  Companies engaged in the research, development...  2014
# 8728  Companies engaged in the research, development...  2015
# 8729  Companies engaged in the research, development...  2015
# 8730  Companies engaged in the research, development...  2016
# 8731  Companies engaged in the research, development...  2016
#
# [3171 rows x 22 columns]

# %%
# Min and max of Date
print(s_and_p_2010_2016_data['Date'].min())
print(s_and_p_2010_2016_data['Date'].max())
# Out:
# 2010-04-06 00:00:00
# 2016-12-23 00:00:00

# %%
# Count of firms
s_and_p_2010_2016_data['Symbol'].nunique()
# Out:
# 638

# %%
# How many observations/ratings per company? Create histogram with bin width of 1 and axis ticks every 1
# Bars centered over ticks
# Bar width of 0.5
plt.hist(s_and_p_2010_2016_data['Symbol'].value_counts(), bins=range(10), align='left', rwidth=0.5)
plt.xticks(range(10))
plt.title('Number of Rating Issuances per Company - S&P 2010-2016')
plt.savefig('../../../Output/Number of Rating Issuances per Company - S&P 2010-2016.png')
plt.show()

# %%
# Values of Type
print('Num ratings issued')
print(len(s_and_p_2010_2016_data))
print(s_and_p_2010_2016_data['Type'].value_counts())
# Out:
# Num ratings issued
# 3171
# Type
# Affirmation    1992
# Ambiguous       637
# Upgrade         292
# Downgrade       250
# Name: count, dtype: int64

# %%
# Distribution of 'Change in Rating'
# Plot a histogram
plt.hist(s_and_p_2010_2016_data['Change in Rating'], bins=range(-10, 11), align='left', rwidth=0.5)
# Title: 'Change in Rating'
plt.title('Change in Rating')
# ticks every 1
plt.xticks(range(-10, 11))
plt.show()

# Print values
print(s_and_p_2010_2016_data['Change in Rating'].value_counts().sort_index())
# Out:
# Change in Rating
# -4.0       1
# -3.0       2
# -2.0      21
# -1.0     226
#  0.0    1992
#  1.0     266
#  2.0      23
#  3.0       3
# Name: count, dtype: int64

# %%
# Distribution of Sector
s_and_p_2010_2016_data['Sector'].value_counts().plot(kind='barh', title='Number of Rating Issuances by GICS Sector')
# Out:
# <Axes: title={'center': 'Number of Rating Issuances by GICS Sector'}, ylabel='Sector'>

# %%
# Distribution of firm by Sector
s_and_p_2010_2016_data[['Symbol', 'Sector']].drop_duplicates()['Sector'].value_counts().plot(kind='barh', title='Number of Firms by GICS Sector')
# Out:
# <Axes: title={'center': 'Number of Firms by GICS Sector'}, ylabel='Sector'>

# %%
# Create plot
plt.bar(s_and_p_2010_2016_data['Rating'].value_counts().sort_index().index, s_and_p_2010_2016_data['Rating'].value_counts().sort_index(), color=[hex_code_mapper[i] for i in bar_order])
plt.title('Issuances of Each S&P Rating')
plt.show()
